# %% [markdown]
# # Cubic Bezier Optimization

# %% [markdown]
# Optimizes a cubic bezier curved-line path from a point on the viable brain surface region to a point on the subthalamic nucleus (STN) for DBS electrode planning.
#
# Treats the following as obstacles:
# - Sulci
# - Ventricles
# - Corpus Callosum (prevent brain crossing)

# %% [markdown]
# **Objective Functions**
# - Distance to obstacles
# - Minimum path distance  *(not optimized yet)*

# %% [markdown]
# Includes P1 and P2 optimization using differential evolution function

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### Import Libraries

# %%
import os
import glob
import random
import numpy as np
import pandas as pd

import vedo
from vedo import Volume, show, Line, merge, Plotter, Points

from scipy.optimize import minimize, differential_evolution

import k3d

# %%
# Set vedo backend to pop out plots in separate windows
vedo.settings.default_backend = '2d' # or 'vt' or '2d' or 'k3d' or 'ipyvtklink'

# %%
# ## Vedo sphere plot test
# sphere = vedo.Sphere(pos=[0, 0, 0], c="red", r=1.0)
# plotter = vedo.Plotter()
# plotter += sphere
# plotter.show(axes=1, viewup='z', zoom=1.5)

# %% [markdown]
# ### Configuration and Setup

# %%
# Define new base directory and sub-folder structure
base_dir = "./FINAL_BRAIN_ATLAS/final_nii_files"

# Entry zones (viable surface regions for path start)
entry_zone_dir = os.path.join(base_dir, "entry_zone")
left_entry_zone_dir = os.path.join(entry_zone_dir, "LEFT_ENTRY_ZONE")
right_entry_zone_dir = os.path.join(entry_zone_dir, "RIGHT_ENTRY_ZONE")

# Subthalamic nucleus (targets)
stn_root_dir = os.path.join(base_dir, "subthalamic_nucleus")
left_stn_dir = os.path.join(stn_root_dir, "LEFT_STN")
right_stn_dir = os.path.join(stn_root_dir, "RIGHT_STN")

# Full brain (for context / outline only)
full_brain_dir = os.path.join(base_dir, "full_brain")

# Skin surface (outer head/skin/skull)
skin_dir = os.path.join(base_dir, "skin")

# Obstacles (same role as before)
obstacles_dir = os.path.join(base_dir, "obstacles")

print("Base directory:", base_dir)
# Out:
# Base directory: ./FINAL_BRAIN_ATLAS/final_nii_files

# %% [markdown]
# ### Load Brain Structures
#
# Recursively load all `.nii` / `.nii.gz` files under each designated root:
# - Entry Zones (LEFT/RIGHT) viable start regions (light brown, low alpha)
# - STN Targets (LEFT/RIGHT) (distinct greens)
# - Obstacles (red)
# - Full Brain outline (very light grey, minimal alpha)
#
# All subfolder contents are merged later per category.

# %%
# Initialize lists for different structure types
left_entry_zone_structures = []
right_entry_zone_structures = []
left_stn_structures = []
right_stn_structures = []
allowed_left_entry_zone_structures = []
allowed_right_entry_zone_structures = []
obstacle_structures = []
full_brain_structures = []
skin_structures = []

# Loader utility: walk all subfolders and load every .nii / .nii.gz
def load_folder_surfaces(root_folder, color, alpha=1.0):
    loaded = []
    if not os.path.isdir(root_folder):
        print(f"[WARN] Folder not found: {root_folder}")
        return loaded
    
    for dirpath, dirnames, filenames in os.walk(root_folder):
        nii_files = [f for f in filenames if f.lower().endswith('.nii') or f.lower().endswith('.nii.gz')]
        for fname in nii_files:
            fpath = os.path.join(dirpath, fname)
            rel = os.path.relpath(fpath, root_folder)
            print(f"  Loading structure: {rel}")
            try:
                vol = Volume(fpath)
                surf = vol.isosurface()
                surf.c(color).alpha(alpha)
                loaded.append(surf)
            except Exception as e:
                print(f"  [WARN] Failed to load volume/surface: {fpath} ({e})")
    if not loaded:
        print(f"  [INFO] No NIfTI files found under {root_folder}")
    return loaded

print("\nLoading Entry Zones (LEFT)...")
left_entry_zone_structures = load_folder_surfaces(left_entry_zone_dir, color=(0.95, 0.65, 0.85), alpha=0.04)
print("Loading Entry Zones (RIGHT)...")
right_entry_zone_structures = load_folder_surfaces(right_entry_zone_dir, color=(0.95, 0.75, 0.85), alpha=0.04)

# STN folders (may already be deepest; recursion still safe)
print("\nLoading STN (LEFT)...")
left_stn_structures = load_folder_surfaces(left_stn_dir, color="green", alpha=1.0)
print("Loading STN (RIGHT)...")
right_stn_structures = load_folder_surfaces(right_stn_dir, color="green", alpha=1.0)

print("\nLoading Obstacles...")
obstacle_structures = load_folder_surfaces(obstacles_dir, color="red", alpha=0.7)

print("\nLoading Full Brain Outline...")
full_brain_structures = load_folder_surfaces(full_brain_dir, color="grey", alpha=0.01)

print("\nLoading Skin Surface...")
# Use light skin tone color and slightly higher alpha for visibility
skin_structures = load_folder_surfaces(skin_dir, color="grey", alpha=0.02)
# Out:
# Loading Entry Zones (LEFT)...
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1003_posterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1012_left_lateral_orbital_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1014_left_straight_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1017_left_paracentral_lobule.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1018_opercular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1019_orbital_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1020_triangular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1024_left_precentral_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1027_anterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1028_left_superior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1032_left_frontal_pole.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1008_left_inferior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1022_left_postcentral_gyrus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1025_left_precuneus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1029_left_superior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1031_left_supramarginal_gyrus.nii
# Loading Entry Zones (RIGHT)...
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2003_posterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2012_right_lateral_orbital_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2014_right_straight_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2017_right_paracentral_lobule.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2018_opercular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2019_orbital_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2020_triangular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2024_right_precentral_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2027_anterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2028_right_superior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2032_right_frontal_pole.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2008_right_inferior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2022_right_postcentral_gyrus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2025_right_precuneus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2029_right_superior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2031_right_supramarginal_gyrus.nii
#
# Loading STN (LEFT)...
#   Loading structure: Model_391_left_subthalamic_nucleus.nii
# Loading STN (RIGHT)...
#   Loading structure: Model_390_right_subthalamic_nucleus.nii
#
# Loading Obstacles...
#   Loading structure: SULCI\Model_5001_left_calcarine_sulcus.nii
#   Loading structure: SULCI\Model_5002_right_calcarine_sulcus.nii
#   Loading structure: SULCI\Model_5003_left_central_sulcus.nii
#   Loading structure: SULCI\Model_5004_right_central_sulcus.nii
#   Loading structure: SULCI\Model_5005_left_cingulate_sulcus.nii
#   Loading structure: SULCI\Model_5006_right_cingulate_sulcus.nii
#   Loading structure: SULCI\Model_5007_left_collateral_sulcus.nii
#   Loading structure: SULCI\Model_5008_right_collateral_sulcus.nii
#   Loading structure: SULCI\Model_5009_left_inferior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5010_right_inferior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5011_left_intraparietal_sulcus.nii
#   Loading structure: SULCI\Model_5012_right_intraparietal_sulcus.nii
#   Loading structure: SULCI\Model_5013_left_parieto-occipital_sulcus.nii
#   Loading structure: SULCI\Model_5014_right_parieto-occipital_sulcus.nii
#   Loading structure: SULCI\Model_5015_left_postcentral_sulcus.nii
#   Loading structure: SULCI\Model_5016_right_postcentral_sulcus.nii
#   Loading structure: SULCI\Model_5017_left_precentral_sulcus.nii
#   Loading structure: SULCI\Model_5018_right_precentral_sulcus.nii
#   Loading structure: SULCI\Model_5019_left_superior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5020_right_superior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5022_right_superior_temporal_sulcus.nii
#   Loading structure: VENTRICLE\Model_15_fourth_ventricle.nii
#   Loading structure: VENTRICLE\Model_19_aqueduct.nii
#   Loading structure: VENTRICLE\Model_24_third_ventricle.nii
#   Loading structure: VENTRICLE\Model_43_right_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_44_temporal_horn_of_right_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_4_left_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_5_temporal_horn_of_left_lateral_ventricle.nii
#
# Loading Full Brain Outline...
#   Loading structure: CEREBELLUM\Model_46_white_matter_of_right_hemisphere_of_cerebellum.nii
#   Loading structure: CEREBELLUM\Model_7_white_matter_of_left_hemisphere_of_cerebellum.nii
#   Loading structure: CORPUS_CALLOSUM\Model_3004_corpus_callosum.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1003_posterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1012_left_lateral_orbital_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1014_left_straight_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1017_left_paracentral_lobule.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1018_opercular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1019_orbital_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1020_triangular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1024_left_precentral_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1027_anterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1028_left_superior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1032_left_frontal_pole.nii
#   Loading structure: LEFT_INSULA\Model_1000_left_insula.nii
#   Loading structure: LEFT_INSULA\Model_1035_left_limen_insulae.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1002_caudal_part_of_left_anterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1010_isthmus_of_left_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1016_left_parahippocampal_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1023_left_posterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1026_rostral_part_of_left_anterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_17_left_hippocampus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_18_left_amygdala.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1005_left_cuneus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1011_left_lateral_occipital_gyrus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1013_left_lingual_gyrus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1021_left_visual_cortex.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1008_left_inferior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1022_left_postcentral_gyrus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1025_left_precuneus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1029_left_superior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1031_left_supramarginal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1001_left_superior_temporal_gyrus_(banks_of_left_superior_temporal_sulcus).nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1006_left_ambiens_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1007_left_fusiform_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1009_left_inferior_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1015_left_middle_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1030_left_superior_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1033_left_temporal_pole.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1034_left_transverse_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_3001_left_claustrum.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2003_posterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2012_right_lateral_orbital_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2014_right_straight_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2017_right_paracentral_lobule.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2018_opercular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2019_orbital_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2020_triangular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2024_right_precentral_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2027_anterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2028_right_superior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2032_right_frontal_pole.nii
#   Loading structure: RIGHT_INSULA\Model_2000_right_insula.nii
#   Loading structure: RIGHT_INSULA\Model_2035_right_limen_insulae.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2002_caudal_part_of_right_anterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2010_isthmus_of_right_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2016_right_parahippocampal_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2023_right_posterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2026_rostral_part_of_right_anterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_53_right_hippocampus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_54_right_amygdala.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2005_right_cuneus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2011_right_lateral_occipital_gyrus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2013_right_lingual_gyrus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2021_right_visual_cortex.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2008_right_inferior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2022_right_postcentral_gyrus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2025_right_precuneus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2029_right_superior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2031_right_supramarginal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2001_right_superior_temporal_gyrus_(banks_of_right_superior_temporal_sulcus).nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2006_right_ambiens_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2007_right_fusiform_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2009_right_inferior_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2015_right_middle_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2030_right_superior_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2033_right_temporal_pole.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2034_right_transverse_temporal_gyrus.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_11_left_caudate_nucleus.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_12_left_putamen.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_13_left_globus_pallidus_pars_externa.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_25_left_globus_pallidus_pars_interna.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_26_left_nucleus_accumbens.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_2_white_matter_of_left_cerebral_hemisphere.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_3007_left_fornix_of_forebrain.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_3005_right_fornix_of_forebrain.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_41_white_matter_of_right_cerebral_hemisphere.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_50_right_caudate_nucleus.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_51_right_putamen.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_52_right_globus_pallidus_pars_externa.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_58_right_nucleus_accumbens.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_83_right_globus_pallidus_pars_interna.nii
#
# Loading Skin Surface...
#   Loading structure: Model_3_skin.nii

# %% [markdown]
# ### Merge Structures
#
# Combine individual structures into single meshes for:
# - LEFT/RIGHT Entry Zones (start sampling)
# - LEFT/RIGHT STN (target sampling hemisphere-consistent)
# - Obstacles (for intersection & distance)
# - Full Brain (context outline only)

# %%
# Merge structures into single meshes
merged_left_entry_zone = merge(left_entry_zone_structures) if left_entry_zone_structures else None
if merged_left_entry_zone: merged_left_entry_zone.alpha(0.04)

merged_right_entry_zone = merge(right_entry_zone_structures) if right_entry_zone_structures else None
if merged_right_entry_zone: merged_right_entry_zone.alpha(0.04)

merged_allowed_left_entry_zone = merged_left_entry_zone
merged_allowed_right_entry_zone = merged_right_entry_zone

merged_left_stn = merge(left_stn_structures) if left_stn_structures else None
merged_right_stn = merge(right_stn_structures) if right_stn_structures else None

merged_obstacles = merge(obstacle_structures) if obstacle_structures else None
if merged_obstacles: merged_obstacles.c("red").alpha(0.75)

merged_full_brain = merge(full_brain_structures) if full_brain_structures else None
if merged_full_brain: merged_full_brain.c("grey").alpha(0.01)

merged_skin = merge(skin_structures) if skin_structures else None
if merged_skin: merged_skin.c("grey").alpha(0.02)

print("\nMerged Summary:")
print(f"  Left Entry Zone: {'yes' if merged_left_entry_zone else 'no'}")
print(f"  Right Entry Zone: {'yes' if merged_right_entry_zone else 'no'}")
print(f"  Left Allowed Entry Zone: {'yes' if merged_allowed_left_entry_zone else 'no'}")
print(f"  Right Allowed Entry Zone: {'yes' if merged_allowed_right_entry_zone else 'no'}")
print(f"  Left STN: {'yes' if merged_left_stn else 'no'}")
print(f"  Right STN: {'yes' if merged_right_stn else 'no'}")
print(f"  Obstacles: {'yes' if merged_obstacles else 'no'}")
print(f"  Full Brain: {'yes' if merged_full_brain else 'no'}")
print(f"  Skin: {'yes' if merged_skin else 'no'}")
# Out:
# Merged Summary:
#   Left Entry Zone: yes
#   Right Entry Zone: yes
#   Left Allowed Entry Zone: yes
#   Right Allowed Entry Zone: yes
#   Left STN: yes
#   Right STN: yes
#   Obstacles: yes
#   Full Brain: yes
#   Skin: yes

# %%
# # Plot and show the outer entry zone
# actors1 = []
# actors1.append(merged_allowed_left_entry_zone)
# actors1.append(merged_allowed_right_entry_zone)
# actors1.append(merged_skin)
# # actors1.append(merged_full_brain)
# show(actors1, axes=1, viewup="z", title="Entry Zones")

# %% [markdown]
# ### Helper Functions

# %%
def compute_path_length(start_point, end_point):
    """Compute the distance between two points for the line path."""
    return np.linalg.norm(np.array(end_point) - np.array(start_point))


def compute_obstacle_distance(start_point, end_point):
    """Compute the minimum distance from the line path to any obstacle."""
    if merged_obstacles is None:
        return 0.0
    temp_line = Line([start_point, end_point])
    d = temp_line.distance_to(merged_obstacles)
    if isinstance(d, (list, tuple, np.ndarray)):
        return float(np.min(d))
    return float(d)


def check_intersection(start_point, end_point):
    """Check if the line path intersects any obstacle."""
    if merged_obstacles is None:
        return False
    intersections = merged_obstacles.intersect_with_line(start_point, end_point)
    return intersections is not None and len(intersections) > 0


def _closest_point_on_mesh(point, mesh):
    """Project a 3D point onto the closest point on a mesh surface."""
    if mesh is None:
        return tuple(point)
    try:
        cp = mesh.closest_point(point)
        return tuple(cp)
    except Exception:
        # Fallback to nearest vertex
        verts = np.asarray(mesh.vertices)
        if verts.size == 0:
            return tuple(point)
        idx = int(np.argmin(np.linalg.norm(verts - np.asarray(point), axis=1)))
        return tuple(verts[idx])


def project_to_surfaces(start_point, end_point, hemisphere):
    """Project start onto entry zone then onto skin; end onto STN for hemisphere."""
    # 1. project to entry zone of hemisphere
    if hemisphere == 'left':
        sp_entry = _closest_point_on_mesh(start_point, merged_allowed_left_entry_zone)
        ep = _closest_point_on_mesh(end_point, merged_left_stn)
    else:
        sp_entry = _closest_point_on_mesh(start_point, merged_allowed_right_entry_zone)
        ep = _closest_point_on_mesh(end_point, merged_right_stn)
    # 2. project onto head skin surface
    sp = _closest_point_on_mesh(sp_entry, merged_skin)
    return sp, ep


def sample_start_and_end():
    """Sample a hemisphere-consistent start (entry zone) and end (STN)."""
    hemispheres = []
    if merged_allowed_left_entry_zone and merged_left_stn:
        hemispheres.append('left')
    if merged_allowed_right_entry_zone and merged_right_stn:
        hemispheres.append('right')
    if not hemispheres:
        raise RuntimeError("No valid hemisphere data available for sampling.")
    hemi = random.choice(hemispheres)
    # Sample a random point from entry zone surface, then project to skin
    if hemi == 'left':
        start_entry = tuple(merged_allowed_left_entry_zone.generate_random_points(1).points[0])
        end = tuple(merged_left_stn.generate_random_points(1).points[0])
    else:
        start_entry = tuple(merged_allowed_right_entry_zone.generate_random_points(1).points[0])
        end = tuple(merged_right_stn.generate_random_points(1).points[0])
    start = _closest_point_on_mesh(start_entry, merged_skin)
    return hemi, start, end

# %% [markdown]
# ## Cubic Bezier Function

# %% [markdown]
# Initialize variables

# %%
R_MIN_MM = 40.0  # min radius of curvature
NUM_SAMPLE = 500 # number of line samples for bezier helper functions
MAX_P1_P2_OPT_IT = 20 # max number of iterations for p1 p2 optimization
P1_P2_OPT_TOL = 1e-2 # tolerance for p1 p2 differential evolution optimization

w_obstacle = 0.9     # Weight for obstacle distance (higher = prefer safer paths)
w_path_length = 0.1   # Weight for path length (higher = prefer shorter paths)

# Normalize weights to sum to 1
total_weight = w_obstacle + w_path_length
w_obstacle_norm = w_obstacle / total_weight
w_path_length_norm = w_path_length / total_weight

# %% [markdown]
# #### Helper Functions

# %%
# def propose_control_points(start, end): ## random generation of alpha, beta, gamma, and direction vector
#     start = np.array(start)
#     end = np.array(end)
#     d = end - start
#     d_norm = d / np.linalg.norm(d)

#     # perpendicular vector
#     tmp = np.random.randn(3)
#     perp = tmp - np.dot(tmp, d_norm)*d_norm
#     perp /= np.linalg.norm(perp)

#     alpha = np.random.uniform(0.1, 0.4)
#     gamma = np.random.uniform(0.6, 0.9)
#     beta = np.random.uniform(0, 25.0)  # mm

#     P1 = start + alpha * d + beta * perp
#     P2 = start + gamma * d - beta * perp

#     return P1, P2


def control_points_from_params_with_angle(start_point, end_point,
                                          alpha, gamma, beta_mm, theta):
    P0 = np.asarray(start_point, dtype=float)
    P3 = np.asarray(end_point, dtype=float)
    d = P3 - P0
    d_norm = d / (np.linalg.norm(d) + 1e-9)

    # build an orthonormal basis (u, v) in the plane perp to d_norm
    if abs(d_norm[0]) < 0.9:
        ref = np.array([1.0, 0.0, 0.0])
    else:
        ref = np.array([0.0, 1.0, 0.0])

    u = np.cross(d_norm, ref)
    u /= (np.linalg.norm(u) + 1e-9)

    v = np.cross(d_norm, u)
    v /= (np.linalg.norm(v) + 1e-9)

    # optimized perpendicular direction
    perp = np.cos(theta) * u + np.sin(theta) * v

    P1 = P0 + alpha * d + beta_mm * perp
    P2 = P0 + gamma * d - beta_mm * perp
    return P1, P2


def sample_bezier_points(start_point, control_point1, control_point2, end_point, num_samples=NUM_SAMPLE):
    # sample points along 3d cubic bezier curve
    P0 = np.asarray(start_point, dtype=float)
    P1 = np.asarray(control_point1, dtype=float)
    P2 = np.asarray(control_point2, dtype=float)
    P3 = np.asarray(end_point, dtype=float)

    t = np.linspace(0.0, 1.0, num_samples)
    one_minus_t = 1.0 - t

    pts = (
        (one_minus_t**3)[:, None] * P0 +
        (3 * one_minus_t**2 * t)[:, None] * P1 +
        (3 * one_minus_t * t**2)[:, None] * P2 +
        (t**3)[:, None] * P3
    )
    return pts


def compute_obstacle_distance_bezier(start_point, end_point, control_point1, control_point2, num_samples=NUM_SAMPLE):
    # calculate the minimum distance from the cubic bezier path to any obstacle
    if merged_obstacles is None:
        return 0.0

    pts = sample_bezier_points(start_point, control_point1, control_point2, end_point, num_samples=num_samples)
    curve_pts = Points(pts)

    d = curve_pts.distance_to(merged_obstacles)
    if isinstance(d, (list, tuple, np.ndarray)):
        return float(np.min(d))
    return float(d)


def check_intersection_bezier(start_point, end_point, control_point1, control_point2, num_samples=NUM_SAMPLE):
    """
    1. check if the cubic bezier path intersects any obstacle, and
    2. approximates curve with short line segments and tests each segment.
    """
    if merged_obstacles is None:
        return False

    pts = sample_bezier_points(start_point, control_point1, control_point2, end_point, num_samples=num_samples)

    # check each segment along the curve
    for i in range(len(pts) - 1):
        p0 = pts[i]
        p1 = pts[i + 1]
        intersections = merged_obstacles.intersect_with_line(p0, p1)
        if intersections is not None and len(intersections) > 0:
            return True

    return False


def compute_bezier_path_length(
    start_point,
    end_point,
    control_point1,
    control_point2,
    min_radius_mm=None,
    num_samples=NUM_SAMPLE,
):
    """
    compute length of 3d cubic bezeier curve btw start_point and end_point

    calculate p1 p2 from propose_control_points helper function

    """
    P0 = np.asarray(start_point, dtype=float)
    P1 = np.asarray(control_point1, dtype=float)
    P2 = np.asarray(control_point2, dtype=float)
    P3 = np.asarray(end_point, dtype=float)

    t = np.linspace(0.0, 1.0, num_samples)

    def bezier_pos(t):
        one_minus_t = 1.0 - t
        return (
            (one_minus_t**3)[:, None] * P0 +
            (3 * one_minus_t**2 * t)[:, None] * P1 +
            (3 * one_minus_t * t**2)[:, None] * P2 +
            (t**3)[:, None] * P3
        )

    # first derivative B'(t)
    def bezier_first_derivative(t):
        one_minus_t = 1.0 - t
        return (
            (3 * one_minus_t**2)[:, None] * (P1 - P0) +
            (6 * one_minus_t * t)[:, None] * (P2 - P1) +
            (3 * t**2)[:, None] * (P3 - P2)
        )

    # secibd derivative B''(t)
    def bezier_second_derivative(t):
        return (
            (6 * (1.0 - t))[:, None] * (P2 - 2*P1 + P0) +
            (6 * t)[:, None] * (P3 - 2*P2 + P1)
        )

    pts = bezier_pos(t) #sample curve

    # approx. length
    diffs = np.diff(pts, axis=0)
    segment_lengths = np.linalg.norm(diffs, axis=1)
    length = float(np.sum(segment_lengths))

    # electrode needle curvature constraint
    if min_radius_mm is not None:
        t_mid = t[1:-1]
        B1 = bezier_first_derivative(t_mid)
        B2 = bezier_second_derivative(t_mid)

        # curvature k(t) = ||B'(t) x B''(t)|| / ||B'(t)||^3
        cross = np.cross(B1, B2)
        num = np.linalg.norm(cross, axis=1)
        denom = np.linalg.norm(B1, axis=1)**3

        with np.errstate(divide='ignore', invalid='ignore'):
            curvature = np.where(denom > 0, num / denom, 0.0)

        # radius of curvature R(t) = 1 / k(t) --> if straight, R(t) = inf
        radius = np.where(curvature > 0, 1.0 / curvature, np.inf)

        min_radius_on_curve = np.min(radius)

        if min_radius_on_curve < min_radius_mm:
            # print(f"Curvature constraint violated: minimum radius along curve ")
            # print(f"is {min_radius_on_curve:.3f} mm, required >= {min_radius_mm:.3f} mm.")
            return None 

    return length

# %% [markdown]
# #### Control Point (P1 P2) Optimization Functions

# %%
def inner_cp_objective(params, start_point, end_point):
    alpha, gamma, beta_mm, theta = params

    P1, P2 = control_points_from_params_with_angle(
        start_point, end_point, alpha, gamma, beta_mm, theta
    )

    raw_length = compute_bezier_path_length(
        start_point=start_point,
        end_point=end_point,
        control_point1=P1,
        control_point2=P2,
        min_radius_mm=R_MIN_MM,
    )
    if raw_length is None:
        return 1e10

    # handle scalar vs tuple/list return
    min_radius = None
    if isinstance(raw_length, (tuple, list, np.ndarray)):
        path_length = float(raw_length[0])
        if len(raw_length) > 1:
            min_radius = raw_length[1]
    else:
        path_length = float(raw_length)

    if min_radius is not None:
        try:
            if float(min_radius) < float(R_MIN_MM):
                return 1e10
        except TypeError:
            pass

    if check_intersection_bezier(start_point, end_point, P1, P2, num_samples=NUM_SAMPLE):
        return 1e10

    obstacle_dist_raw = compute_obstacle_distance_bezier(
        start_point, end_point, P1, P2, num_samples=NUM_SAMPLE
    )

    if isinstance(obstacle_dist_raw, (list, tuple, np.ndarray)): #obj dist should be scalar
        if len(obstacle_dist_raw) == 0:
            obstacle_dist = 0.0
        else:
            obstacle_dist = float(np.min(obstacle_dist_raw))
    else:
        obstacle_dist = float(obstacle_dist_raw)
    
    try:
        if max_obstacle_dist is not None and max_obstacle_dist > 0:
            norm_obstacle_dist = obstacle_dist / max_obstacle_dist
        else:
            norm_obstacle_dist = obstacle_dist / 8

        if max_path_length is not None and max_path_length > 0:
            norm_path_length = path_length / max_path_length
        else:
            norm_path_length = path_length / 105
    except Exception:
        norm_obstacle_dist = obstacle_dist / 8
        norm_path_length = path_length / 105

    objective = -w_obstacle_norm * norm_obstacle_dist + w_path_length_norm * norm_path_length

    return objective


def control_points_from_params_with_angle(start_point, end_point,
                                          alpha, gamma, beta_mm, theta):
    P0 = np.asarray(start_point, dtype=float)
    P3 = np.asarray(end_point, dtype=float)
    d = P3 - P0
    d_norm = d / (np.linalg.norm(d) + 1e-9)

    # build an orthonormal basis in the plane perp w d_norm
    if abs(d_norm[0]) < 0.9:
        ref = np.array([1.0, 0.0, 0.0])
    else:
        ref = np.array([0.0, 1.0, 0.0])

    u = np.cross(d_norm, ref)
    u /= (np.linalg.norm(u) + 1e-9)

    v = np.cross(d_norm, u)
    v /= (np.linalg.norm(v) + 1e-9)

    # find perpendicular direction given theta
    perp = np.cos(theta) * u + np.sin(theta) * v

    # calculate P1 and P2 from alpha, beta, gamma, and perp (from theta)
    P1 = P0 + alpha * d + beta_mm * perp
    P2 = P0 + gamma * d - beta_mm * perp

    return P1, P2


def optimize_control_points(start_point, end_point):
    """
    for a fixed start/end optimize (alpha, gamma, beta_mm, theta) to get best P1 P2.

    alpha: location of P1 along chord [0, 1]
    gamma: location of P2 along chord [0, 1]
    beta_mm: lateral offset magnitude in mm
    theta: angle (radians) selecting direction in the perp plane
    """
    bounds = [
        (0.1, 0.5), # alpha
        (0.5, 0.9), # gamma
        (0.0, 25.0), # beta_mm (sideways offset)
        (0.0, 2.0 * np.pi) # theta (angle around the axis)
    ]

    result = differential_evolution(
        inner_cp_objective,
        bounds=bounds,
        args=(start_point, end_point),
        maxiter=MAX_P1_P2_OPT_IT,
        tol=P1_P2_OPT_TOL,
        polish=False,
        disp=False
    )

    alpha_opt, gamma_opt, beta_opt, theta_opt = result.x
    P1_opt, P2_opt = control_points_from_params_with_angle(
        start_point, end_point,
        alpha_opt, gamma_opt, beta_opt, theta_opt
    )
    return P1_opt, P2_opt

# %% [markdown]
# ## 2. Monte Carlo Optimization

# %% [markdown]
# ### Path Generation and Optimization

# %% [markdown]
# Generate random paths from brain surface to STN and evaluate them:
# - **Orange lines**: Failed paths (intersect obstacles)
# - **Yellow lines**: Successful but suboptimal paths
# - **Green line**: Optimal path (maximum distance from obstacles)

# %% [markdown]
# **Optimization Algorithm**
#
# Runs until finding a successful path and after a minimum of `min_attempts`.
#
# Chooses a **random location** from the viable brain surface region and the STN of the corresponding hemisphere.
#
# For each plot, the distance from obstacles is saved. The "best" path is determined using the highest distance to obstacles.

# %%
## Config for Monte Carlo
# Monte Carlo path generation parameters
max_attempts = 2000
min_successful_attempts = 100

# Line width configuration (for visualization)
BEST_PATH_WIDTH = 6
SUBOPTIMAL_PATH_WIDTH = 4
FAILED_PATH_WIDTH = 4

# %%
## Run Monte Carlo sampling

successful_attempts = []  # Store (hemisphere, start_point, end_point, obstacle_distance, path_length) tuples
failed_attempts = []      # Store (hemisphere, start_point, end_point, obstacle_distance(=0 for fail), path_length)
failed_lines = []

# Generate and evaluate hemisphere-consistent bezier paths
for attempt in range(max_attempts):
    if len(successful_attempts) >= min_successful_attempts:
        break

    hemi, start_point, end_point = sample_start_and_end()
    print(f"Attempt {attempt+1}: hemisphere={hemi} start={start_point} end={end_point}")

    # Generate control points for cubic bezier curve
    P1, P2 = optimize_control_points(start_point, end_point)
    print("[OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point")
    # Compute path length with curvature constraint
    path_len = compute_bezier_path_length(
        start_point=start_point,
        end_point=end_point,
        control_point1=P1,
        control_point2=P2,
        min_radius_mm=R_MIN_MM,
    )
    
    if path_len is None:  # skip paths that violate curvature (too sharp bend)
        print(f"  Skipping path: violates curvature constraint")
        continue

    # Check for intersection if we have obstacles
    if merged_obstacles:
        if not check_intersection_bezier(start_point, end_point, P1, P2, num_samples=100):
            # Compute metrics
            obstacle_dist = compute_obstacle_distance_bezier(start_point, end_point, P1, P2)
            successful_attempts.append((hemi, start_point, end_point, P1, P2, obstacle_dist, path_len))
            print(f"  SUCCESS ({len(successful_attempts)}/{min_successful_attempts}) - Obstacle Distance: {obstacle_dist:.3f} Path Length: {path_len:.3f}")
        else:
            pts = sample_bezier_points(start_point, P1, P2, end_point, num_samples=100)
            failed_line = Line(pts).c("orange").alpha(0.3).lw(FAILED_PATH_WIDTH)
            failed_lines.append(failed_line)
            failed_attempts.append((hemi, start_point, end_point, P1, P2, 0.0, path_len))
            print("  FAIL - Curve intersects obstacles")
    else:
        obstacle_dist = 0.0
        successful_attempts.append((hemi, start_point, end_point, P1, P2, obstacle_dist, path_len))
        print(f"  SUCCESS (no obstacles) Path Length: {path_len:.3f}")
else:
    print(f"Warning: Only found {len(successful_attempts)} non-intersecting curves after {max_attempts} attempts")
# Out:
# Attempt 1: hemisphere=right start=(np.float64(22.75), np.float64(138.75), np.float64(89.25)) end=(np.float32(106.0), np.float32(130.50978), np.float32(83.73754))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (1/100) - Obstacle Distance: 5.178 Path Length: 83.838
# Attempt 2: hemisphere=right start=(np.float64(22.0), np.float64(136.5), np.float64(92.25)) end=(np.float32(109.14969), np.float32(131.20172), np.float32(83.19796))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (2/100) - Obstacle Distance: 4.929 Path Length: 87.779
# Attempt 3: hemisphere=left start=(np.float64(144.0), np.float64(44.5), np.float64(66.0)) end=(np.float32(107.585), np.float32(129.94904), np.float32(70.415))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 4: hemisphere=left start=(np.float64(172.5), np.float64(118.5), np.float64(13.75)) end=(np.float32(107.45366), np.float32(131.56387), np.float32(74.232475))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (3/100) - Obstacle Distance: 2.385 Path Length: 89.797
# Attempt 5: hemisphere=left start=(np.float64(102.0), np.float64(68.25), np.float64(24.25)) end=(np.float32(107.90232), np.float32(129.47145), np.float32(72.31914))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (4/100) - Obstacle Distance: 2.639 Path Length: 78.566
# Attempt 6: hemisphere=right start=(np.float64(117.0), np.float64(69.75), np.float64(134.75)) end=(np.float32(109.25), np.float32(130.18988), np.float32(85.30019))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (5/100) - Obstacle Distance: 1.825 Path Length: 80.140
# Attempt 7: hemisphere=left start=(np.float64(162.75), np.float64(107.25), np.float64(11.5)) end=(np.float32(106.901344), np.float32(130.45773), np.float32(71.098656))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (6/100) - Obstacle Distance: 4.400 Path Length: 84.910
# Attempt 8: hemisphere=left start=(np.float64(66.75), np.float64(65.53944396972656), np.float64(36.71055603027344)) end=(np.float32(108.58974), np.float32(129.25), np.float32(70.85995))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (7/100) - Obstacle Distance: 3.778 Path Length: 83.521
# Attempt 9: hemisphere=left start=(np.float64(25.75), np.float64(138.0), np.float64(56.25)) end=(np.float32(109.25), np.float32(131.47968), np.float32(71.5575))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (8/100) - Obstacle Distance: 4.078 Path Length: 85.142
# Attempt 10: hemisphere=left start=(np.float64(153.0), np.float64(54.25), np.float64(50.25)) end=(np.float32(106.85508), np.float32(131.97375), np.float32(71.868675))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (9/100) - Obstacle Distance: 2.812 Path Length: 96.317
# Attempt 11: hemisphere=left start=(np.float64(164.25), np.float64(87.0), np.float64(18.25)) end=(np.float32(106.42848), np.float32(129.78746), np.float32(71.60898))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (10/100) - Obstacle Distance: 3.687 Path Length: 89.562
# Attempt 12: hemisphere=right start=(np.float64(48.75), np.float64(94.5), np.float64(128.75)) end=(np.float32(106.790886), np.float32(130.61685), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (11/100) - Obstacle Distance: 3.657 Path Length: 82.817
# Attempt 13: hemisphere=right start=(np.float64(137.25), np.float64(49.75), np.float64(108.75)) end=(np.float32(109.25), np.float32(130.68886), np.float32(84.30018))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 14: hemisphere=right start=(np.float64(24.25), np.float64(142.5), np.float64(90.0)) end=(np.float32(107.70448), np.float32(131.89703), np.float32(85.05745))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (12/100) - Obstacle Distance: 6.858 Path Length: 84.270
# Attempt 15: hemisphere=right start=(np.float64(112.5), np.float64(80.25), np.float64(143.0)) end=(np.float32(109.07358), np.float32(131.05911), np.float32(83.264465))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (13/100) - Obstacle Distance: 2.891 Path Length: 80.354
# Attempt 16: hemisphere=right start=(np.float64(153.75), np.float64(104.25), np.float64(149.0)) end=(np.float32(108.34705), np.float32(130.2374), np.float32(86.262596))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (14/100) - Obstacle Distance: 7.289 Path Length: 81.687
# Attempt 17: hemisphere=left start=(np.float64(25.75), np.float64(138.0), np.float64(56.25)) end=(np.float32(106.21015), np.float32(129.9969), np.float32(73.207054))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (15/100) - Obstacle Distance: 2.273 Path Length: 82.616
# Attempt 18: hemisphere=right start=(np.float64(43.5), np.float64(66.25), np.float64(101.25)) end=(np.float32(108.2989), np.float32(133.25087), np.float32(82.049774))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (16/100) - Obstacle Distance: 1.964 Path Length: 95.712
# Attempt 19: hemisphere=left start=(np.float64(134.0), np.float64(80.25), np.float64(16.0)) end=(np.float32(106.90303), np.float32(129.9438), np.float32(73.4438))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (17/100) - Obstacle Distance: 2.038 Path Length: 81.409
# Attempt 20: hemisphere=left start=(np.float64(19.0), np.float64(94.5), np.float64(57.0)) end=(np.float32(106.0), np.float32(130.77089), np.float32(73.57097))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (18/100) - Obstacle Distance: 2.439 Path Length: 95.823
# Attempt 21: hemisphere=right start=(np.float64(122.6415023803711), np.float64(101.25), np.float64(151.25)) end=(np.float32(106.81164), np.float32(131.55754), np.float32(84.504105))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (19/100) - Obstacle Distance: 6.224 Path Length: 75.127
# Attempt 22: hemisphere=right start=(np.float64(37.439796447753906), np.float64(114.8102035522461), np.float64(125.75)) end=(np.float32(108.322945), np.float32(133.08217), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (20/100) - Obstacle Distance: 4.974 Path Length: 86.156
# Attempt 23: hemisphere=right start=(np.float64(105.5), np.float64(58.75), np.float64(123.0)) end=(np.float32(107.23581), np.float32(132.07259), np.float32(82.08677))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (21/100) - Obstacle Distance: 1.848 Path Length: 86.570
# Attempt 24: hemisphere=right start=(np.float64(63.75), np.float64(129.0), np.float64(140.0)) end=(np.float32(109.25), np.float32(132.36316), np.float32(83.435715))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (22/100) - Obstacle Distance: 5.590 Path Length: 72.671
# Attempt 25: hemisphere=right start=(np.float64(195.5), np.float64(97.5), np.float64(112.5)) end=(np.float32(108.352905), np.float32(130.98558), np.float32(85.91151))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (23/100) - Obstacle Distance: 3.310 Path Length: 101.161
# Attempt 26: hemisphere=left start=(np.float64(106.20072937011719), np.float64(42.25), np.float64(70.04927062988281)) end=(np.float32(109.01562), np.float32(129.53282), np.float32(70.482796))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 27: hemisphere=right start=(np.float64(143.25), np.float64(73.5), np.float64(137.75)) end=(np.float32(107.94336), np.float32(129.39459), np.float32(86.33795))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (24/100) - Obstacle Distance: 3.647 Path Length: 85.369
# Attempt 28: hemisphere=right start=(np.float64(24.25), np.float64(143.25), np.float64(89.25)) end=(np.float32(108.8749), np.float32(130.36603), np.float32(83.75887))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (25/100) - Obstacle Distance: 4.981 Path Length: 85.776
# Attempt 29: hemisphere=left start=(np.float64(162.75), np.float64(61.0), np.float64(43.5)) end=(np.float32(107.69359), np.float32(132.77072), np.float32(73.69359))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (26/100) - Obstacle Distance: 2.469 Path Length: 98.714
# Attempt 30: hemisphere=right start=(np.float64(157.5), np.float64(67.0), np.float64(126.75)) end=(np.float32(108.64349), np.float32(132.36925), np.float32(84.23726))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (27/100) - Obstacle Distance: 2.255 Path Length: 93.835
# Attempt 31: hemisphere=left start=(np.float64(41.25), np.float64(96.75), np.float64(28.75)) end=(np.float32(108.058426), np.float32(132.12721), np.float32(74.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (28/100) - Obstacle Distance: 2.658 Path Length: 88.105
# Attempt 32: hemisphere=right start=(np.float64(55.5), np.float64(75.0), np.float64(121.25)) end=(np.float32(108.788666), np.float32(131.4347), np.float32(85.02664))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (29/100) - Obstacle Distance: 6.596 Path Length: 85.654
# Attempt 33: hemisphere=left start=(np.float64(154.66822814941406), np.float64(100.66822814941406), np.float64(10.75)) end=(np.float32(107.19775), np.float32(131.96118), np.float32(73.986565))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (30/100) - Obstacle Distance: 2.906 Path Length: 85.048
# Attempt 34: hemisphere=left start=(np.float64(83.25), np.float64(95.25), np.float64(12.25)) end=(np.float32(107.231834), np.float32(130.47762), np.float32(70.768166))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (31/100) - Obstacle Distance: 4.604 Path Length: 73.459
# Attempt 35: hemisphere=right start=(np.float64(191.75), np.float64(78.0), np.float64(99.0)) end=(np.float32(108.45838), np.float32(132.10191), np.float32(84.68971))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (32/100) - Obstacle Distance: 4.008 Path Length: 104.834
# Attempt 36: hemisphere=right start=(np.float64(172.5), np.float64(103.5), np.float64(140.0)) end=(np.float32(108.19414), np.float32(129.25), np.float32(86.219475))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (33/100) - Obstacle Distance: 3.528 Path Length: 88.038
# Attempt 37: hemisphere=right start=(np.float64(37.5), np.float64(114.75), np.float64(125.75)) end=(np.float32(108.93979), np.float32(129.43979), np.float32(85.494286))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (34/100) - Obstacle Distance: 6.180 Path Length: 85.023
# Attempt 38: hemisphere=right start=(np.float64(95.25), np.float64(43.0), np.float64(84.75)) end=(np.float32(108.71032), np.float32(131.31195), np.float32(82.64836))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   FAIL - Curve intersects obstacles
# Attempt 39: hemisphere=left start=(np.float64(99.75), np.float64(50.5), np.float64(48.75)) end=(np.float32(106.78334), np.float32(129.53435), np.float32(73.03434))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (35/100) - Obstacle Distance: 2.279 Path Length: 83.860
# Attempt 40: hemisphere=right start=(np.float64(103.5), np.float64(61.75), np.float64(126.75)) end=(np.float32(106.775444), np.float32(132.54762), np.float32(83.47781))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (36/100) - Obstacle Distance: 3.158 Path Length: 85.245
# Attempt 41: hemisphere=right start=(np.float64(20.5), np.float64(134.25), np.float64(95.22388458251953)) end=(np.float32(106.00144), np.float32(130.8296), np.float32(83.67184))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (37/100) - Obstacle Distance: 5.269 Path Length: 86.346
# Attempt 42: hemisphere=right start=(np.float64(22.0), np.float64(137.25), np.float64(89.25)) end=(np.float32(106.65888), np.float32(129.35811), np.float32(83.89189))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (38/100) - Obstacle Distance: 4.809 Path Length: 85.195
# Attempt 43: hemisphere=right start=(np.float64(67.5), np.float64(108.75), np.float64(141.5)) end=(np.float32(109.079994), np.float32(131.85173), np.float32(84.318275))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (39/100) - Obstacle Distance: 6.200 Path Length: 74.380
# Attempt 44: hemisphere=left start=(np.float64(197.75), np.float64(88.73007202148438), np.float64(57.519927978515625)) end=(np.float32(108.326546), np.float32(131.72894), np.float32(74.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (40/100) - Obstacle Distance: 2.295 Path Length: 105.066
# Attempt 45: hemisphere=right start=(np.float64(54.0), np.float64(80.25), np.float64(124.25)) end=(np.float32(107.54326), np.float32(132.95886), np.float32(82.45674))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (41/100) - Obstacle Distance: 5.457 Path Length: 85.975
# Attempt 46: hemisphere=right start=(np.float64(51.0), np.float64(102.0), np.float64(132.5)) end=(np.float32(108.49241), np.float32(129.72424), np.float32(84.018166))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (42/100) - Obstacle Distance: 4.991 Path Length: 80.153
# Attempt 47: hemisphere=right start=(np.float64(191.0), np.float64(97.5), np.float64(120.0)) end=(np.float32(107.03341), np.float32(132.21916), np.float32(84.064255))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 48: hemisphere=right start=(np.float64(130.3687744140625), np.float64(79.5), np.float64(142.25)) end=(np.float32(106.091095), np.float32(131.08997), np.float32(82.408905))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (43/100) - Obstacle Distance: 2.181 Path Length: 85.220
# Attempt 49: hemisphere=left start=(np.float64(29.5), np.float64(72.0), np.float64(65.25)) end=(np.float32(107.5), np.float32(133.20935), np.float32(72.85487))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 50: hemisphere=left start=(np.float64(184.5), np.float64(129.00503540039062), np.float64(19.75)) end=(np.float32(106.11655), np.float32(130.59631), np.float32(72.63345))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (44/100) - Obstacle Distance: 2.862 Path Length: 98.264
# Attempt 51: hemisphere=left start=(np.float64(69.0), np.float64(102.0), np.float64(14.5)) end=(np.float32(109.25), np.float32(131.44162), np.float32(72.80297))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (45/100) - Obstacle Distance: 2.975 Path Length: 76.721
# Attempt 52: hemisphere=right start=(np.float64(77.25), np.float64(105.0), np.float64(144.5)) end=(np.float32(108.74062), np.float32(130.66391), np.float32(83.32671))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (46/100) - Obstacle Distance: 4.738 Path Length: 73.433
# Attempt 53: hemisphere=left start=(np.float64(115.5), np.float64(96.0), np.float64(8.5)) end=(np.float32(108.434166), np.float32(129.52852), np.float32(72.27852))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (47/100) - Obstacle Distance: 2.583 Path Length: 73.014
# Attempt 54: hemisphere=left start=(np.float64(83.25), np.float64(93.0), np.float64(13.0)) end=(np.float32(107.245155), np.float32(132.40067), np.float32(73.59449))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (48/100) - Obstacle Distance: 3.396 Path Length: 76.352
# Attempt 55: hemisphere=left start=(np.float64(84.0), np.float64(87.75), np.float64(15.25)) end=(np.float32(108.14173), np.float32(132.88893), np.float32(72.25))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (49/100) - Obstacle Distance: 4.161 Path Length: 78.608
# Attempt 56: hemisphere=left start=(np.float64(183.37500190734863), np.float64(88.5), np.float64(32.87500190734863)) end=(np.float32(109.25), np.float32(129.79128), np.float32(70.777336))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (50/100) - Obstacle Distance: 4.029 Path Length: 93.737
# Attempt 57: hemisphere=left start=(np.float64(120.93199157714844), np.float64(54.25), np.float64(41.25)) end=(np.float32(109.25), np.float32(130.04448), np.float32(71.916016))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (51/100) - Obstacle Distance: 3.073 Path Length: 84.336
# Attempt 58: hemisphere=right start=(np.float64(194.0), np.float64(90.75), np.float64(109.5)) end=(np.float32(108.89849), np.float32(133.10152), np.float32(82.746475))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (52/100) - Obstacle Distance: 4.189 Path Length: 102.783
# Attempt 59: hemisphere=right start=(np.float64(24.25), np.float64(142.5), np.float64(90.0)) end=(np.float32(107.64598), np.float32(133.64598), np.float32(83.16238))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (53/100) - Obstacle Distance: 6.352 Path Length: 84.143
# Attempt 60: hemisphere=left start=(np.float64(91.43381881713867), np.float64(44.5), np.float64(68.31618118286133)) end=(np.float32(109.25), np.float32(130.53595), np.float32(72.09299))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 61: hemisphere=right start=(np.float64(104.25), np.float64(53.5), np.float64(115.5)) end=(np.float32(106.306114), np.float32(131.55612), np.float32(82.71341))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (54/100) - Obstacle Distance: 2.517 Path Length: 86.735
# Attempt 62: hemisphere=right start=(np.float64(51.0), np.float64(122.72914123535156), np.float64(134.75)) end=(np.float32(107.77682), np.float32(129.25), np.float32(85.82588))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (55/100) - Obstacle Distance: 6.651 Path Length: 75.231
# Attempt 63: hemisphere=left start=(np.float64(207.5), np.float64(102.0), np.float64(72.0)) end=(np.float32(106.15249), np.float32(130.0951), np.float32(73.24759))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (56/100) - Obstacle Distance: 2.282 Path Length: 105.489
# Attempt 64: hemisphere=right start=(np.float64(57.75), np.float64(112.5), np.float64(137.75)) end=(np.float32(107.96118), np.float32(129.633), np.float32(86.59418))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (57/100) - Obstacle Distance: 7.473 Path Length: 73.700
# Attempt 65: hemisphere=right start=(np.float64(82.5), np.float64(52.0), np.float64(105.0)) end=(np.float32(107.45015), np.float32(131.01399), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (58/100) - Obstacle Distance: 1.996 Path Length: 86.900
# Attempt 66: hemisphere=left start=(np.float64(203.75), np.float64(90.75), np.float64(83.25)) end=(np.float32(108.1401), np.float32(130.10794), np.float32(70.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (59/100) - Obstacle Distance: 4.472 Path Length: 109.078
# Attempt 67: hemisphere=left start=(np.float64(88.5), np.float64(75.0), np.float64(21.25)) end=(np.float32(107.95654), np.float32(130.52994), np.float32(70.073395))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (60/100) - Obstacle Distance: 5.042 Path Length: 77.214
# Attempt 68: hemisphere=right start=(np.float64(69.0), np.float64(81.0), np.float64(132.5)) end=(np.float32(108.32135), np.float32(133.24309), np.float32(83.68556))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (61/100) - Obstacle Distance: 3.296 Path Length: 83.965
# Attempt 69: hemisphere=left start=(np.float64(86.27872848510742), np.float64(46.0), np.float64(65.97127151489258)) end=(np.float32(106.085686), np.float32(130.43715), np.float32(73.522835))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 70: hemisphere=right start=(np.float64(181.62500381469727), np.float64(67.12500381469727), np.float64(102.0)) end=(np.float32(107.5531), np.float32(133.07161), np.float32(82.4469))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (62/100) - Obstacle Distance: 1.349 Path Length: 102.991
# Attempt 71: hemisphere=left start=(np.float64(204.5), np.float64(126.9280014038086), np.float64(39.75)) end=(np.float32(108.40907), np.float32(131.31615), np.float32(74.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 72: hemisphere=right start=(np.float64(69.24493408203125), np.float64(92.75506591796875), np.float64(138.5)) end=(np.float32(108.72282), np.float32(132.27637), np.float32(84.25082))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (63/100) - Obstacle Distance: 6.329 Path Length: 77.898
# Attempt 73: hemisphere=left start=(np.float64(66.74811935424805), np.float64(51.25), np.float64(60.75188064575195)) end=(np.float32(108.71545), np.float32(129.58127), np.float32(70.16874))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (64/100) - Obstacle Distance: 1.805 Path Length: 91.648
# Attempt 74: hemisphere=right start=(np.float64(37.81291580200195), np.float64(96.0), np.float64(120.81291580200195)) end=(np.float32(108.48044), np.float32(129.25), np.float32(84.67657))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (65/100) - Obstacle Distance: 5.518 Path Length: 86.057
# Attempt 75: hemisphere=left start=(np.float64(127.5), np.float64(53.5), np.float64(43.5)) end=(np.float32(107.738266), np.float32(132.15244), np.float32(71.652435))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (66/100) - Obstacle Distance: 4.435 Path Length: 88.469
# Attempt 76: hemisphere=left start=(np.float64(209.0), np.float64(104.25), np.float64(83.25)) end=(np.float32(107.84213), np.float32(129.70787), np.float32(72.61573))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (67/100) - Obstacle Distance: 2.546 Path Length: 108.147
# Attempt 77: hemisphere=left start=(np.float64(42.0), np.float64(114.75), np.float64(22.75)) end=(np.float32(106.581764), np.float32(131.46794), np.float32(72.386185))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (68/100) - Obstacle Distance: 3.780 Path Length: 83.151
# Attempt 78: hemisphere=left start=(np.float64(210.5), np.float64(150.75), np.float64(76.5)) end=(np.float32(107.20178), np.float32(130.88986), np.float32(70.79822))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (69/100) - Obstacle Distance: 4.803 Path Length: 108.657
# Attempt 79: hemisphere=left start=(np.float64(84.75), np.float64(64.50924110412598), np.float64(30.990758895874023)) end=(np.float32(106.69021), np.float32(129.25), np.float32(72.704254))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (70/100) - Obstacle Distance: 2.507 Path Length: 80.230
# Attempt 80: hemisphere=right start=(np.float64(57.75), np.float64(64.75), np.float64(111.0)) end=(np.float32(109.25), np.float32(131.57321), np.float32(84.13849))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (71/100) - Obstacle Distance: 5.911 Path Length: 88.647
# Attempt 81: hemisphere=left start=(np.float64(39.75), np.float64(102.75), np.float64(26.5)) end=(np.float32(109.25), np.float32(131.39209), np.float32(73.32738))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (72/100) - Obstacle Distance: 2.528 Path Length: 88.563
# Attempt 82: hemisphere=right start=(np.float64(153.75), np.float64(67.75), np.float64(129.75)) end=(np.float32(106.556244), np.float32(130.97299), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (73/100) - Obstacle Distance: 3.818 Path Length: 93.200
# Attempt 83: hemisphere=right start=(np.float64(132.5), np.float64(111.75), np.float64(152.75)) end=(np.float32(108.60361), np.float32(131.89902), np.float32(84.74738))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (74/100) - Obstacle Distance: 6.598 Path Length: 74.842
# Attempt 84: hemisphere=right start=(np.float64(57.75), np.float64(97.5), np.float64(134.75)) end=(np.float32(106.0), np.float32(130.1264), np.float32(83.8911))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (75/100) - Obstacle Distance: 5.160 Path Length: 77.611
# Attempt 85: hemisphere=left start=(np.float64(138.0), np.float64(75.75), np.float64(19.0)) end=(np.float32(107.49807), np.float32(130.13234), np.float32(70.50193))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (76/100) - Obstacle Distance: 3.866 Path Length: 82.026
# Attempt 86: hemisphere=right start=(np.float64(107.25), np.float64(75.75), np.float64(139.25)) end=(np.float32(107.13295), np.float32(129.54482), np.float32(85.677765))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (77/100) - Obstacle Distance: 4.955 Path Length: 77.609
# Attempt 87: hemisphere=right start=(np.float64(99.0), np.float64(57.25), np.float64(120.0)) end=(np.float32(108.252975), np.float32(131.00095), np.float32(85.996086))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (78/100) - Obstacle Distance: 4.301 Path Length: 83.674
# Attempt 88: hemisphere=right start=(np.float64(40.57186381022135), np.float64(75.08014551798503), np.float64(111.65200932820638)) end=(np.float32(108.19058), np.float32(132.46593), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (79/100) - Obstacle Distance: 4.620 Path Length: 93.532
# Attempt 89: hemisphere=left start=(np.float64(206.0), np.float64(126.0), np.float64(42.0)) end=(np.float32(106.97723), np.float32(129.54527), np.float32(73.04528))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 90: hemisphere=left start=(np.float64(56.25), np.float64(59.5), np.float64(50.25)) end=(np.float32(109.25), np.float32(131.17758), np.float32(72.28505))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (80/100) - Obstacle Distance: 2.057 Path Length: 91.892
# Attempt 91: hemisphere=left start=(np.float64(47.87678146362305), np.float64(92.37321853637695), np.float64(26.5)) end=(np.float32(106.0), np.float32(130.89546), np.float32(73.44298))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (81/100) - Obstacle Distance: 2.618 Path Length: 84.059
# Attempt 92: hemisphere=right start=(np.float64(206.0), np.float64(113.58356475830078), np.float64(103.83356475830078)) end=(np.float32(108.18164), np.float32(132.52252), np.float32(84.54583))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (82/100) - Obstacle Distance: 4.895 Path Length: 102.404
# Attempt 93: hemisphere=right start=(np.float64(185.25), np.float64(117.0), np.float64(131.75)) end=(np.float32(108.95244), np.float32(131.54317), np.float32(82.65926))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 94: hemisphere=right start=(np.float64(90.0), np.float64(50.5), np.float64(105.75)) end=(np.float32(106.61539), np.float32(131.82837), np.float32(83.28702))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (83/100) - Obstacle Distance: 2.382 Path Length: 87.810
# Attempt 95: hemisphere=left start=(np.float64(85.37261581420898), np.float64(114.87738418579102), np.float64(7.75)) end=(np.float32(109.25), np.float32(131.68707), np.float32(72.43537))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (84/100) - Obstacle Distance: 3.417 Path Length: 70.971
# Attempt 96: hemisphere=right start=(np.float64(48.75), np.float64(94.5), np.float64(128.75)) end=(np.float32(107.8049), np.float32(129.25), np.float32(84.21428))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (85/100) - Obstacle Distance: 5.064 Path Length: 81.756
# Attempt 97: hemisphere=left start=(np.float64(110.25), np.float64(54.25), np.float64(41.25)) end=(np.float32(107.23968), np.float32(132.05232), np.float32(71.562645))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (86/100) - Obstacle Distance: 3.812 Path Length: 85.718
# Attempt 98: hemisphere=right start=(np.float64(186.0), np.float64(126.75), np.float64(132.5)) end=(np.float32(107.660706), np.float32(131.8463), np.float32(82.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 99: hemisphere=left start=(np.float64(208.25), np.float64(105.0), np.float64(70.5)) end=(np.float32(109.25), np.float32(130.8159), np.float32(71.667534))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (87/100) - Obstacle Distance: 3.738 Path Length: 103.507
# Attempt 100: hemisphere=left start=(np.float64(135.0), np.float64(42.25), np.float64(90.75)) end=(np.float32(106.43218), np.float32(130.0136), np.float32(73.445786))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 101: hemisphere=left start=(np.float64(127.9002456665039), np.float64(63.45439147949219), np.float64(29.045608520507812)) end=(np.float32(107.687164), np.float32(131.81364), np.float32(74.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (88/100) - Obstacle Distance: 2.573 Path Length: 84.801
# Attempt 102: hemisphere=left start=(np.float64(126.0), np.float64(69.0), np.float64(24.25)) end=(np.float32(106.09753), np.float32(130.78506), np.float32(73.8826))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (89/100) - Obstacle Distance: 2.229 Path Length: 81.782
# Attempt 103: hemisphere=left start=(np.float64(51.0), np.float64(108.75), np.float64(19.75)) end=(np.float32(107.27138), np.float32(130.89224), np.float32(74.37087))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (90/100) - Obstacle Distance: 1.960 Path Length: 81.487
# Attempt 104: hemisphere=right start=(np.float64(132.0), np.float64(75.0), np.float64(139.25)) end=(np.float32(107.45399), np.float32(131.51796), np.float32(85.186035))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (91/100) - Obstacle Distance: 3.082 Path Length: 84.176
# Attempt 105: hemisphere=right start=(np.float64(129.75), np.float64(83.25), np.float64(144.5)) end=(np.float32(108.42375), np.float32(129.25), np.float32(85.32064))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (92/100) - Obstacle Distance: 3.400 Path Length: 79.883
# Attempt 106: hemisphere=left start=(np.float64(120.10234069824219), np.float64(46.0), np.float64(57.0)) end=(np.float32(106.75084), np.float32(131.97041), np.float32(71.96957))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 107: hemisphere=left start=(np.float64(180.80532836914062), np.float64(70.80532836914062), np.float64(48.75)) end=(np.float32(107.45465), np.float32(129.87755), np.float32(73.17289))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 108: hemisphere=left start=(np.float64(96.75), np.float64(49.0), np.float64(52.5)) end=(np.float32(109.25), np.float32(131.41843), np.float32(73.19901))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 109: hemisphere=right start=(np.float64(24.25), np.float64(143.09727478027344), np.float64(89.40272521972656)) end=(np.float32(108.29108), np.float32(132.56651), np.float32(84.39241))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (93/100) - Obstacle Distance: 6.642 Path Length: 84.846
# Attempt 110: hemisphere=left start=(np.float64(82.5), np.float64(67.93087959289551), np.float64(28.319120407104492)) end=(np.float32(108.78889), np.float32(129.28888), np.float32(71.29252))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (94/100) - Obstacle Distance: 3.372 Path Length: 79.874
# Attempt 111: hemisphere=right start=(np.float64(152.25), np.float64(77.25), np.float64(139.25)) end=(np.float32(107.5), np.float32(132.80693), np.float32(82.534256))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (95/100) - Obstacle Distance: 3.310 Path Length: 93.909
# Attempt 112: hemisphere=left start=(np.float64(179.25), np.float64(116.25), np.float64(17.5)) end=(np.float32(107.5), np.float32(133.32104), np.float32(73.215706))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (96/100) - Obstacle Distance: 4.173 Path Length: 93.953
# Attempt 113: hemisphere=left start=(np.float64(88.5), np.float64(44.5), np.float64(73.5)) end=(np.float32(108.391464), np.float32(130.96243), np.float32(74.0))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 114: hemisphere=left start=(np.float64(197.0), np.float64(90.0), np.float64(54.75)) end=(np.float32(106.32229), np.float32(129.89459), np.float32(71.82231))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 115: hemisphere=left start=(np.float64(91.5), np.float64(61.0), np.float64(33.0)) end=(np.float32(107.21218), np.float32(129.88127), np.float32(73.38127))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (97/100) - Obstacle Distance: 2.066 Path Length: 81.377
# Attempt 116: hemisphere=right start=(np.float64(181.6271743774414), np.float64(67.1271743774414), np.float64(102.0)) end=(np.float32(107.831985), np.float32(133.64346), np.float32(82.31148))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (98/100) - Obstacle Distance: 1.404 Path Length: 102.991
# Attempt 117: hemisphere=left start=(np.float64(79.14000701904297), np.float64(46.75), np.float64(69.35999298095703)) end=(np.float32(109.193924), np.float32(131.59688), np.float32(73.556076))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   Skipping path: violates curvature constraint
# Attempt 118: hemisphere=left start=(np.float64(48.676979064941406), np.float64(90.0730209350586), np.float64(27.25)) end=(np.float32(108.668175), np.float32(129.25), np.float32(71.469345))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (99/100) - Obstacle Distance: 3.192 Path Length: 84.378
# Attempt 119: hemisphere=right start=(np.float64(129.75), np.float64(83.25), np.float64(144.5)) end=(np.float32(108.04585), np.float32(133.26169), np.float32(83.94246))
# [OPTIMIZE] Obtained optimal P1, P2 for startpoint and end point
#   SUCCESS (100/100) - Obstacle Distance: 4.415 Path Length: 83.695

# %% [markdown]
# ### Select Optimal Path
#
# Find the best path among successful attempts by maximizing distance from obstacles.

# %%
# Select best path (maximum obstacle distance; tie-breaker shorter path length)
SUBOPTIMAL_PATHS_TO_DISPLAY = 10

best_path = None
suboptimal_lines = []
selected_hemisphere = None

if successful_attempts:
    # Sort: first by obstacle distance desc, then by path length asc
    successful_attempts.sort(key=lambda x: (-x[5], x[6]))

    best_hemi, best_start, best_end, best_P1, best_P2, best_obstacle_dist, best_path_len = successful_attempts[0]
    best_pts = sample_bezier_points(best_start, best_P1, best_P2, best_end, num_samples=100)
    best_path = Line(best_pts).c("green").lw(BEST_PATH_WIDTH)
    selected_hemisphere = best_hemi
    print(f"\nBest path: hemisphere={best_hemi} obstacle_dist={best_obstacle_dist:.3f} path_len={best_path_len:.3f}")

    s = 1
    for hemi, start_pt, end_pt, P1, P2, obstacle_dist, path_len in successful_attempts[1:]:
        if s > SUBOPTIMAL_PATHS_TO_DISPLAY:
            break
        
        pts = sample_bezier_points(start_pt, P1, P2, end_pt, num_samples=100)
        suboptimal_line = Line(pts).c("yellow").alpha(0.3).lw(SUBOPTIMAL_PATH_WIDTH)
        suboptimal_lines.append(suboptimal_line)
        print(f"Suboptimal path {s}: hemi={hemi} obstacle_dist={obstacle_dist:.3f} path_len={path_len:.3f}")
        
        s += 1
else:
    print("No successful paths found!")

print("\nTotal successful paths: ", len(successful_attempts))
# Out:
# Best path: hemisphere=right obstacle_dist=7.473 path_len=73.700
# Suboptimal path 1: hemi=right obstacle_dist=7.289 path_len=81.687
# Suboptimal path 2: hemi=right obstacle_dist=6.858 path_len=84.270
# Suboptimal path 3: hemi=right obstacle_dist=6.651 path_len=75.231
# Suboptimal path 4: hemi=right obstacle_dist=6.642 path_len=84.846
# Suboptimal path 5: hemi=right obstacle_dist=6.598 path_len=74.842
# Suboptimal path 6: hemi=right obstacle_dist=6.596 path_len=85.654
# Suboptimal path 7: hemi=right obstacle_dist=6.352 path_len=84.143
# Suboptimal path 8: hemi=right obstacle_dist=6.329 path_len=77.898
# Suboptimal path 9: hemi=right obstacle_dist=6.224 path_len=75.127
# Suboptimal path 10: hemi=right obstacle_dist=6.200 path_len=74.380
#
# Total successful paths:  100

# %%
## Save Monte Carlo bezier path coordinates to file (success + fail + best flag)
output_file = "monte_carlo_bezier_paths.csv"
with open(output_file, 'w') as f:
    f.write("hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,p1_x,p1_y,p1_z,p2_x,p2_y,p2_z,obstacle_distance,path_length,status,is_best\n")
    # Successful attempts are already sorted (best first) after selection step
    for idx, (hemi, start_pt, end_pt, P1, P2, obstacle_dist, path_len) in enumerate(successful_attempts):
        is_best = 1 if idx == 0 else 0
        f.write(
            f"{hemi},{start_pt[0]},{start_pt[1]},{start_pt[2]},{end_pt[0]},{end_pt[1]},{end_pt[2]},{P1[0]},{P1[1]},{P1[2]},{P2[0]},{P2[1]},{P2[2]},{obstacle_dist},{path_len},success,{is_best}\n"
        )
    # Failed attempts
    for hemi, start_pt, end_pt, P1, P2, obstacle_dist, path_len in failed_attempts:
        f.write(
            f"{hemi},{start_pt[0]},{start_pt[1]},{start_pt[2]},{end_pt[0]},{end_pt[1]},{end_pt[2]},{P1[0]},{P1[1]},{P1[2]},{P2[0]},{P2[1]},{P2[2]},{obstacle_dist},{path_len},fail,0\n"
        )
print(f"Saved Monte Carlo bezier paths ({len(successful_attempts)} success, {len(failed_attempts)} fail) to {output_file}")
# Out:
# Saved Monte Carlo bezier paths (100 success, 1 fail) to monte_carlo_bezier_paths.csv

# %% [markdown]
# ## 3. Weighted Sum + Mono-Criteria Optimization

# %% [markdown]
# ### Configuration
#
# Set weights and optimization parameters:
# - `w_obstacle`: Weight for obstacle distance (maximize)
# - `w_path_length`: Weight for path length (minimize)
# - Weights are normalized automatically

# %%
# Weights for multi-objective optimization (easily configurable)
w_obstacle = 0.9     # Weight for obstacle distance (higher = prefer safer paths)
w_path_length = 0.1   # Weight for path length (higher = prefer shorter paths)

# Normalize weights to sum to 1
total_weight = w_obstacle + w_path_length
w_obstacle_norm = w_obstacle / total_weight
w_path_length_norm = w_path_length / total_weight

print(f"Objective function weights:\n  Obstacle distance: {w_obstacle_norm:.3f}\n  Path length: {w_path_length_norm:.3f}")

# Mono-criteria optimization parameters
initial_point_attempts = 50
opt_max_iterations = 20
opt_tolerance = 1e-6  # default: 1e-6, applied as xatol and fatol

# Hemisphere lock for optimization (set later when picking x0)
opt_hemisphere = None

# Number of best Monte Carlo paths to use as initial conditions
n_initial = 5
# Out:
# Objective function weights:
#   Obstacle distance: 0.900
#   Path length: 0.100

# %% [markdown]
# ### Weighted Sum Objective Function
#
# Combines both objectives (obstacle distance and path length) into a single scalar value for optimization.

# %%
# with P1P2 optimization

max_obstacle_dist = None
max_path_length = None

last_eval = {
    "x": None,
    "start": None,
    "end": None,
    "P1": None,
    "P2": None,
    "path_points": None,
    "objective": None,
}

all_evals = []

def weighted_sum_objective(x):
    """
    Weighted sum objective function for optimization (cubic Bézier).
    For each candidate start/end, first optimizes P1/P2 (curve shape),
    then evaluates the global objective.
    """
    global opt_hemisphere, last_eval, all_evals

    start_guess = tuple(x[:3])
    end_guess   = tuple(x[3:])

    if opt_hemisphere is None:
        opt_hemisphere = 'left' if merged_left_entry_zone and merged_left_stn else 'right'

    start_point, end_point = project_to_surfaces(start_guess, end_guess, opt_hemisphere)

    P1, P2 = optimize_control_points(start_point, end_point)

    path_length = compute_bezier_path_length(
        start_point=start_point,
        end_point=end_point,
        control_point1=P1,
        control_point2=P2,
        min_radius_mm=R_MIN_MM,
    )
    if path_length is None:
        return 1e10

    if check_intersection_bezier(start_point, end_point, P1, P2):
        return 1e10

    obstacle_dist = compute_obstacle_distance_bezier(start_point, end_point, P1, P2)

    if max_obstacle_dist is not None and max_obstacle_dist > 0:
        norm_obstacle_dist = obstacle_dist / max_obstacle_dist
    else:
        norm_obstacle_dist = obstacle_dist / 8

    if max_path_length is not None and max_path_length > 0:
        norm_path_length = path_length / max_path_length
    else:
        norm_path_length = path_length / 105

    objective = -w_obstacle_norm * norm_obstacle_dist + w_path_length_norm * norm_path_length

    path_points = sample_bezier_points(start_point, P1, P2, end_point, num_samples=NUM_SAMPLE)

    last_eval = {
        "x": x.copy(),
        "start": start_point,
        "end": end_point,
        "P1": P1,
        "P2": P2,
        "path_points": path_points,
        "objective": objective,
    }
    all_evals.append(last_eval.copy())

    return objective

# %% [markdown]
# ### Estimate Normalization Constants
#
# Sample a few random paths to estimate typical ranges for obstacle distance and path length.

# %%
# ## Option 1: Sample random paths to estimate normalization constants
# ESTIMATION_SAMPLES = 100

# print("Estimating normalization constants from random samples...")
# sample_obstacle_dists = []
# sample_path_lengths = []

# for _ in range(ESTIMATION_SAMPLES):
#     print(f"Sampling path {_+1}/{ESTIMATION_SAMPLES}...")
#     hemi, start, end = sample_start_and_end()
#     if not check_intersection(start, end):
#         obstacle_dist = compute_obstacle_distance(start, end)
#         path_length = compute_path_length(start, end)
#         sample_obstacle_dists.append(obstacle_dist)
#         sample_path_lengths.append(path_length)
#         # print(f"  obstacle_dist={obstacle_dist:.3f} path_len={path_length:.3f}")
#     else:
#         print("  Sampled path intersects obstacles, skipping...")

# if sample_obstacle_dists:
#     max_obstacle_dist = max(sample_obstacle_dists)
#     max_path_length = max(sample_path_lengths)
#     print(f"Estimated max obstacle distance: {max_obstacle_dist:.2f}")
#     print(f"Estimated max path length: {max_path_length:.2f}")
# else:
#     print("Warning: No valid paths found for normalization, using defaults")
#     max_obstacle_dist = 8
#     max_path_length = 100

# %%
# ## OPTION 2: Use Monte Carlo results for normalization (if available)
# if successful_attempts:
#     print("\nUsing Monte Carlo results for normalization...")
#     mc_obstacle_dists = [x[5] for x in successful_attempts]  # obstacle_dist is at index 5 for bezier
#     mc_path_lengths = [x[6] for x in successful_attempts]    # path_length is at index 6 for bezier
#     max_obstacle_dist = max(mc_obstacle_dists)
#     max_path_length = max(mc_path_lengths)
#     print(f"Max obstacle distance from Monte Carlo: {max_obstacle_dist:.2f}")
#     print(f"Max path length from Monte Carlo: {max_path_length:.2f}")
# else:
#     print("\nNo Monte Carlo results available for normalization, using defaults")
#     max_obstacle_dist = 8
#     max_path_length = 105

# %%
## Option 3: Set Manually
max_obstacle_dist = 8
max_path_length = 105

# %% [markdown]
# ### Set Initial Path for Optimization

# %%
# ## OPTION 1: Find first feasible initial point from random sampling
# print("\nFinding feasible initial point...")
# x0 = None
# for attempt in range(initial_point_attempts):
#     hemi, start, end = sample_start_and_end()
#     if not check_intersection(start, end):
#         x0 = np.concatenate([start, end])
#         opt_hemisphere = hemi  # lock hemisphere for optimization
#         print(f"Found feasible starting point after {attempt+1} attempts (hemi={hemi})")
#         print(f"  Start: {start}")
#         print(f"  End: {end}")
#         break

# if x0 is None:
#     print("Warning: Could not find feasible starting point, using last sampled anyway")
#     hemi, start, end = sample_start_and_end()
#     x0 = np.concatenate([start, end])
#     opt_hemisphere = hemi

# %%
## OPTION 2: Select best Monte Carlo path as starting point(s)
if successful_attempts:
    print("\nSelecting initial conditions from best Monte Carlo paths...")
    # successful_attempts is already sorted earlier (best first)
    take = min(n_initial, len(successful_attempts))
    initial_paths = successful_attempts[:take]
    
    print(f"  Using {take} initial path(s) from Monte Carlo results")
    
    # Ensure initial_paths are not all from the same hemisphere
    hemis = [h for h, *_ in initial_paths[:take]]
    
    if len(set(hemis)) == 1:
        target_hemi = 'left' if hemis[0] == 'right' else 'right'
        print(f"  Detected single-hemisphere initials ({hemis[0]}). Picking one from {target_hemi} hemi in successful_attempts...")

        # Find first successful attempt from the opposite hemisphere beyond the first 'take'
        replacement = next((rec for rec in successful_attempts[take:] if rec[0] == target_hemi), None)

        if replacement:
            initial_paths[-1] = replacement
            print("  Replaced one initial path with other-hemisphere entry from successful_attempts.")
        else:
            print("  Warning: No other-hemisphere entry found in successful_attempts; keeping originals.")
    # Update selected hemisphere preview from the first initial path
    selected_hemisphere = initial_paths[0][0]
else:
    raise RuntimeError("No successful Monte Carlo paths available for optimization initialization.")
# Out:
# Selecting initial conditions from best Monte Carlo paths...
#   Using 5 initial path(s) from Monte Carlo results
#   Detected single-hemisphere initials (right). Picking one from left hemi in successful_attempts...
#   Replaced one initial path with other-hemisphere entry from successful_attempts.

# %% [markdown]
# ### Mono-criteria optimization function

# %%
import time

def run_multistart_bezier(method_name, options):
    """Run chosen optimization method over all initial_paths and return best record.
    
    Updated for Bezier curves with control point optimization.

    Returns:
      best_record, records_list
    Prints per-start info plus total elapsed time and summed iterations across starts.
    """
    if not initial_paths:
        raise RuntimeError("initial_paths is empty. Ensure Monte Carlo step ran and initial paths were selected.")

    best = None
    records = []
    total_time = 0.0
    total_iterations = 0

    for idx, (hemi, start, end, P1_init, P2_init, obst, plen) in enumerate(initial_paths, start=1):
        print(f"\n[{method_name} {idx}/{len(initial_paths)}] hemi={hemi}")
        global opt_hemisphere
        opt_hemisphere = hemi  # hemisphere locking
        x0 = np.concatenate([start, end])
        t0 = time.perf_counter()
        
        res = minimize(weighted_sum_objective, x0, method=method_name, options=options)
        
        elapsed = time.perf_counter() - t0
        iters = getattr(res, 'nit', getattr(res, 'nfev', 0)) or 0
        total_time += elapsed
        total_iterations += iters

        raw_start = tuple(res.x[:3])
        raw_end = tuple(res.x[3:])
        opt_start, opt_end = project_to_surfaces(raw_start, raw_end, opt_hemisphere)
        opt_obj = float(res.fun)
        
        # Optimize control points for the final path
        P1_opt, P2_opt = optimize_control_points(opt_start, opt_end)
        
        # Compute bezier metrics
        opt_obst = compute_obstacle_distance_bezier(opt_start, opt_end, P1_opt, P2_opt)
        opt_len = compute_bezier_path_length(opt_start, opt_end, P1_opt, P2_opt, min_radius_mm=R_MIN_MM)
        
        # Create bezier curve for visualization
        path_points = sample_bezier_points(opt_start, P1_opt, P2_opt, opt_end, num_samples=NUM_SAMPLE)
        if method_name == 'Nelder-Mead':
            opt_line = Line(path_points).c("cyan").lw(10)
        elif method_name == 'Powell':
            opt_line = Line(path_points).c("magenta").lw(10)
        elif method_name == 'COBYLA':
            opt_line = Line(path_points).c("blue").lw(10)
        else:
            opt_line = Line(path_points).c("purple").lw(10)

        rec = {
            'method': method_name,
            'hemi': hemi,
            'start': opt_start,
            'end': opt_end,
            'P1': P1_opt,
            'P2': P2_opt,
            'objective': opt_obj,
            'obstacle_distance': opt_obst,
            'path_length': opt_len,
            'line': opt_line,
            'path_points': path_points,
            'result': res,
            'elapsed': elapsed,
            'iterations': iters
        }
        records.append(rec)
        if best is None or opt_obj < best['objective']:
            best = rec
        print(f"  Objective: {opt_obj:.6f}  ObstDist: {opt_obst:.3f}  PathLen: {opt_len:.3f}")
        print(f"  Elapsed: {elapsed:.3f}s  Iterations: {iters}")

    print(f"\n[{method_name} Summary] Total time: {total_time:.3f}s  Total iterations: {total_iterations}")
    return best, records

# %% [markdown]
# ### Pareto Front Optimization (Bezier)

# %%
# Set weight combinations for Pareto sweep (Bezier)
weights = [
    {"w_obstacle": 0.95, "w_path_length": 0.05},
    {"w_obstacle": 0.90, "w_path_length": 0.10},
    {"w_obstacle": 0.85, "w_path_length": 0.15},
    {"w_obstacle": 0.80, "w_path_length": 0.20},
    {"w_obstacle": 0.75, "w_path_length": 0.25},
    {"w_obstacle": 0.70, "w_path_length": 0.30},
]

# Storage for Pareto-optimal results (Bezier)
pareto_results = []  # list of dicts with method, weights, hemisphere, start, end, P1, P2, metrics
pareto_lines = []    # list of vedo.Line for plotting

# %%
# Keep single-method optimization above for comparison, but Pareto will use opt_method
opt_method = 'COBYLA'

# %%
for w in weights:
    # Weights for multi-objective optimization
    w_obstacle = w["w_obstacle"]
    w_path_length = w["w_path_length"]
    
    # Normalize weights to sum to 1
    total_weight = w_obstacle + w_path_length
    w_obstacle_norm = w_obstacle / total_weight
    w_path_length_norm = w_path_length / total_weight
    
    if any(abs(r['w_obstacle']-w_obstacle_norm)<1e-9 and abs(r['w_path_length']-w_path_length_norm)<1e-9 for r in pareto_results):
        print(f"\nSkipping weights w_obstacle={w_obstacle_norm:.2f}, w_path_length={w_path_length_norm:.2f} (already computed)")
        continue
    
    print(f"Bezier Objective weights:\n  Obstacle distance: {w_obstacle_norm:.3f}\n  Path length: {w_path_length_norm:.3f}")
    
    print(f"\nRunning {opt_method} Bezier optimization over {len(initial_paths)} initial path(s)...")
    best_run, all_records = run_multistart_bezier(opt_method, {
        'maxiter': opt_max_iterations,
        'tol': opt_tolerance,
        'disp': True
    })
    
    hemi = best_run['hemi']
    opt_start = best_run['start']
    opt_end = best_run['end']
    P1_opt = best_run['P1']
    P2_opt = best_run['P2']
    opt_objective = best_run['objective']
    opt_obst = best_run['obstacle_distance']
    opt_len = best_run['path_length']
    opt_line = best_run['line']
    
    pareto_entry = {
        'method': opt_method,
        'w_obstacle': w_obstacle_norm,
        'w_path_length': w_path_length_norm,
        'hemisphere': hemi,
        'start': opt_start,
        'end': opt_end,
        'P1': P1_opt,
        'P2': P2_opt,
        'weighted_objective': opt_objective,
        'obstacle_distance': opt_obst,
        'path_length': opt_len
    }
    pareto_results.append(pareto_entry)
    pareto_lines.append(opt_line)
    
    print(f"\n{'='*60}")
    print(f"Best {opt_method} Bezier run for weights w_obstacle={w_obstacle:.2f}, w_path_length={w_path_length:.2f}:")
    print(f"  Hemisphere: {hemi}")
    print(f"  Objective: {opt_objective:.6f}")
    print(f"  Obstacle distance: {opt_obst:.3f}")
    print(f"  Path length: {opt_len:.3f}")
    print(f"  Start: {opt_start}")
    print(f"  End:   {opt_end}")
    print(f"  P1:    {P1_opt}")
    print(f"  P2:    {P2_opt}")
    
pareto_results.sort(key=lambda x: x['w_obstacle'], reverse=True)
# Out:
# Bezier Objective weights:
#   Obstacle distance: 0.950
#   Path length: 0.050
#
# Running COBYLA Bezier optimization over 5 initial path(s)...
#
# [COBYLA 1/5] hemi=right
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 20   Least value of F = -0.8728606429256905
# The corresponding X is:
# [ 57.75       112.5        137.74999999 107.96580268 128.55170928
#   88.50565875]
#
#   Objective: -0.872861  ObstDist: 7.649  PathLen: 74.345
#   Elapsed: 306.425s  Iterations: 20
#
# [COBYLA 2/5] hemi=right
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 20   Least value of F = -0.8383764736481187
# The corresponding X is:
# [153.74269493 105.29529798 149.06607729 108.09063906 131.42252857
#   87.26259614]
#
#   Objective: -0.838376  ObstDist: 7.387  PathLen: 81.454
#   Elapsed: 337.235s  Iterations: 20
#
# [COBYLA 3/5] hemi=right
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 20   Least value of F = -0.8360828087013733
# The corresponding X is:
# [ 23.74999989 143.5         93.30991229 107.26415358 132.68865528
#   88.836448  ]
#
#   Objective: -0.836083  ObstDist: 7.387  PathLen: 86.270
#   Elapsed: 282.456s  Iterations: 20
#
# [COBYLA 4/5] hemi=right
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 20   Least value of F = -0.8725664267533271
# The corresponding X is:
# [ 52.52940758 122.33471397 136.62275989 106.7794593  130.34698025
#   89.50240663]
#
#   Objective: -0.872566  ObstDist: 7.649  PathLen: 74.962
#   Elapsed: 332.472s  Iterations: 20
#
# [COBYLA 5/5] hemi=left
# Return from COBYLA because the objective function has been evaluated MAXFUN times.
# Number of function values = 20   Least value of F = -0.48199905897725603
# The corresponding X is:
# [ 88.6634055   75.90406287  21.26678598 109.33901335 130.44669527
#   70.2620362 ]
#
#   Objective: -0.481999  ObstDist: 4.347  PathLen: 78.621
#   Elapsed: 553.356s  Iterations: 20
#
# [COBYLA Summary] Total time: 1811.944s  Total iterations: 100
#
# ============================================================
# Best COBYLA Bezier run for weights w_obstacle=0.95, w_path_length=0.05:
#   Hemisphere: right
#   Objective: -0.872861
#   Obstacle distance: 7.649
#   Path length: 74.345
#   Start: (np.float64(56.25), np.float64(111.75), np.float64(137.0))
#   End:   (np.float64(108.0), np.float64(129.75), np.float64(86.75))
#   P1:    [ 66.93054335 115.46542184 126.62886924]
#   P2:    [ 86.7606069  122.36193477 107.3739269 ]
# Bezier Objective weights:
#   Obstacle distance: 0.900
#   Path length: 0.100
#
# Running COBYLA Bezier optimization over 5 initial path(s)...
#
# [COBYLA 1/5] hemi=right
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 14
#      11 print(f"Bezier Objective weights:\n  Obstacle distance: {w_obstacle_norm:.3f}\n  Path length: {w_path_length_norm:.3f}")
#      13 print(f"\nRunning {opt_method} Bezier optimization over {len(initial_paths)} initial path(s)...")
# ---> 14 best_run, all_records = run_multistart_bezier(opt_method, {
#      15     'maxiter': opt_max_iterations,
#      16     'tol': opt_tolerance,
#      17     'disp': True
#      18 })
#      20 hemi = best_run['hemi']
#      21 opt_start = best_run['start']
#
# Cell In[20], line 27, in run_multistart_bezier(method_name, options)
#      24 x0 = np.concatenate([start, end])
#      25 t0 = time.perf_counter()
# ---> 27 res = minimize(weighted_sum_objective, x0, method=method_name, options=options)
#      29 elapsed = time.perf_counter() - t0
#      30 iters = getattr(res, 'nit', getattr(res, 'nfev', 0)) or 0
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_minimize.py:790, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     787     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     788                         **options)
#     789 elif meth == 'cobyla':
# --> 790     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     791                            bounds=bounds, **options)
#     792 elif meth == 'cobyqa':
#     793     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     794                            **options)
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_cobyla_py.py:278, in _minimize_cobyla(fun, x0, args, constraints, rhobeg, tol, maxiter, disp, catol, f_target, callback, bounds, **unknown_options)
#     268 ctol = catol if catol is not None else np.sqrt(np.finfo(float).eps)
#     269 options = {
#     270     'rhobeg': rhobeg,
#     271     'rhoend': rhoend,
#    (...)    275     'ftarget': f_target,
#     276 }
# --> 278 result = minimize(sf.fun, x0, method='cobyla', bounds=bounds,
#     279                   constraints=constraints, callback=wrapped_callback,
#     280                   options=options)
#     283 if result.cstrv > ctol:
#     284     success = False
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\__init__.py:191, in minimize(fun, x0, args, method, bounds, constraints, callback, options)
#     188     options['maxfun'] = options['maxfev']
#     189     del options['maxfev']
# --> 191 result = cobyla(
#     192     calcfc,
#     193     len(nlconstr0),
#     194     x0,
#     195     A_ineq,
#     196     b_ineq,
#     197     A_eq,
#     198     b_eq,
#     199     lb,
#     200     ub,
#     201     f0=f0,
#     202     nlconstr0=nlconstr0,
#     203     callback=callback,
#     204     **options
#     205 )
#     207 if any(_fixed_idx):
#     208     newx = np.zeros(lenx0)
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\cobyla\cobyla.py:461, in cobyla(calcfc, m_nlcon, x, Aineq, bineq, Aeq, beq, xl, xu, f0, nlconstr0, rhobeg, rhoend, ftarget, ctol, cweight, maxfun, iprint, eta1, eta2, gamma1, gamma2, maxhist, maxfilt, callback)
#     417 (
#     418     iprint,
#     419     maxfun,
#    (...)    450     is_constrained=(mmm > 0),
#     451 )
#     453 # Further revise MAXHIST according to MAXHISTMEM, and allocate memory for the history.
#     454 # In MATLAB/Python/Julia/R implementation, we should simply set MAXHIST = MAXFUN and initialize
#     455 # CHIST = NaN(1, MAXFUN), CONHIST = NaN(M, MAXFUN), FHIST = NaN(1, MAXFUN), XHIST = NaN(N, MAXFUN)
#    (...)    459
#     460 # call cobylb, which performs the real calculations
# --> 461 x, f, constr, cstrv, nf, xhist, fhist, chist, conhist, info = cobylb(
#     462     calcfc,
#     463     iprint,
#     464     maxfilt,
#     465     maxfun,
#     466     amat,
#     467     bvec,
#     468     ctol,
#     469     cweight,
#     470     eta1,
#     471     eta2,
#     472     ftarget,
#     473     gamma1,
#     474     gamma2,
#     475     rhobeg,
#     476     rhoend,
#     477     constr,
#     478     f,
#     479     x,
#     480     maxhist,
#     481     callback
#     482 )
#     484 return COBYLAResult(x, f, constr, cstrv, nf, xhist, fhist, chist, conhist, info)
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\cobyla\cobylb.py:93, in cobylb(calcfc, iprint, maxfilt, maxfun, amat, bvec, ctol, cweight, eta1, eta2, ftarget, gamma1, gamma2, rhobeg, rhoend, constr, f, x, maxhist, callback)
#      80     assert min(MIN_MAXFILT, maxfun) <= maxfilt <= maxfun
#      82 #====================#
#      83 # Calculation starts #
#      84 #====================#
#    (...)     91 # values, and constraint violations on the vertices in the order corresponding to
#      92 # SIM.
# ---> 93 evaluated, conmat, cval, sim, simi, fval, nf, subinfo = initxfc(calcfc, iprint,
#      94   maxfun, constr, amat, bvec, ctol, f, ftarget, rhobeg, x,
#      95   xhist, fhist, chist, conhist, maxhist)
#      97 # Initialize the filter, including xfilt, ffilt, confilt, cfilt, and nfilt.
#      98 # N.B.: The filter is used only when selecting which iterate to return. It does not
#      99 # interfere with the iterations. COBYLA is NOT a filter method but a trust-region
#     100 # method based on an L-infinity merit function. Powell's implementation does not
#     101 # use a filter to select the iterate, possibly returning a suboptimal iterate.
#     102 cfilt = np.zeros(np.minimum(np.maximum(maxfilt, 1), maxfun))
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\cobyla\initialize.py:87, in initxfc(calcfc, iprint, maxfun, constr0, amat, bvec, ctol, f0, ftarget, rhobeg, x0, xhist, fhist, chist, conhist, maxhist)
#      85     j = k - 1
#      86     x[j] += rhobeg
# ---> 87     f, constr = evaluate(calcfc, x, m_nlcon, amat, bvec)
#      88 cstrv = np.max(np.append(0, constr))
#      90 # Print a message about the function/constraint evaluation according to IPRINT.
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\common\evaluate.py:80, in evaluate(calcfc, x, m_nlcon, amat, bvec)
#      78     constr = np.ones(m_nlcon) * f
#      79 else:
# ---> 80     f, constr[m_lcon:] = calcfc(moderatex(x))
#      82     # Moderated extreme barrier: replace NaN/huge objective or constraint values
#      83     # with a large but finite value. This is naive, and better approaches surely
#      84     # exist.
#      85     f = moderatef(f)
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\pyprima\__init__.py:178, in minimize.<locals>.calcfc(x)
#     177 def calcfc(x):
# --> 178     f = fun(x, *args)
#     179     constr = np.zeros(0)
#     180     return f, constr
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:385, in ScalarFunction.fun(self, x)
#     383 if not np.array_equal(x, self.x):
#     384     self._update_x(x)
# --> 385 self._update_fun()
#     386 return self.f
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_differentiable_functions.py:353, in ScalarFunction._update_fun(self)
#     351 def _update_fun(self):
#     352     if not self.f_updated:
# --> 353         fx = self._wrapped_fun(self.x)
#     354         self._nfev += 1
#     355         if fx < self._lowest_f:
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\_util.py:590, in _ScalarFunctionWrapper.__call__(self, x)
#     587 def __call__(self, x):
#     588     # Send a copy because the user may overwrite it.
#     589     # The user of this class might want `x` to remain unchanged.
# --> 590     fx = self.f(np.copy(x), *self.args)
#     591     self.nfev += 1
#     593     # Make sure the function returns a true scalar
#
# Cell In[17], line 34, in weighted_sum_objective(x)
#      30     opt_hemisphere = 'left' if merged_left_entry_zone and merged_left_stn else 'right'
#      32 start_point, end_point = project_to_surfaces(start_guess, end_guess, opt_hemisphere)
# ---> 34 P1, P2 = optimize_control_points(start_point, end_point)
#      36 path_length = compute_bezier_path_length(
#      37     start_point=start_point,
#      38     end_point=end_point,
#    (...)     41     min_radius_mm=R_MIN_MM,
#      42 )
#      43 if path_length is None:
#
# Cell In[11], line 113, in optimize_control_points(start_point, end_point)
#      98 """
#      99 for a fixed start/end optimize (alpha, gamma, beta_mm, theta) to get best P1 P2.
#     100
#    (...)    104 theta: angle (radians) selecting direction in the perp plane
#     105 """
#     106 bounds = [
#     107     (0.1, 0.5), # alpha
#     108     (0.5, 0.9), # gamma
#     109     (0.0, 25.0), # beta_mm (sideways offset)
#     110     (0.0, 2.0 * np.pi) # theta (angle around the axis)
#     111 ]
# --> 113 result = differential_evolution(
#     114     inner_cp_objective,
#     115     bounds=bounds,
#     116     args=(start_point, end_point),
#     117     maxiter=MAX_P1_P2_OPT_IT,
#     118     tol=P1_P2_OPT_TOL,
#     119     polish=False,
#     120     disp=False
#     121 )
#     123 alpha_opt, gamma_opt, beta_opt, theta_opt = result.x
#     124 P1_opt, P2_opt = control_points_from_params_with_angle(
#     125     start_point, end_point,
#     126     alpha_opt, gamma_opt, beta_opt, theta_opt
#     127 )
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\_util.py:352, in _transition_to_rng.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     345     message = (
#     346         "The NumPy global RNG was seeded by calling "
#     347         f"`np.random.seed`. Beginning in {end_version}, this "
#     348         "function will no longer use the global RNG."
#     349     ) + cmn_msg
#     350     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 352 return fun(*args, **kwargs)
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:502, in differential_evolution(func, bounds, args, strategy, maxiter, popsize, tol, mutation, recombination, rng, callback, disp, polish, init, atol, updating, workers, constraints, x0, integrality, vectorized)
#     485 # using a context manager means that any created Pool objects are
#     486 # cleared up.
#     487 with DifferentialEvolutionSolver(func, bounds, args=args,
#     488                                  strategy=strategy,
#     489                                  maxiter=maxiter,
#    (...)    500                                  integrality=integrality,
#     501                                  vectorized=vectorized) as solver:
# --> 502     ret = solver.solve()
#     504 return ret
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:1186, in DifferentialEvolutionSolver.solve(self)
#    1183 for nit in range(1, self.maxiter + 1):
#    1184     # evolve the population by a generation
#    1185     try:
# -> 1186         next(self)
#    1187     except StopIteration:
#    1188         warning_flag = True
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\optimize\_differentialevolution.py:1601, in DifferentialEvolutionSolver.__next__(self)
#    1599     feasible = True
#    1600     cv = np.atleast_2d([0.])
# -> 1601     energy = self.func(parameters)
#    1602     self._nfev += 1
#    1604 # compare trial and population member
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\scipy\_lib\_util.py:575, in _FunctionWrapper.__call__(self, x)
#     574 def __call__(self, x):
# --> 575     return self.f(x, *self.args)
#
# Cell In[11], line 8, in inner_cp_objective(params, start_point, end_point)
#       2 alpha, gamma, beta_mm, theta = params
#       4 P1, P2 = control_points_from_params_with_angle(
#       5     start_point, end_point, alpha, gamma, beta_mm, theta
#       6 )
# ----> 8 raw_length = compute_bezier_path_length(
#       9     start_point=start_point,
#      10     end_point=end_point,
#      11     control_point1=P1,
#      12     control_point2=P2,
#      13     min_radius_mm=R_MIN_MM,
#      14 )
#      15 if raw_length is None:
#      16     return 1e10
#
# Cell In[10], line 152, in compute_bezier_path_length(start_point, end_point, control_point1, control_point2, min_radius_mm, num_samples)
#     149 pts = bezier_pos(t) #sample curve
#     151 # approx. length
# --> 152 diffs = np.diff(pts, axis=0)
#     153 segment_lengths = np.linalg.norm(diffs, axis=1)
#     154 length = float(np.sum(segment_lengths))
#
# File c:\Users\doubl\Desktop\School\BME 411\Optimization_Project\.venv\Lib\site-packages\numpy\lib\_function_base_impl.py:1387, in _diff_dispatcher(a, n, axis, prepend, append)
#    1383         return outvals[0]
#    1384     return tuple(outvals)
# -> 1387 def _diff_dispatcher(a, n=None, axis=None, prepend=None, append=None):
#    1388     return (a, prepend, append)
#    1391 @array_function_dispatch(_diff_dispatcher)
#    1392 def diff(a, n=1, axis=-1, prepend=np._NoValue, append=np._NoValue):
#
# KeyboardInterrupt:

# %%
# Save aggregated Pareto-optimal Bezier paths to CSV
pareto_output_file = 'cubic_bezier_pareto_optimal_paths.csv'
with open(pareto_output_file, 'w') as f:
    f.write('method,w_obstacle,w_path_length,hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,p1_x,p1_y,p1_z,p2_x,p2_y,p2_z,obstacle_distance,path_length,weighted_objective\n')
    for rec in pareto_results:
        sx, sy, sz = rec['start']
        ex, ey, ez = rec['end']
        p1x, p1y, p1z = rec['P1']
        p2x, p2y, p2z = rec['P2']
        f.write(
            f"{rec['method']},{rec['w_obstacle']},{rec['w_path_length']},{rec['hemisphere']},{sx},{sy},{sz},{ex},{ey},{ez},{p1x},{p1y},{p1z},{p2x},{p2y},{p2z},{rec['obstacle_distance']},{rec['path_length']},{rec['weighted_objective']}\n"
        )
print(f'Saved Bezier Pareto-optimal set ({len(pareto_results)} paths) to {pareto_output_file}')

# %% [markdown]
# ## Load Path Data

# %%
import csv

# %%
## Load Monte Carlo bezier path coordinates from file
input_file = "monte_carlo_bezier_paths.csv"
monte_carlo_records = []

if os.path.exists(input_file):
    with open(input_file, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            try:
                record = {
                    'hemisphere': row['hemisphere'],
                    'start': (
                        float(row['start_x']),
                        float(row['start_y']),
                        float(row['start_z'])
                    ),
                    'end': (
                        float(row['end_x']),
                        float(row['end_y']),
                        float(row['end_z'])
                    ),
                    'P1': (
                        float(row['p1_x']),
                        float(row['p1_y']),
                        float(row['p1_z'])
                    ),
                    'P2': (
                        float(row['p2_x']),
                        float(row['p2_y']),
                        float(row['p2_z'])
                    ),
                    'obstacle_distance': float(row['obstacle_distance']),
                    'path_length': float(row['path_length']),
                    'status': row['status'],
                    'is_best': (row.get('is_best', '0') == '1')
                }
                monte_carlo_records.append(record)
            except Exception as e:
                print(f"[WARN] Skipping row due to parse error: {e}")

    # Rebuild successful_attempts
    successful_attempts = []
    
    for r in monte_carlo_records:
        if r['status'] == 'success':
            successful_attempts.append((r['hemisphere'], r['start'], r['end'], r['P1'], r['P2'], r['obstacle_distance'], r['path_length']))

    # Rebuild failed_attempts
    failed_attempts = []
    for r in monte_carlo_records:
        if r['status'] == 'fail':
            failed_attempts.append((r['hemisphere'], r['start'], r['end'], r['P1'], r['P2'], r['obstacle_distance'], r['path_length']))
    
    # Identify best path
    loaded_best = next((r for r in monte_carlo_records if r['status'] == 'success' and r['is_best']), None)
    if loaded_best:
        print(f"Loaded best Monte Carlo path: hemi={loaded_best['hemisphere']} obstacle_dist={loaded_best['obstacle_distance']:.3f} path_len={loaded_best['path_length']:.3f}")
    else:
        print("Best Monte Carlo path flag not found; will infer later if needed.")
    print(f"Loaded {len(monte_carlo_records)} Monte Carlo path records from {input_file}")
else:
    print(f"[INFO] Monte Carlo path file not found: {input_file}")
# Out:
# Loaded best Monte Carlo path: hemi=right obstacle_dist=7.473 path_len=73.700
# Loaded 101 Monte Carlo path records from monte_carlo_bezier_paths.csv

# %%
## Load optimized bezier path from file
OPTIMIZATION_METHOD = 'COBYLA'  # Ensure this matches the saved optimization method

opt_input_file = f"{OPTIMIZATION_METHOD.lower()}_optimal_bezier_path.csv"
# Read optimal path from CSV and rebuild variables
if os.path.exists(opt_input_file):
    with open(opt_input_file, 'r') as f:
        reader = csv.DictReader(f)
        row = next(reader, None)
        if row:
            opt_hemisphere = row['hemisphere']
            opt_optimal_start = (float(row['start_x']), float(row['start_y']), float(row['start_z']))
            opt_optimal_end = (float(row['end_x']), float(row['end_y']), float(row['end_z']))
            P1_opt = (float(row['p1_x']), float(row['p1_y']), float(row['p1_z']))
            P2_opt = (float(row['p2_x']), float(row['p2_y']), float(row['p2_z']))
            opt_obstacle_dist = float(row['obstacle_distance'])
            opt_path_length = float(row['path_length'])
            opt_weighted_obj = float(row.get('weighted_objective', -w_obstacle_norm * (opt_obstacle_dist / max_obstacle_dist if max_obstacle_dist else opt_obstacle_dist / 100.0)
                                            + w_path_length_norm * (opt_path_length / max_path_length if max_path_length else opt_path_length / 200.0)))
            selected_hemisphere = opt_hemisphere
            path_points = sample_bezier_points(opt_optimal_start, P1_opt, P2_opt, opt_optimal_end, num_samples=200)
            opt_optimal_line = Line(path_points).c("cyan").lw(10)
            print(f"Loaded {OPTIMIZATION_METHOD} path: hemi={opt_hemisphere} obstacle={opt_obstacle_dist:.3f} length={opt_path_length:.3f} weighted={opt_weighted_obj:.6f}")
        else:
            print(f"[INFO] {OPTIMIZATION_METHOD} file is empty.")
else:
    print(f"[INFO] {OPTIMIZATION_METHOD} path file not found: {opt_input_file}")
# Out:
# Loaded COBYLA path: hemi=right obstacle=7.649 length=73.519 weighted=-0.790441

# %%
## Load optimized COBYLA linear path from file
cobyla_input_file = "cobyla_optimal_path.csv"
if os.path.exists(cobyla_input_file):
    with open(cobyla_input_file, 'r') as f:
        reader = csv.DictReader(f)
        row = next(reader, None)
        if row:
            cobyla_hemisphere = row['hemisphere']
            cobyla_optimal_start = (float(row['start_x']), float(row['start_y']), float(row['start_z']))
            cobyla_optimal_end = (float(row['end_x']), float(row['end_y']), float(row['end_z']))
            cobyla_obstacle_dist = float(row['obstacle_distance'])
            cobyla_path_length = float(row['path_length'])
            cobyla_weighted_obj = float(row.get('weighted_objective', -w_obstacle_norm * (cobyla_obstacle_dist / max_obstacle_dist if max_obstacle_dist else cobyla_obstacle_dist / 100.0)
                                            + w_path_length_norm * (cobyla_path_length / max_path_length if max_path_length else cobyla_path_length / 200.0)))
            selected_hemisphere = cobyla_hemisphere
            cobyla_optimal_line = Line([cobyla_optimal_start, cobyla_optimal_end]).c("cyan").lw(10)
            print(f"Loaded COBYLA path: hemi={cobyla_hemisphere} obstacle={cobyla_obstacle_dist:.3f} length={cobyla_path_length:.3f} weighted={cobyla_weighted_obj:.6f}")
        else:
            print("[INFO] COBYLA file is empty.")
else:
    print(f"[INFO] COBYLA path file not found: {cobyla_input_file}")


# Optionally preload COBYLA Bezier result for (0.90, 0.10) into Pareto
try:
    bezier_csv = "cobyla_optimal_bezier_path.csv"
    if os.path.exists(bezier_csv):
        with open(bezier_csv, 'r') as f:
            reader = csv.DictReader(f)
            row = next(reader, None)
        if row is not None:
            preload_weights = (0.90, 0.10)
            # Ensure weights list will include this combo later
            # Prepare record
            rec = {
                'method': 'COBYLA',
                'w_obstacle': preload_weights[0],
                'w_path_length': preload_weights[1],
                'hemisphere': row['hemisphere'],
                'start': (float(row['start_x']), float(row['start_y']), float(row['start_z'])),
                'end': (float(row['end_x']), float(row['end_y']), float(row['end_z'])),
                'P1': (float(row['p1_x']), float(row['p1_y']), float(row['p1_z'])),
                'P2': (float(row['p2_x']), float(row['p2_y']), float(row['p2_z'])),
                'obstacle_distance': float(row['obstacle_distance']),
                'path_length': float(row['path_length']),
                'weighted_objective': float(row.get('weighted_objective', 0.0))
            }
            if 'pareto_results' not in globals():
                pareto_results = []
            if 'pareto_lines' not in globals():
                pareto_lines = []
            pareto_results.append(rec)
            # Build a line from saved points
            saved_pts = sample_bezier_points(rec['start'], rec['P1'], rec['P2'], rec['end'], num_samples=NUM_SAMPLE)
            preload_line = Line(saved_pts).c("blue").lw(10)
            pareto_lines.append(preload_line)
            print("Preloaded COBYLA Bezier Pareto entry (0.90, 0.10) from CSV.")
    else:
        print("Bezier COBYLA CSV not found; skipping preload.")
except Exception as e:
    print(f"[WARN] Failed to preload Bezier COBYLA Pareto entry: {e}")
# Out:
# Loaded COBYLA path: hemi=right obstacle=7.649 length=65.863 weighted=-0.858854
# Preloaded COBYLA Bezier Pareto entry (0.90, 0.10) from CSV.

# %% [markdown]
# ## Visualization

# %%
# Set vedo backend to pop out plots in separate windows
vedo.settings.default_backend = 'vtk' # or 'vt' or '2d' or 'k3d' or 'ipyvtklink'

# %%
## Plot final results
NUM_FAILED_TO_SHOW = min(10, len(failed_lines))
NUM_SUBOPTIMAL_TO_SHOW = min(10, len(suboptimal_lines))

actors = []
if merged_full_brain: actors.append(merged_full_brain)
if merged_skin: actors.append(merged_skin)

if selected_hemisphere == 'left':
    if merged_left_entry_zone: actors.append(merged_left_entry_zone.clone().alpha(0.08))
    if merged_right_entry_zone: actors.append(merged_right_entry_zone.clone().alpha(0.02))
    if merged_left_stn: actors.append(merged_left_stn.clone().alpha(0.9))
    if merged_right_stn: actors.append(merged_right_stn.clone().alpha(0.3))
elif selected_hemisphere == 'right':
    if merged_left_entry_zone: actors.append(merged_left_entry_zone.clone().alpha(0.02))
    if merged_right_entry_zone: actors.append(merged_right_entry_zone.clone().alpha(0.08))
    if merged_left_stn: actors.append(merged_left_stn.clone().alpha(0.3))
    if merged_right_stn: actors.append(merged_right_stn.clone().alpha(0.9))
else:
    if merged_left_entry_zone: actors.append(merged_left_entry_zone)
    if merged_right_entry_zone: actors.append(merged_right_entry_zone)
    if merged_left_stn: actors.append(merged_left_stn)
    if merged_right_stn: actors.append(merged_right_stn)

if merged_obstacles: actors.append(merged_obstacles.clone().alpha(0.7))

actors.extend(failed_lines[:NUM_FAILED_TO_SHOW])
actors.extend(suboptimal_lines[:NUM_SUBOPTIMAL_TO_SHOW])
if best_path:
    mc_best_faded = best_path.clone().alpha(0.6)
    actors.append(mc_best_faded)

try:
    actors.append(opt_optimal_line)
except:
    print("Optimized path not found.")
    
# try:
#     actors.append(cobyla_optimal_line)
# except:
#     print("Linear COBYLA optimized path not found.")

# Plot Pareto-optimal set together (Bezier)
if 'pareto_lines' in globals() and pareto_lines:
    print(f"Adding {len(pareto_lines)} Pareto-optimal Bezier paths to plot...")
    for ln in pareto_lines:
        actors.append(ln.clone().alpha(0.85).lw(8))
else:
    print("No Pareto-optimal Bezier paths available to plot.")

print("Rendering scene with Pareto-optimal Bezier set...")
show(actors, axes=1, viewup="z", title="Bezier Pareto-Optimal Paths", new=True, interactive=True)
# Out:
# Rendering scene with optimized path (cyan)...
