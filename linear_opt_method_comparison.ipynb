# %% [markdown]
# # Linear Optimization

# %% [markdown]
# Optimizes a linear straight-line path from a point on the viable brain surface region to a point on the subthalamic nucleus (STN) for DBS electrode planning.
#
# Treats the following as obstacles:
# - Sulci
# - Ventricles
# - Corpus Callosum (prevent brain crossing)

# %% [markdown]
# **Objective Functions**
# - Distance to obstacles
# - Minimum path distance  *(not optimized yet)*

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### Import Libraries

# %%
import os
import glob
import random
import numpy as np

import vedo
from vedo import Volume, show, Line, merge, Plotter

from scipy.optimize import minimize

import k3d

# %%
# Set vedo backend to pop out plots in separate windows
vedo.settings.default_backend = '2d' # or 'vt' or '2d' or 'k3d' or 'ipyvtklink'

# %%
## Vedo sphere plot test
sphere = vedo.Sphere(pos=[0, 0, 0], c="red", r=1.0)
plotter = vedo.Plotter()
plotter += sphere
plotter.show(axes=1, viewup='z', zoom=1.5)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %% [markdown]
# ### Configuration and Setup

# %%
# Define new base directory and sub-folder structure
base_dir = "./FINAL_BRAIN_ATLAS/final_nii_files"

# Entry zones (viable surface regions for path start)
entry_zone_dir = os.path.join(base_dir, "entry_zone")
left_entry_zone_dir = os.path.join(entry_zone_dir, "LEFT_ENTRY_ZONE")
right_entry_zone_dir = os.path.join(entry_zone_dir, "RIGHT_ENTRY_ZONE")

# Subthalamic nucleus (targets)
stn_root_dir = os.path.join(base_dir, "subthalamic_nucleus")
left_stn_dir = os.path.join(stn_root_dir, "LEFT_STN")
right_stn_dir = os.path.join(stn_root_dir, "RIGHT_STN")

# Full brain (for context / outline only)
full_brain_dir = os.path.join(base_dir, "full_brain")

# Obstacles (same role as before)
obstacles_dir = os.path.join(base_dir, "obstacles")

print("Base directory:", base_dir)
# Out:
# Base directory: ./FINAL_BRAIN_ATLAS/final_nii_files

# %% [markdown]
# ### Load Brain Structures
#
# Recursively load all `.nii` / `.nii.gz` files under each designated root:
# - Entry Zones (LEFT/RIGHT) viable start regions (light brown, low alpha)
# - STN Targets (LEFT/RIGHT) (distinct greens)
# - Obstacles (red)
# - Full Brain outline (very light grey, minimal alpha)
#
# All subfolder contents are merged later per category.

# %%
# Initialize lists for different structure types
left_entry_zone_structures = []
right_entry_zone_structures = []
left_stn_structures = []
right_stn_structures = []
allowed_left_entry_zone_structures = []
allowed_right_entry_zone_structures = []
obstacle_structures = []
full_brain_structures = []

# Loader utility: walk all subfolders and load every .nii / .nii.gz
def load_folder_surfaces(root_folder, color, alpha=1.0):
    loaded = []
    if not os.path.isdir(root_folder):
        print(f"[WARN] Folder not found: {root_folder}")
        return loaded
    
    for dirpath, dirnames, filenames in os.walk(root_folder):
        nii_files = [f for f in filenames if f.lower().endswith('.nii') or f.lower().endswith('.nii.gz')]
        for fname in nii_files:
            fpath = os.path.join(dirpath, fname)
            rel = os.path.relpath(fpath, root_folder)
            print(f"  Loading structure: {rel}")
            try:
                vol = Volume(fpath)
                surf = vol.isosurface()
                surf.c(color).alpha(alpha)
                loaded.append(surf)
            except Exception as e:
                print(f"  [WARN] Failed to load volume/surface: {fpath} ({e})")
    if not loaded:
        print(f"  [INFO] No NIfTI files found under {root_folder}")
    return loaded

print("\nLoading Entry Zones (LEFT)...")
left_entry_zone_structures = load_folder_surfaces(left_entry_zone_dir, color=(0.95, 0.65, 0.85), alpha=0.04)
print("Loading Entry Zones (RIGHT)...")
right_entry_zone_structures = load_folder_surfaces(right_entry_zone_dir, color=(0.95, 0.75, 0.85), alpha=0.04)

# STN folders (may already be deepest; recursion still safe)
print("\nLoading STN (LEFT)...")
left_stn_structures = load_folder_surfaces(left_stn_dir, color="green", alpha=1.0)
print("Loading STN (RIGHT)...")
right_stn_structures = load_folder_surfaces(right_stn_dir, color="green", alpha=1.0)

print("\nLoading Obstacles...")
obstacle_structures = load_folder_surfaces(obstacles_dir, color="red", alpha=0.7)

print("\nLoading Full Brain Outline...")
full_brain_structures = load_folder_surfaces(full_brain_dir, color="grey", alpha=0.01)
# Out:
# Loading Entry Zones (LEFT)...
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1003_posterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1012_left_lateral_orbital_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1014_left_straight_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1017_left_paracentral_lobule.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1018_opercular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1019_orbital_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1020_triangular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1024_left_precentral_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1027_anterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1028_left_superior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1032_left_frontal_pole.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1008_left_inferior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1022_left_postcentral_gyrus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1025_left_precuneus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1029_left_superior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1031_left_supramarginal_gyrus.nii
# Loading Entry Zones (RIGHT)...
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2003_posterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2012_right_lateral_orbital_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2014_right_straight_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2017_right_paracentral_lobule.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2018_opercular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2019_orbital_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2020_triangular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2024_right_precentral_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2027_anterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2028_right_superior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2032_right_frontal_pole.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2008_right_inferior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2022_right_postcentral_gyrus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2025_right_precuneus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2029_right_superior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2031_right_supramarginal_gyrus.nii
#
# Loading STN (LEFT)...
#   Loading structure: Model_391_left_subthalamic_nucleus.nii
# Loading STN (RIGHT)...
#   Loading structure: Model_390_right_subthalamic_nucleus.nii
#
# Loading Obstacles...
#   Loading structure: SULCI\Model_5001_left_calcarine_sulcus.nii
#   Loading structure: SULCI\Model_5002_right_calcarine_sulcus.nii
#   Loading structure: SULCI\Model_5003_left_central_sulcus.nii
#   Loading structure: SULCI\Model_5004_right_central_sulcus.nii
#   Loading structure: SULCI\Model_5005_left_cingulate_sulcus.nii
#   Loading structure: SULCI\Model_5006_right_cingulate_sulcus.nii
#   Loading structure: SULCI\Model_5007_left_collateral_sulcus.nii
#   Loading structure: SULCI\Model_5008_right_collateral_sulcus.nii
#   Loading structure: SULCI\Model_5009_left_inferior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5010_right_inferior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5011_left_intraparietal_sulcus.nii
#   Loading structure: SULCI\Model_5012_right_intraparietal_sulcus.nii
#   Loading structure: SULCI\Model_5013_left_parieto-occipital_sulcus.nii
#   Loading structure: SULCI\Model_5014_right_parieto-occipital_sulcus.nii
#   Loading structure: SULCI\Model_5015_left_postcentral_sulcus.nii
#   Loading structure: SULCI\Model_5016_right_postcentral_sulcus.nii
#   Loading structure: SULCI\Model_5017_left_precentral_sulcus.nii
#   Loading structure: SULCI\Model_5018_right_precentral_sulcus.nii
#   Loading structure: SULCI\Model_5019_left_superior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5020_right_superior_frontal_sulcus.nii
#   Loading structure: SULCI\Model_5022_right_superior_temporal_sulcus.nii
#   Loading structure: VENTRICLE\Model_15_fourth_ventricle.nii
#   Loading structure: VENTRICLE\Model_19_aqueduct.nii
#   Loading structure: VENTRICLE\Model_24_third_ventricle.nii
#   Loading structure: VENTRICLE\Model_43_right_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_44_temporal_horn_of_right_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_4_left_lateral_ventricle.nii
#   Loading structure: VENTRICLE\Model_5_temporal_horn_of_left_lateral_ventricle.nii
#
# Loading Full Brain Outline...
#   Loading structure: CEREBELLUM\Model_46_white_matter_of_right_hemisphere_of_cerebellum.nii
#   Loading structure: CEREBELLUM\Model_7_white_matter_of_left_hemisphere_of_cerebellum.nii
#   Loading structure: CORPUS_CALLOSUM\Model_3004_corpus_callosum.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1003_posterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1012_left_lateral_orbital_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1014_left_straight_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1017_left_paracentral_lobule.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1018_opercular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1019_orbital_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1020_triangular_part_of_left_inferior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1024_left_precentral_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1027_anterior_part_of_left_middle_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1028_left_superior_frontal_gyrus.nii
#   Loading structure: LEFT_FRONTAL_LOBE\Model_1032_left_frontal_pole.nii
#   Loading structure: LEFT_INSULA\Model_1000_left_insula.nii
#   Loading structure: LEFT_INSULA\Model_1035_left_limen_insulae.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1002_caudal_part_of_left_anterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1010_isthmus_of_left_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1016_left_parahippocampal_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1023_left_posterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_1026_rostral_part_of_left_anterior_cingulate_gyrus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_17_left_hippocampus.nii
#   Loading structure: LEFT_LIMBIC_LOBE\Model_18_left_amygdala.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1005_left_cuneus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1011_left_lateral_occipital_gyrus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1013_left_lingual_gyrus.nii
#   Loading structure: LEFT_OCCIPITAL_LOBE\Model_1021_left_visual_cortex.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1008_left_inferior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1022_left_postcentral_gyrus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1025_left_precuneus.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1029_left_superior_parietal_lobule.nii
#   Loading structure: LEFT_PARIETAL_LOBE\Model_1031_left_supramarginal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1001_left_superior_temporal_gyrus_(banks_of_left_superior_temporal_sulcus).nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1006_left_ambiens_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1007_left_fusiform_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1009_left_inferior_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1015_left_middle_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1030_left_superior_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1033_left_temporal_pole.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_1034_left_transverse_temporal_gyrus.nii
#   Loading structure: LEFT_TEMPORAL_LOBE\Model_3001_left_claustrum.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2003_posterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2012_right_lateral_orbital_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2014_right_straight_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2017_right_paracentral_lobule.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2018_opercular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2019_orbital_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2020_triangular_part_of_right_inferior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2024_right_precentral_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2027_anterior_part_of_right_middle_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2028_right_superior_frontal_gyrus.nii
#   Loading structure: RIGHT_FRONTAL_LOBE\Model_2032_right_frontal_pole.nii
#   Loading structure: RIGHT_INSULA\Model_2000_right_insula.nii
#   Loading structure: RIGHT_INSULA\Model_2035_right_limen_insulae.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2002_caudal_part_of_right_anterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2010_isthmus_of_right_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2016_right_parahippocampal_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2023_right_posterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_2026_rostral_part_of_right_anterior_cingulate_gyrus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_53_right_hippocampus.nii
#   Loading structure: RIGHT_LIMBIC_LOBE\Model_54_right_amygdala.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2005_right_cuneus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2011_right_lateral_occipital_gyrus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2013_right_lingual_gyrus.nii
#   Loading structure: RIGHT_OCCIPITAL_LOBE\Model_2021_right_visual_cortex.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2008_right_inferior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2022_right_postcentral_gyrus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2025_right_precuneus.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2029_right_superior_parietal_lobule.nii
#   Loading structure: RIGHT_PARIETAL_LOBE\Model_2031_right_supramarginal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2001_right_superior_temporal_gyrus_(banks_of_right_superior_temporal_sulcus).nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2006_right_ambiens_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2007_right_fusiform_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2009_right_inferior_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2015_right_middle_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2030_right_superior_temporal_gyrus.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2033_right_temporal_pole.nii
#   Loading structure: RIGHT_TEMPORAL_LOBE\Model_2034_right_transverse_temporal_gyrus.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_11_left_caudate_nucleus.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_12_left_putamen.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_13_left_globus_pallidus_pars_externa.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_25_left_globus_pallidus_pars_interna.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_26_left_nucleus_accumbens.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_2_white_matter_of_left_cerebral_hemisphere.nii
#   Loading structure: SUBCORTEX_OF_LEFT_CEREBRAL_HEMISPHERE\Model_3007_left_fornix_of_forebrain.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_3005_right_fornix_of_forebrain.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_41_white_matter_of_right_cerebral_hemisphere.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_50_right_caudate_nucleus.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_51_right_putamen.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_52_right_globus_pallidus_pars_externa.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_58_right_nucleus_accumbens.nii
#   Loading structure: SUBCORTEX_OF_RIGHT_CEREBRAL_HEMISPHERE\Model_83_right_globus_pallidus_pars_interna.nii

# %% [markdown]
# ### Merge Structures
#
# Combine individual structures into single meshes for:
# - LEFT/RIGHT Entry Zones (start sampling)
# - LEFT/RIGHT STN (target sampling hemisphere-consistent)
# - Obstacles (for intersection & distance)
# - Full Brain (context outline only)

# %%
# Merge structures into single meshes
merged_left_entry_zone = merge(left_entry_zone_structures) if left_entry_zone_structures else None
if merged_left_entry_zone: merged_left_entry_zone.alpha(0.04)

merged_right_entry_zone = merge(right_entry_zone_structures) if right_entry_zone_structures else None
if merged_right_entry_zone: merged_right_entry_zone.alpha(0.04)

# Placeholders for allowed (outer-facing) entry zone meshes; computed later
merged_allowed_left_entry_zone = None
merged_allowed_right_entry_zone = None

merged_left_stn = merge(left_stn_structures) if left_stn_structures else None
merged_right_stn = merge(right_stn_structures) if right_stn_structures else None

merged_obstacles = merge(obstacle_structures) if obstacle_structures else None
if merged_obstacles: merged_obstacles.c("red").alpha(0.75)

merged_full_brain = merge(full_brain_structures) if full_brain_structures else None
if merged_full_brain: merged_full_brain.c("grey").alpha(0.01)

print("\nMerged Summary:")
print(f"  Left Entry Zone: {'yes' if merged_left_entry_zone else 'no'}")
print(f"  Right Entry Zone: {'yes' if merged_right_entry_zone else 'no'}")
print(f"  Left Allowed Entry Zone: {'yes' if merged_allowed_left_entry_zone else 'no'}")
print(f"  Right Allowed Entry Zone: {'yes' if merged_allowed_right_entry_zone else 'no'}")
print(f"  Left STN: {'yes' if merged_left_stn else 'no'}")
print(f"  Right STN: {'yes' if merged_right_stn else 'no'}")
print(f"  Obstacles: {'yes' if merged_obstacles else 'no'}")
print(f"  Full Brain: {'yes' if merged_full_brain else 'no'}")
# Out:
# Merged Summary:
#   Left Entry Zone: yes
#   Right Entry Zone: yes
#   Left Allowed Entry Zone: no
#   Right Allowed Entry Zone: no
#   Left STN: yes
#   Right STN: yes
#   Obstacles: yes
#   Full Brain: yes

# %%
# Compute allowed entry zones (outer-facing only) based on full brain center
# This cell should run AFTER merging meshes
if merged_full_brain is None:
    print("[WARN] Full brain mesh not available; cannot compute outward-facing entry zones.")
else:
    brain_center = np.array(merged_full_brain.points).mean(axis=0)
    
    allowed_left_entry_zone_structures = []
    allowed_right_entry_zone_structures = []
    
    def outer_facing_mesh_from_merged(merged_mesh, color, alpha):
        if merged_mesh is None:
            return None
        # Ensure normals on cells
        merged_mesh.compute_normals(points=False, cells=True, consistency=True)
        verts = np.array(merged_mesh.points)
        faces = np.array(merged_mesh.cells)
        try:
            norms = np.array(merged_mesh.celldata["Normals"])
        except Exception:
            norms = None
        if norms is None or norms.size == 0 or faces.size == 0:
            print("  [WARN] Could not compute cell normals; returning original merged mesh")
            mm = merged_mesh.clone()
            mm.c(color).alpha(alpha)
            return mm
        faces_centers = verts[faces].mean(axis=1)
        vectors = faces_centers - brain_center
        dots = np.einsum("ij,ij->i", norms, vectors)
        keep = dots > 0
        if keep.sum() == 0:
            print("  [WARN] No outward-facing faces detected; returning original merged mesh")
            mm = merged_mesh.clone()
            mm.c(color).alpha(alpha)
            return mm
        outer_faces = faces[keep]
        outer_mesh = vedo.Mesh([verts, outer_faces])
        outer_mesh.clean()
        outer_mesh.smooth()
        outer_mesh.c(color).alpha(alpha)
        return outer_mesh
    
    # Compute allowed (outer-facing) merged entry zone meshes
    merged_allowed_left_entry_zone = outer_facing_mesh_from_merged(merged_left_entry_zone, color=(0.95, 0.65, 0.85), alpha=0.04)
    merged_allowed_right_entry_zone = outer_facing_mesh_from_merged(merged_right_entry_zone, color=(0.95, 0.75, 0.85), alpha=0.04)
    
    # Also keep list variants for downstream plotting that expects lists
    if merged_allowed_left_entry_zone is not None:
        allowed_left_entry_zone_structures = [merged_allowed_left_entry_zone]
    if merged_allowed_right_entry_zone is not None:
        allowed_right_entry_zone_structures = [merged_allowed_right_entry_zone]
    
    print("Computed outward-facing allowed entry zone meshes using full brain center.")
# Out:
# Computed outward-facing allowed entry zone meshes using full brain center.

# %%
# Plot and show the outer entry zone
actors1 = []
actors1 += allowed_left_entry_zone_structures
actors1 += allowed_right_entry_zone_structures
# actors1.append(merged_full_brain)
show(actors1, axes=1, viewup="z", title="Entry Zones")
# Out:
# <PIL.Image.Image image mode=RGB size=800x600>

# %% [markdown]
# ### Helper Functions

# %%
def compute_path_length(start_point, end_point):
    """Compute the distance between two points for the line path."""
    return np.linalg.norm(np.array(end_point) - np.array(start_point))


def compute_obstacle_distance(start_point, end_point):
    """Compute the minimum distance from the line path to any obstacle."""
    if merged_obstacles is None:
        return 0.0
    temp_line = Line([start_point, end_point])
    d = temp_line.distance_to(merged_obstacles)
    if isinstance(d, (list, tuple, np.ndarray)):
        return float(np.min(d))
    return float(d)


def check_intersection(start_point, end_point):
    """Check if the line path intersects any obstacle."""
    if merged_obstacles is None:
        return False
    intersections = merged_obstacles.intersect_with_line(start_point, end_point)
    return intersections is not None and len(intersections) > 0


def _closest_point_on_mesh(point, mesh):
    """Project a 3D point onto the closest point on a mesh surface."""
    if mesh is None:
        return tuple(point)
    try:
        cp = mesh.closest_point(point)
        return tuple(cp)
    except Exception:
        # Fallback to nearest vertex
        verts = np.asarray(mesh.vertices)
        if verts.size == 0:
            return tuple(point)
        idx = int(np.argmin(np.linalg.norm(verts - np.asarray(point), axis=1)))
        return tuple(verts[idx])


def project_to_surfaces(start_point, end_point, hemisphere):
    """Project start/end onto entry zone and STN surfaces for the chosen hemisphere."""
    if hemisphere == 'left':
        sp = _closest_point_on_mesh(start_point, merged_allowed_left_entry_zone)
        ep = _closest_point_on_mesh(end_point, merged_left_stn)
    else:
        sp = _closest_point_on_mesh(start_point, merged_allowed_right_entry_zone)
        ep = _closest_point_on_mesh(end_point, merged_right_stn)
    return sp, ep


def sample_start_and_end():
    """Sample a hemisphere-consistent start (entry zone) and end (STN)."""
    hemispheres = []
    if merged_allowed_left_entry_zone and merged_left_stn:
        hemispheres.append('left')
    if merged_allowed_right_entry_zone and merged_right_stn:
        hemispheres.append('right')
    if not hemispheres:
        raise RuntimeError("No valid hemisphere data available for sampling.")
    hemi = random.choice(hemispheres)
    if hemi == 'left':
        start = tuple(merged_allowed_left_entry_zone.generate_random_points(1).points[0])
        end = tuple(merged_left_stn.generate_random_points(1).points[0])
    else:
        start = tuple(merged_allowed_right_entry_zone.generate_random_points(1).points[0])
        end = tuple(merged_right_stn.generate_random_points(1).points[0])
    return hemi, start, end

# %% [markdown]
# ## 2. Monte Carlo Optimization

# %% [markdown]
# ### Path Generation and Optimization

# %% [markdown]
# Generate random paths from brain surface to STN and evaluate them:
# - **Orange lines**: Failed paths (intersect obstacles)
# - **Yellow lines**: Successful but suboptimal paths
# - **Green line**: Optimal path (maximum distance from obstacles)

# %% [markdown]
# **Optimization Algorithm**
#
# Runs until finding a minimum of `min_successful_attempts`, or up until `max_attempts`.
#
# Chooses a **random location** from the viable brain surface region and the STN of the corresponding hemisphere.
#
# For each plot, the distance from obstacles is saved. The "best" path is determined using the highest distance to obstacles.

# %%
## Config for Monte Carlo
# Monte Carlo path generation parameters
max_attempts = 2000
min_successful_attempts = 100

# Line width configuration (for visualization)
BEST_PATH_WIDTH = 6
SUBOPTIMAL_PATH_WIDTH = 4
FAILED_PATH_WIDTH = 4

# %%
## Run Monte Carlo sampling

successful_attempts = []  # Store (hemisphere, start_point, end_point, obstacle_distance, path_length) tuples
failed_attempts = []      # Store (hemisphere, start_point, end_point, obstacle_distance(=0 for fail), path_length)
failed_lines = []

for attempt in range(max_attempts):
    if len(successful_attempts) >= min_successful_attempts:
        break

    hemi, start_point, end_point = sample_start_and_end()
    print(f"Attempt {attempt+1}: hemisphere={hemi} start={start_point} end={end_point}")

    path_len = compute_path_length(start_point, end_point)

    # Check for intersection if we have obstacles
    if merged_obstacles:
        if not check_intersection(start_point, end_point):
            # Compute metrics
            temp_line = Line([start_point, end_point])
            obstacle_dist = compute_obstacle_distance(start_point, end_point)
            successful_attempts.append((hemi, start_point, end_point, obstacle_dist, path_len))
            print(f"  SUCCESS ({len(successful_attempts)}/{min_successful_attempts}) - Obstacle Distance: {obstacle_dist:.3f} Path Length: {path_len:.3f}")
        else:
            failed_line = Line([start_point, end_point]).c("orange").alpha(0.3).lw(FAILED_PATH_WIDTH)
            failed_lines.append(failed_line)
            failed_attempts.append((hemi, start_point, end_point, 0.0, path_len))
            print("  FAIL - Line intersects obstacles")
    else:
        obstacle_dist = 0.0
        successful_attempts.append((hemi, start_point, end_point, obstacle_dist, path_len))
        print(f"  SUCCESS ({len(successful_attempts)}/{min_successful_attempts}) (no obstacles) Path Length: {path_len:.3f}")
else:
    print(f"Warning: Only found {len(successful_attempts)} non-intersecting lines after {max_attempts} attempts")
# Out:
# Attempt 1: hemisphere=right start=(np.float32(59.280334), np.float32(65.73294), np.float32(81.409134)) end=(np.float32(106.32691), np.float32(131.5303), np.float32(82.45339))
#   FAIL - Line intersects obstacles
# Attempt 2: hemisphere=right start=(np.float32(143.66301), np.float32(80.45261), np.float32(126.43423)) end=(np.float32(108.74869), np.float32(130.41978), np.float32(86.08021))
#   SUCCESS (1/100) - Obstacle Distance: 7.111 Path Length: 73.104
# Attempt 3: hemisphere=left start=(np.float32(144.41524), np.float32(98.04911), np.float32(20.204735)) end=(np.float32(107.05571), np.float32(131.14711), np.float32(74.64712))
#   SUCCESS (2/100) - Obstacle Distance: 1.982 Path Length: 73.859
# Attempt 4: hemisphere=left start=(np.float32(125.02705), np.float32(86.12733), np.float32(22.884878)) end=(np.float32(106.75), np.float32(130.73135), np.float32(71.33542))
#   SUCCESS (3/100) - Obstacle Distance: 4.280 Path Length: 68.345
# Attempt 5: hemisphere=right start=(np.float32(160.27318), np.float32(90.59693), np.float32(128.47517)) end=(np.float32(108.368515), np.float32(133.50238), np.float32(82.370895))
#   SUCCESS (4/100) - Obstacle Distance: 5.509 Path Length: 81.612
# Attempt 6: hemisphere=right start=(np.float32(48.098034), np.float32(76.37199), np.float32(79.51404)) end=(np.float32(109.25), np.float32(131.60406), np.float32(84.20154))
#   FAIL - Line intersects obstacles
# Attempt 7: hemisphere=left start=(np.float32(54.254505), np.float32(124.80097), np.float32(68.62195)) end=(np.float32(107.97401), np.float32(129.25), np.float32(71.83677))
#   SUCCESS (5/100) - Obstacle Distance: 2.949 Path Length: 53.999
# Attempt 8: hemisphere=right start=(np.float32(52.866604), np.float32(105.266365), np.float32(116.28297)) end=(np.float32(108.209335), np.float32(133.79066), np.float32(82.50669))
#   SUCCESS (6/100) - Obstacle Distance: 3.096 Path Length: 70.833
# Attempt 9: hemisphere=right start=(np.float32(86.82608), np.float32(119.69095), np.float32(132.22757)) end=(np.float32(108.46177), np.float32(129.72581), np.float32(86.72582))
#   SUCCESS (7/100) - Obstacle Distance: 7.522 Path Length: 51.373
# Attempt 10: hemisphere=left start=(np.float32(107.675316), np.float32(58.741474), np.float32(60.01003)) end=(np.float32(107.147835), np.float32(131.83473), np.float32(71.4369))
#   FAIL - Line intersects obstacles
# Attempt 11: hemisphere=left start=(np.float32(85.7965), np.float32(89.93515), np.float32(36.967274)) end=(np.float32(106.805435), np.float32(131.97319), np.float32(71.917755))
#   FAIL - Line intersects obstacles
# Attempt 12: hemisphere=left start=(np.float32(146.72731), np.float32(84.583405), np.float32(51.72924)) end=(np.float32(109.25), np.float32(130.35976), np.float32(72.07603))
#   FAIL - Line intersects obstacles
# Attempt 13: hemisphere=right start=(np.float32(89.80578), np.float32(65.368996), np.float32(86.7617)) end=(np.float32(107.30803), np.float32(131.38174), np.float32(85.176285))
#   FAIL - Line intersects obstacles
# Attempt 14: hemisphere=left start=(np.float32(103.531075), np.float32(66.17839), np.float32(58.573742)) end=(np.float32(108.35416), np.float32(130.0), np.float32(72.828705))
#   FAIL - Line intersects obstacles
# Attempt 15: hemisphere=left start=(np.float32(95.45587), np.float32(76.78621), np.float32(71.76886)) end=(np.float32(106.0), np.float32(130.69005), np.float32(73.507385))
#   FAIL - Line intersects obstacles
# Attempt 16: hemisphere=left start=(np.float32(53.184875), np.float32(87.63523), np.float32(69.44582)) end=(np.float32(108.0079), np.float32(132.72572), np.float32(72.22572))
#   FAIL - Line intersects obstacles
# Attempt 17: hemisphere=right start=(np.float32(115.53931), np.float32(82.09828), np.float32(131.05933)) end=(np.float32(109.25), np.float32(132.02771), np.float32(83.71494))
#   FAIL - Line intersects obstacles
# Attempt 18: hemisphere=left start=(np.float32(39.81501), np.float32(101.803795), np.float32(67.072525)) end=(np.float32(107.92115), np.float32(129.31126), np.float32(70.51759))
#   SUCCESS (8/100) - Obstacle Distance: 4.204 Path Length: 73.532
# Attempt 19: hemisphere=right start=(np.float32(68.51999), np.float32(126.10578), np.float32(110.07091)) end=(np.float32(107.921135), np.float32(129.63231), np.float32(86.55344))
#   SUCCESS (9/100) - Obstacle Distance: 7.433 Path Length: 46.021
# Attempt 20: hemisphere=left start=(np.float32(65.31258), np.float32(127.77056), np.float32(68.745125)) end=(np.float32(107.5063), np.float32(132.07407), np.float32(71.574066))
#   SUCCESS (10/100) - Obstacle Distance: 4.523 Path Length: 42.507
# Attempt 21: hemisphere=left start=(np.float32(102.725044), np.float32(69.79246), np.float32(37.509754)) end=(np.float32(108.82657), np.float32(132.55887), np.float32(72.13544))
#   SUCCESS (11/100) - Obstacle Distance: 4.194 Path Length: 71.943
# Attempt 22: hemisphere=right start=(np.float32(103.238716), np.float32(67.37101), np.float32(113.18335)) end=(np.float32(109.25), np.float32(131.84622), np.float32(83.66552))
#   FAIL - Line intersects obstacles
# Attempt 23: hemisphere=left start=(np.float32(185.81953), np.float32(124.92636), np.float32(47.88034)) end=(np.float32(108.69765), np.float32(130.61012), np.float32(73.41247))
#   FAIL - Line intersects obstacles
# Attempt 24: hemisphere=right start=(np.float32(144.15376), np.float32(97.373215), np.float32(92.021324)) end=(np.float32(107.29098), np.float32(131.73877), np.float32(84.802216))
#   FAIL - Line intersects obstacles
# Attempt 25: hemisphere=left start=(np.float32(57.871758), np.float32(135.33649), np.float32(59.889027)) end=(np.float32(107.33836), np.float32(130.96829), np.float32(74.37993))
#   SUCCESS (12/100) - Obstacle Distance: 2.008 Path Length: 51.730
# Attempt 26: hemisphere=right start=(np.float32(146.9436), np.float32(90.70978), np.float32(114.23157)) end=(np.float32(108.50972), np.float32(131.93079), np.float32(82.0))
#   FAIL - Line intersects obstacles
# Attempt 27: hemisphere=right start=(np.float32(76.809074), np.float32(67.07264), np.float32(104.74152)) end=(np.float32(108.79055), np.float32(131.3966), np.float32(85.06284))
#   FAIL - Line intersects obstacles
# Attempt 28: hemisphere=left start=(np.float32(89.518036), np.float32(103.443016), np.float32(21.85806)) end=(np.float32(108.70186), np.float32(133.25356), np.float32(73.54458))
#   SUCCESS (13/100) - Obstacle Distance: 3.727 Path Length: 62.675
# Attempt 29: hemisphere=left start=(np.float32(116.08183), np.float32(86.3894), np.float32(25.73805)) end=(np.float32(108.298134), np.float32(133.57948), np.float32(73.62238))
#   SUCCESS (14/100) - Obstacle Distance: 3.977 Path Length: 67.679
# Attempt 30: hemisphere=left start=(np.float32(63.097744), np.float32(124.82022), np.float32(41.9238)) end=(np.float32(107.7449), np.float32(133.7449), np.float32(72.778015))
#   SUCCESS (15/100) - Obstacle Distance: 4.697 Path Length: 55.000
# Attempt 31: hemisphere=right start=(np.float32(133.91605), np.float32(66.963326), np.float32(90.30895)) end=(np.float32(107.294205), np.float32(130.42577), np.float32(82.11844))
#   FAIL - Line intersects obstacles
# Attempt 32: hemisphere=right start=(np.float32(113.68831), np.float32(57.577072), np.float32(95.75856)) end=(np.float32(107.325356), np.float32(131.69426), np.float32(84.8811))
#   FAIL - Line intersects obstacles
# Attempt 33: hemisphere=right start=(np.float32(168.18506), np.float32(109.5617), np.float32(127.05994)) end=(np.float32(107.37008), np.float32(129.25), np.float32(84.593475))
#   FAIL - Line intersects obstacles
# Attempt 34: hemisphere=left start=(np.float32(87.70335), np.float32(59.72214), np.float32(71.1504)) end=(np.float32(108.365456), np.float32(132.31784), np.float32(71.81784))
#   FAIL - Line intersects obstacles
# Attempt 35: hemisphere=right start=(np.float32(157.49536), np.float32(98.1469), np.float32(117.9539)) end=(np.float32(108.382904), np.float32(129.98282), np.float32(86.51718))
#   FAIL - Line intersects obstacles
# Attempt 36: hemisphere=right start=(np.float32(156.2365), np.float32(92.70958), np.float32(133.4479)) end=(np.float32(106.08833), np.float32(130.41167), np.float32(83.23511))
#   SUCCESS (16/100) - Obstacle Distance: 4.680 Path Length: 80.359
# Attempt 37: hemisphere=right start=(np.float32(120.995476), np.float32(59.626175), np.float32(85.98005)) end=(np.float32(108.66513), np.float32(132.46762), np.float32(82.0))
#   FAIL - Line intersects obstacles
# Attempt 38: hemisphere=right start=(np.float32(106.04959), np.float32(97.54848), np.float32(124.93607)) end=(np.float32(107.13815), np.float32(129.25), np.float32(84.45237))
#   SUCCESS (17/100) - Obstacle Distance: 4.561 Path Length: 51.431
# Attempt 39: hemisphere=right start=(np.float32(46.209335), np.float32(122.56679), np.float32(101.13711)) end=(np.float32(107.95228), np.float32(129.7364), np.float32(86.68868))
#   SUCCESS (18/100) - Obstacle Distance: 7.586 Path Length: 63.815
# Attempt 40: hemisphere=left start=(np.float32(196.01337), np.float32(125.98254), np.float32(58.364777)) end=(np.float32(108.221924), np.float32(130.0), np.float32(73.2252))
#   SUCCESS (19/100) - Obstacle Distance: 2.098 Path Length: 89.131
# Attempt 41: hemisphere=left start=(np.float32(141.59267), np.float32(68.45172), np.float32(42.83405)) end=(np.float32(106.21019), np.float32(131.03674), np.float32(74.24694))
#   SUCCESS (20/100) - Obstacle Distance: 2.150 Path Length: 78.457
# Attempt 42: hemisphere=right start=(np.float32(54.273106), np.float32(69.18124), np.float32(92.52763)) end=(np.float32(107.80649), np.float32(130.11447), np.float32(86.192024))
#   FAIL - Line intersects obstacles
# Attempt 43: hemisphere=right start=(np.float32(105.42228), np.float32(85.13874), np.float32(91.22072)) end=(np.float32(108.71948), np.float32(133.28052), np.float32(83.19052))
#   FAIL - Line intersects obstacles
# Attempt 44: hemisphere=left start=(np.float32(156.05675), np.float32(113.538284), np.float32(31.093441)) end=(np.float32(108.71415), np.float32(131.67845), np.float32(71.17845))
#   SUCCESS (21/100) - Obstacle Distance: 4.505 Path Length: 64.631
# Attempt 45: hemisphere=left start=(np.float32(112.67369), np.float32(97.6162), np.float32(32.90097)) end=(np.float32(109.25), np.float32(131.30429), np.float32(73.28587))
#   SUCCESS (22/100) - Obstacle Distance: 1.055 Path Length: 52.702
# Attempt 46: hemisphere=left start=(np.float32(34.53386), np.float32(115.902214), np.float32(70.20722)) end=(np.float32(107.16674), np.float32(130.16446), np.float32(70.83326))
#   SUCCESS (23/100) - Obstacle Distance: 4.429 Path Length: 74.023
# Attempt 47: hemisphere=right start=(np.float32(146.87714), np.float32(123.76702), np.float32(133.57123)) end=(np.float32(107.47749), np.float32(131.96144), np.float32(84.766045))
#   SUCCESS (24/100) - Obstacle Distance: 6.648 Path Length: 63.257
# Attempt 48: hemisphere=right start=(np.float32(99.62457), np.float32(107.293396), np.float32(116.76889)) end=(np.float32(107.67219), np.float32(130.95822), np.float32(82.0))
#   SUCCESS (25/100) - Obstacle Distance: 3.860 Path Length: 42.821
# Attempt 49: hemisphere=right start=(np.float32(150.67555), np.float32(118.74581), np.float32(135.51846)) end=(np.float32(108.13305), np.float32(132.59152), np.float32(82.0))
#   SUCCESS (26/100) - Obstacle Distance: 4.711 Path Length: 69.755
# Attempt 50: hemisphere=left start=(np.float32(184.82591), np.float32(94.744446), np.float32(70.595474)) end=(np.float32(107.65974), np.float32(131.63802), np.float32(71.13802))
#   FAIL - Line intersects obstacles
# Attempt 51: hemisphere=left start=(np.float32(143.7256), np.float32(94.435936), np.float32(37.314713)) end=(np.float32(107.040955), np.float32(129.25003), np.float32(72.75004))
#   SUCCESS (27/100) - Obstacle Distance: 2.370 Path Length: 61.753
# Attempt 52: hemisphere=left start=(np.float32(42.022476), np.float32(91.04434), np.float32(47.288067)) end=(np.float32(106.0), np.float32(131.00815), np.float32(73.42009))
#   FAIL - Line intersects obstacles
# Attempt 53: hemisphere=right start=(np.float32(105.80125), np.float32(72.40896), np.float32(118.27598)) end=(np.float32(107.53937), np.float32(129.6469), np.float32(83.6031))
#   SUCCESS (28/100) - Obstacle Distance: 4.572 Path Length: 66.943
# Attempt 54: hemisphere=left start=(np.float32(151.0319), np.float32(117.32242), np.float32(30.76323)) end=(np.float32(108.289604), np.float32(129.25), np.float32(71.76249))
#   SUCCESS (29/100) - Obstacle Distance: 2.951 Path Length: 60.416
# Attempt 55: hemisphere=left start=(np.float32(175.59526), np.float32(94.62662), np.float32(77.7795)) end=(np.float32(106.0), np.float32(130.0369), np.float32(72.84222))
#   SUCCESS (30/100) - Obstacle Distance: 2.622 Path Length: 78.242
# Attempt 56: hemisphere=right start=(np.float32(118.47293), np.float32(62.30967), np.float32(88.9993)) end=(np.float32(108.2513), np.float32(131.26974), np.float32(85.72895))
#   FAIL - Line intersects obstacles
# Attempt 57: hemisphere=right start=(np.float32(86.25338), np.float32(102.309555), np.float32(119.58129)) end=(np.float32(108.52531), np.float32(129.86804), np.float32(83.907265))
#   SUCCESS (31/100) - Obstacle Distance: 4.930 Path Length: 50.281
# Attempt 58: hemisphere=left start=(np.float32(93.36082), np.float32(99.98475), np.float32(26.112255)) end=(np.float32(108.13485), np.float32(129.25), np.float32(71.49674))
#   SUCCESS (32/100) - Obstacle Distance: 3.225 Path Length: 55.986
# Attempt 59: hemisphere=left start=(np.float32(43.847652), np.float32(108.95975), np.float32(47.263706)) end=(np.float32(106.46307), np.float32(130.562), np.float32(74.02507))
#   SUCCESS (33/100) - Obstacle Distance: 1.971 Path Length: 71.439
# Attempt 60: hemisphere=left start=(np.float32(169.11217), np.float32(87.023476), np.float32(79.43375)) end=(np.float32(107.93086), np.float32(130.99295), np.float32(74.0))
#   FAIL - Line intersects obstacles
# Attempt 61: hemisphere=right start=(np.float32(36.714794), np.float32(96.37494), np.float32(106.022095)) end=(np.float32(107.22004), np.float32(132.93155), np.float32(83.53849))
#   SUCCESS (34/100) - Obstacle Distance: 6.343 Path Length: 82.540
# Attempt 62: hemisphere=right start=(np.float32(155.72505), np.float32(87.899475), np.float32(121.20978)) end=(np.float32(108.69041), np.float32(129.5376), np.float32(84.40282))
#   SUCCESS (35/100) - Obstacle Distance: 5.311 Path Length: 72.806
# Attempt 63: hemisphere=left start=(np.float32(92.44885), np.float32(103.2016), np.float32(29.798656)) end=(np.float32(108.11103), np.float32(132.49539), np.float32(74.0))
#   FAIL - Line intersects obstacles
# Attempt 64: hemisphere=right start=(np.float32(85.57289), np.float32(69.179794), np.float32(111.73336)) end=(np.float32(108.34669), np.float32(131.51483), np.float32(82.08186))
#   SUCCESS (36/100) - Obstacle Distance: 4.156 Path Length: 72.688
# Attempt 65: hemisphere=right start=(np.float32(78.163475), np.float32(93.32177), np.float32(132.84052)) end=(np.float32(106.72593), np.float32(129.63217), np.float32(83.617836))
#   SUCCESS (37/100) - Obstacle Distance: 4.611 Path Length: 67.507
# Attempt 66: hemisphere=left start=(np.float32(102.45053), np.float32(59.879868), np.float32(66.57806)) end=(np.float32(106.75), np.float32(130.64778), np.float32(71.83505))
#   FAIL - Line intersects obstacles
# Attempt 67: hemisphere=right start=(np.float32(49.53043), np.float32(103.76286), np.float32(104.39588)) end=(np.float32(107.56985), np.float32(133.48573), np.float32(82.43015))
#   SUCCESS (38/100) - Obstacle Distance: 5.756 Path Length: 68.808
# Attempt 68: hemisphere=right start=(np.float32(45.391026), np.float32(97.51902), np.float32(110.05533)) end=(np.float32(107.3511), np.float32(129.25), np.float32(84.310005))
#   SUCCESS (39/100) - Obstacle Distance: 5.158 Path Length: 74.221
# Attempt 69: hemisphere=right start=(np.float32(76.582565), np.float32(62.063908), np.float32(82.94982)) end=(np.float32(109.08398), np.float32(131.38177), np.float32(84.78424))
#   FAIL - Line intersects obstacles
# Attempt 70: hemisphere=right start=(np.float32(104.25091), np.float32(81.50913), np.float32(102.847565)) end=(np.float32(107.487404), np.float32(132.14877), np.float32(82.0))
#   SUCCESS (40/100) - Obstacle Distance: 2.569 Path Length: 54.859
# Attempt 71: hemisphere=left start=(np.float32(158.02872), np.float32(104.39074), np.float32(31.911499)) end=(np.float32(107.59158), np.float32(131.10007), np.float32(70.75))
#   SUCCESS (41/100) - Obstacle Distance: 4.839 Path Length: 69.034
# Attempt 72: hemisphere=left start=(np.float32(165.60066), np.float32(130.4188), np.float32(65.934204)) end=(np.float32(107.726715), np.float32(129.85107), np.float32(70.273285))
#   SUCCESS (42/100) - Obstacle Distance: 3.207 Path Length: 58.039
# Attempt 73: hemisphere=left start=(np.float32(109.74207), np.float32(83.171005), np.float32(42.9186)) end=(np.float32(108.02594), np.float32(129.5287), np.float32(70.22129))
#   FAIL - Line intersects obstacles
# Attempt 74: hemisphere=left start=(np.float32(60.48402), np.float32(79.92764), np.float32(60.81204)) end=(np.float32(109.24241), np.float32(130.70598), np.float32(70.69838))
#   FAIL - Line intersects obstacles
# Attempt 75: hemisphere=right start=(np.float32(123.25922), np.float32(61.745266), np.float32(105.07061)) end=(np.float32(106.52579), np.float32(130.0), np.float32(82.89183))
#   FAIL - Line intersects obstacles
# Attempt 76: hemisphere=right start=(np.float32(171.95943), np.float32(93.98192), np.float32(90.42235)) end=(np.float32(106.0), np.float32(131.1324), np.float32(82.76859))
#   SUCCESS (43/100) - Obstacle Distance: 4.717 Path Length: 76.088
# Attempt 77: hemisphere=left start=(np.float32(93.21814), np.float32(67.88088), np.float32(72.955826)) end=(np.float32(109.25), np.float32(131.53946), np.float32(72.68924))
#   FAIL - Line intersects obstacles
# Attempt 78: hemisphere=left start=(np.float32(95.48417), np.float32(88.44262), np.float32(25.155088)) end=(np.float32(107.61792), np.float32(131.31328), np.float32(74.3188))
#   SUCCESS (44/100) - Obstacle Distance: 2.096 Path Length: 66.349
# Attempt 79: hemisphere=left start=(np.float32(98.60715), np.float32(73.79261), np.float32(36.26164)) end=(np.float32(108.12132), np.float32(132.1659), np.float32(74.0))
#   SUCCESS (45/100) - Obstacle Distance: 2.670 Path Length: 70.158
# Attempt 80: hemisphere=left start=(np.float32(75.84568), np.float32(126.816345), np.float32(42.321835)) end=(np.float32(108.52407), np.float32(133.47594), np.float32(73.2098))
#   SUCCESS (46/100) - Obstacle Distance: 4.112 Path Length: 45.457
# Attempt 81: hemisphere=left start=(np.float32(176.30223), np.float32(130.64005), np.float32(30.238756)) end=(np.float32(109.25), np.float32(130.18481), np.float32(71.45368))
#   FAIL - Line intersects obstacles
# Attempt 82: hemisphere=right start=(np.float32(188.00146), np.float32(104.827255), np.float32(98.28983)) end=(np.float32(108.351166), np.float32(132.00941), np.float32(82.0))
#   SUCCESS (47/100) - Obstacle Distance: 4.321 Path Length: 85.723
# Attempt 83: hemisphere=right start=(np.float32(51.63077), np.float32(88.31547), np.float32(81.57079)) end=(np.float32(106.75), np.float32(131.38528), np.float32(84.357))
#   FAIL - Line intersects obstacles
# Attempt 84: hemisphere=left start=(np.float32(43.35902), np.float32(112.84489), np.float32(38.974026)) end=(np.float32(106.33361), np.float32(130.39703), np.float32(73.73065))
#   SUCCESS (48/100) - Obstacle Distance: 2.064 Path Length: 74.040
# Attempt 85: hemisphere=left start=(np.float32(51.625034), np.float32(110.2119), np.float32(62.933487)) end=(np.float32(109.25), np.float32(132.15251), np.float32(73.259476))
#   SUCCESS (49/100) - Obstacle Distance: 3.106 Path Length: 62.519
# Attempt 86: hemisphere=right start=(np.float32(145.91655), np.float32(80.458496), np.float32(124.34455)) end=(np.float32(107.24971), np.float32(129.99486), np.float32(85.99971))
#   SUCCESS (50/100) - Obstacle Distance: 6.972 Path Length: 73.616
# Attempt 87: hemisphere=left start=(np.float32(140.37856), np.float32(78.24896), np.float32(43.39282)) end=(np.float32(109.25), np.float32(130.47548), np.float32(72.30382))
#   FAIL - Line intersects obstacles
# Attempt 88: hemisphere=right start=(np.float32(47.142807), np.float32(112.327446), np.float32(81.13307)) end=(np.float32(107.16095), np.float32(131.59732), np.float32(84.81364))
#   SUCCESS (51/100) - Obstacle Distance: 6.494 Path Length: 63.143
# Attempt 89: hemisphere=right start=(np.float32(149.84888), np.float32(92.79623), np.float32(118.679535)) end=(np.float32(107.30543), np.float32(131.88855), np.float32(84.66688))
#   SUCCESS (52/100) - Obstacle Distance: 6.525 Path Length: 67.045
# Attempt 90: hemisphere=right start=(np.float32(110.04884), np.float32(80.78435), np.float32(107.872536)) end=(np.float32(108.612366), np.float32(130.5645), np.float32(86.0))
#   SUCCESS (53/100) - Obstacle Distance: 5.846 Path Length: 54.392
# Attempt 91: hemisphere=right start=(np.float32(88.193825), np.float32(114.77686), np.float32(126.80921)) end=(np.float32(108.16756), np.float32(133.72017), np.float32(82.387726))
#   SUCCESS (54/100) - Obstacle Distance: 5.714 Path Length: 52.260
# Attempt 92: hemisphere=left start=(np.float32(163.55678), np.float32(71.9366), np.float32(66.21994)) end=(np.float32(108.91098), np.float32(132.32173), np.float32(73.83902))
#   FAIL - Line intersects obstacles
# Attempt 93: hemisphere=left start=(np.float32(183.85628), np.float32(97.34125), np.float32(69.82714)) end=(np.float32(106.75), np.float32(130.40984), np.float32(71.8724))
#   FAIL - Line intersects obstacles
# Attempt 94: hemisphere=left start=(np.float32(118.76023), np.float32(85.27599), np.float32(48.0764)) end=(np.float32(108.29731), np.float32(133.62035), np.float32(72.66765))
#   SUCCESS (55/100) - Obstacle Distance: 4.590 Path Length: 55.239
# Attempt 95: hemisphere=right start=(np.float32(104.63116), np.float32(99.51991), np.float32(130.13345)) end=(np.float32(107.9106), np.float32(130.10783), np.float32(86.30277))
#   SUCCESS (56/100) - Obstacle Distance: 5.914 Path Length: 53.549
# Attempt 96: hemisphere=right start=(np.float32(128.03975), np.float32(66.64542), np.float32(90.72134)) end=(np.float32(107.989716), np.float32(129.5485), np.float32(83.70151))
#   FAIL - Line intersects obstacles
# Attempt 97: hemisphere=right start=(np.float32(100.01624), np.float32(71.5193), np.float32(109.980835)) end=(np.float32(107.61911), np.float32(130.39323), np.float32(86.0))
#   SUCCESS (57/100) - Obstacle Distance: 7.082 Path Length: 64.024
# Attempt 98: hemisphere=left start=(np.float32(143.58495), np.float32(110.3905), np.float32(34.850266)) end=(np.float32(106.28629), np.float32(129.80284), np.float32(73.089134))
#   SUCCESS (58/100) - Obstacle Distance: 2.305 Path Length: 56.835
# Attempt 99: hemisphere=right start=(np.float32(182.42079), np.float32(109.647224), np.float32(94.963745)) end=(np.float32(108.73112), np.float32(130.8357), np.float32(83.14542))
#   SUCCESS (59/100) - Obstacle Distance: 4.675 Path Length: 77.581
# Attempt 100: hemisphere=right start=(np.float32(28.535858), np.float32(97.81364), np.float32(85.933426)) end=(np.float32(108.39507), np.float32(130.09534), np.float32(83.54974))
#   FAIL - Line intersects obstacles
# Attempt 101: hemisphere=left start=(np.float32(158.1162), np.float32(105.798256), np.float32(73.40446)) end=(np.float32(108.500244), np.float32(129.27075), np.float32(70.47925))
#   FAIL - Line intersects obstacles
# Attempt 102: hemisphere=right start=(np.float32(35.475735), np.float32(83.98441), np.float32(80.104774)) end=(np.float32(108.17882), np.float32(131.88654), np.float32(82.0))
#   FAIL - Line intersects obstacles
# Attempt 103: hemisphere=left start=(np.float32(98.45235), np.float32(105.88956), np.float32(43.100327)) end=(np.float32(106.0919), np.float32(129.9781), np.float32(72.13621))
#   SUCCESS (60/100) - Obstacle Distance: 3.264 Path Length: 38.493
# Attempt 104: hemisphere=right start=(np.float32(74.35659), np.float32(115.994286), np.float32(120.56992)) end=(np.float32(106.91463), np.float32(132.7089), np.float32(83.45574))
#   SUCCESS (61/100) - Obstacle Distance: 6.136 Path Length: 52.124
# Attempt 105: hemisphere=right start=(np.float32(65.60457), np.float32(116.44772), np.float32(113.95982)) end=(np.float32(108.010475), np.float32(133.8763), np.float32(82.38677))
#   SUCCESS (62/100) - Obstacle Distance: 5.859 Path Length: 55.668
# Attempt 106: hemisphere=right start=(np.float32(66.15467), np.float32(136.76456), np.float32(83.575676)) end=(np.float32(109.18649), np.float32(132.4577), np.float32(83.605804))
#   SUCCESS (63/100) - Obstacle Distance: 5.788 Path Length: 43.247
# Attempt 107: hemisphere=left start=(np.float32(96.236046), np.float32(74.9274), np.float32(56.96386)) end=(np.float32(106.55084), np.float32(129.73384), np.float32(71.46531))
#   SUCCESS (64/100) - Obstacle Distance: 0.937 Path Length: 57.623
# Attempt 108: hemisphere=right start=(np.float32(132.99797), np.float32(71.40037), np.float32(90.54876)) end=(np.float32(106.056946), np.float32(130.44305), np.float32(82.67782))
#   FAIL - Line intersects obstacles
# Attempt 109: hemisphere=left start=(np.float32(79.188614), np.float32(68.095276), np.float32(64.050255)) end=(np.float32(107.24142), np.float32(130.8124), np.float32(70.75858))
#   FAIL - Line intersects obstacles
# Attempt 110: hemisphere=right start=(np.float32(51.34012), np.float32(119.71035), np.float32(110.47001)) end=(np.float32(107.71697), np.float32(131.55255), np.float32(85.41442))
#   SUCCESS (65/100) - Obstacle Distance: 3.026 Path Length: 62.820
# Attempt 111: hemisphere=left start=(np.float32(120.26373), np.float32(83.96912), np.float32(78.59134)) end=(np.float32(107.06194), np.float32(129.93092), np.float32(70.93806))
#   FAIL - Line intersects obstacles
# Attempt 112: hemisphere=right start=(np.float32(137.13298), np.float32(74.41519), np.float32(106.717476)) end=(np.float32(107.62705), np.float32(133.62706), np.float32(83.240685))
#   FAIL - Line intersects obstacles
# Attempt 113: hemisphere=left start=(np.float32(76.819435), np.float32(78.997444), np.float32(36.661266)) end=(np.float32(106.775475), np.float32(131.42496), np.float32(71.399475))
#   SUCCESS (66/100) - Obstacle Distance: 4.550 Path Length: 69.662
# Attempt 114: hemisphere=left start=(np.float32(152.82825), np.float32(96.487915), np.float32(47.038486)) end=(np.float32(108.10895), np.float32(129.5323), np.float32(70.217705))
#   SUCCESS (67/100) - Obstacle Distance: 4.516 Path Length: 60.241
# Attempt 115: hemisphere=right start=(np.float32(99.661316), np.float32(113.45805), np.float32(121.252495)) end=(np.float32(106.73448), np.float32(131.98448), np.float32(82.73547))
#   SUCCESS (68/100) - Obstacle Distance: 5.131 Path Length: 43.322
# Attempt 116: hemisphere=right start=(np.float32(69.96527), np.float32(81.21025), np.float32(112.93456)) end=(np.float32(106.22926), np.float32(130.52347), np.float32(82.27074))
#   SUCCESS (69/100) - Obstacle Distance: 3.916 Path Length: 68.463
# Attempt 117: hemisphere=left start=(np.float32(51.257435), np.float32(80.581764), np.float32(55.671764)) end=(np.float32(107.96675), np.float32(129.83418), np.float32(72.61743))
#   FAIL - Line intersects obstacles
# Attempt 118: hemisphere=right start=(np.float32(66.00569), np.float32(107.15206), np.float32(131.72014)) end=(np.float32(107.06541), np.float32(131.19101), np.float32(85.12439))
#   SUCCESS (70/100) - Obstacle Distance: 6.572 Path Length: 66.595
# Attempt 119: hemisphere=left start=(np.float32(110.639275), np.float32(104.62466), np.float32(27.234507)) end=(np.float32(107.644), np.float32(131.46593), np.float32(74.14008))
#   SUCCESS (71/100) - Obstacle Distance: 2.284 Path Length: 54.125
# Attempt 120: hemisphere=left start=(np.float32(123.03396), np.float32(69.76911), np.float32(75.47407)) end=(np.float32(108.46569), np.float32(129.60286), np.float32(70.14714))
#   FAIL - Line intersects obstacles
# Attempt 121: hemisphere=right start=(np.float32(54.360184), np.float32(109.10326), np.float32(116.38392)) end=(np.float32(108.81161), np.float32(131.10864), np.float32(85.32975))
#   FAIL - Line intersects obstacles
# Attempt 122: hemisphere=left start=(np.float32(99.21464), np.float32(81.52082), np.float32(35.831177)) end=(np.float32(107.41308), np.float32(130.61302), np.float32(74.0))
#   SUCCESS (72/100) - Obstacle Distance: 1.996 Path Length: 62.723
# Attempt 123: hemisphere=right start=(np.float32(180.4287), np.float32(110.52864), np.float32(102.03854)) end=(np.float32(106.39809), np.float32(131.64809), np.float32(83.05593))
#   SUCCESS (73/100) - Obstacle Distance: 3.154 Path Length: 79.290
# Attempt 124: hemisphere=left start=(np.float32(168.95914), np.float32(94.33164), np.float32(77.8053)) end=(np.float32(107.06624), np.float32(130.16573), np.float32(70.93376))
#   SUCCESS (74/100) - Obstacle Distance: 4.384 Path Length: 71.847
# Attempt 125: hemisphere=left start=(np.float32(79.12399), np.float32(60.629913), np.float32(69.76092)) end=(np.float32(107.7912), np.float32(133.7912), np.float32(73.33918))
#   FAIL - Line intersects obstacles
# Attempt 126: hemisphere=left start=(np.float32(92.877884), np.float32(103.00484), np.float32(30.70928)) end=(np.float32(108.29188), np.float32(129.37616), np.float32(70.37384))
#   FAIL - Line intersects obstacles
# Attempt 127: hemisphere=right start=(np.float32(104.146736), np.float32(84.31441), np.float32(112.50651)) end=(np.float32(109.25), np.float32(130.68567), np.float32(84.05288))
#   FAIL - Line intersects obstacles
# Attempt 128: hemisphere=right start=(np.float32(162.46437), np.float32(128.31172), np.float32(118.30141)) end=(np.float32(106.0), np.float32(130.9586), np.float32(82.50359))
#   FAIL - Line intersects obstacles
# Attempt 129: hemisphere=right start=(np.float32(176.67896), np.float32(108.526115), np.float32(91.48422)) end=(np.float32(107.60014), np.float32(131.56944), np.float32(82.0))
#   SUCCESS (75/100) - Obstacle Distance: 4.292 Path Length: 73.436
# Attempt 130: hemisphere=left start=(np.float32(88.01603), np.float32(97.322914), np.float32(28.27971)) end=(np.float32(106.57251), np.float32(130.92935), np.float32(72.17749))
#   SUCCESS (76/100) - Obstacle Distance: 3.628 Path Length: 58.316
# Attempt 131: hemisphere=right start=(np.float32(130.34377), np.float32(69.8994), np.float32(93.26328)) end=(np.float32(107.6002), np.float32(130.74481), np.float32(82.105385))
#   FAIL - Line intersects obstacles
# Attempt 132: hemisphere=right start=(np.float32(122.352036), np.float32(65.59123), np.float32(92.68413)) end=(np.float32(106.54905), np.float32(131.44461), np.float32(83.60444))
#   FAIL - Line intersects obstacles
# Attempt 133: hemisphere=left start=(np.float32(149.08096), np.float32(82.94868), np.float32(75.35968)) end=(np.float32(107.254456), np.float32(129.659), np.float32(73.15454))
#   FAIL - Line intersects obstacles
# Attempt 134: hemisphere=right start=(np.float32(47.161186), np.float32(123.96864), np.float32(105.41498)) end=(np.float32(106.880196), np.float32(130.03972), np.float32(85.630196))
#   SUCCESS (77/100) - Obstacle Distance: 6.637 Path Length: 63.203
# Attempt 135: hemisphere=right start=(np.float32(63.887596), np.float32(77.71434), np.float32(97.839)) end=(np.float32(108.742714), np.float32(130.07462), np.float32(83.91809))
#   SUCCESS (78/100) - Obstacle Distance: 3.656 Path Length: 70.338
# Attempt 136: hemisphere=left start=(np.float32(109.407295), np.float32(86.90904), np.float32(30.828032)) end=(np.float32(109.199196), np.float32(131.18326), np.float32(71.132454))
#   SUCCESS (79/100) - Obstacle Distance: 4.360 Path Length: 59.872
# Attempt 137: hemisphere=right start=(np.float32(102.23342), np.float32(93.30667), np.float32(128.22423)) end=(np.float32(107.81161), np.float32(133.81161), np.float32(82.86755))
#   SUCCESS (80/100) - Obstacle Distance: 6.199 Path Length: 61.065
# Attempt 138: hemisphere=left start=(np.float32(162.8872), np.float32(114.407845), np.float32(40.19733)) end=(np.float32(109.08831), np.float32(132.06279), np.float32(73.66169))
#   FAIL - Line intersects obstacles
# Attempt 139: hemisphere=left start=(np.float32(54.179512), np.float32(88.33521), np.float32(53.028763)) end=(np.float32(106.2503), np.float32(129.49971), np.float32(72.10102))
#   FAIL - Line intersects obstacles
# Attempt 140: hemisphere=right start=(np.float32(130.11043), np.float32(62.886555), np.float32(85.66231)) end=(np.float32(109.25), np.float32(130.06741), np.float32(85.48652))
#   FAIL - Line intersects obstacles
# Attempt 141: hemisphere=left start=(np.float32(102.14424), np.float32(61.85188), np.float32(74.585106)) end=(np.float32(107.497055), np.float32(130.73132), np.float32(70.73427))
#   FAIL - Line intersects obstacles
# Attempt 142: hemisphere=right start=(np.float32(82.985756), np.float32(66.03971), np.float32(104.026726)) end=(np.float32(109.1201), np.float32(132.8799), np.float32(82.895325))
#   SUCCESS (81/100) - Obstacle Distance: 5.409 Path Length: 74.814
# Attempt 143: hemisphere=left start=(np.float32(161.10255), np.float32(101.28425), np.float32(52.616684)) end=(np.float32(108.07562), np.float32(131.06155), np.float32(74.0))
#   FAIL - Line intersects obstacles
# Attempt 144: hemisphere=left start=(np.float32(111.55472), np.float32(107.087006), np.float32(41.210884)) end=(np.float32(108.08231), np.float32(130.06859), np.float32(73.486275))
#   SUCCESS (82/100) - Obstacle Distance: 1.897 Path Length: 39.773
# Attempt 145: hemisphere=left start=(np.float32(181.47939), np.float32(109.04636), np.float32(71.98745)) end=(np.float32(109.25), np.float32(131.14099), np.float32(72.5725))
#   SUCCESS (83/100) - Obstacle Distance: 3.017 Path Length: 75.535
# Attempt 146: hemisphere=left start=(np.float32(136.44017), np.float32(88.80915), np.float32(24.390802)) end=(np.float32(107.342735), np.float32(130.22766), np.float32(73.72766))
#   FAIL - Line intersects obstacles
# Attempt 147: hemisphere=left start=(np.float32(169.41225), np.float32(116.07933), np.float32(29.238419)) end=(np.float32(107.73612), np.float32(129.65613), np.float32(72.670006))
#   SUCCESS (84/100) - Obstacle Distance: 2.521 Path Length: 76.646
# Attempt 148: hemisphere=right start=(np.float32(168.18773), np.float32(93.79606), np.float32(120.26666)) end=(np.float32(108.143906), np.float32(129.52599), np.float32(86.52599))
#   FAIL - Line intersects obstacles
# Attempt 149: hemisphere=left start=(np.float32(54.81603), np.float32(131.53664), np.float32(68.23586)) end=(np.float32(106.683334), np.float32(131.34949), np.float32(72.16616))
#   SUCCESS (85/100) - Obstacle Distance: 3.877 Path Length: 52.016
# Attempt 150: hemisphere=left start=(np.float32(152.28162), np.float32(80.49615), np.float32(56.296417)) end=(np.float32(108.43218), np.float32(133.56781), np.float32(73.497856))
#   FAIL - Line intersects obstacles
# Attempt 151: hemisphere=right start=(np.float32(34.84713), np.float32(106.787186), np.float32(113.43018)) end=(np.float32(108.30991), np.float32(129.25), np.float32(86.146065))
#   SUCCESS (86/100) - Obstacle Distance: 6.902 Path Length: 81.522
# Attempt 152: hemisphere=left start=(np.float32(66.13214), np.float32(133.68324), np.float32(66.62147)) end=(np.float32(109.1818), np.float32(130.19478), np.float32(72.51297))
#   SUCCESS (87/100) - Obstacle Distance: 2.773 Path Length: 43.591
# Attempt 153: hemisphere=left start=(np.float32(125.99803), np.float32(61.440586), np.float32(78.30093)) end=(np.float32(106.0), np.float32(129.77051), np.float32(72.694786))
#   FAIL - Line intersects obstacles
# Attempt 154: hemisphere=right start=(np.float32(183.78511), np.float32(128.51634), np.float32(122.22149)) end=(np.float32(107.71008), np.float32(130.0), np.float32(83.237785))
#   FAIL - Line intersects obstacles
# Attempt 155: hemisphere=left start=(np.float32(136.51521), np.float32(73.71469), np.float32(33.885944)) end=(np.float32(108.68526), np.float32(129.63792), np.float32(70.112076))
#   SUCCESS (88/100) - Obstacle Distance: 4.603 Path Length: 72.210
# Attempt 156: hemisphere=left start=(np.float32(97.53787), np.float32(69.3756), np.float32(43.228798)) end=(np.float32(108.406204), np.float32(129.25), np.float32(71.5664))
#   SUCCESS (89/100) - Obstacle Distance: 3.118 Path Length: 67.127
# Attempt 157: hemisphere=right start=(np.float32(108.99532), np.float32(89.074234), np.float32(122.014084)) end=(np.float32(108.021935), np.float32(130.33739), np.float32(86.16262))
#   SUCCESS (90/100) - Obstacle Distance: 7.221 Path Length: 54.671
# Attempt 158: hemisphere=right start=(np.float32(115.35145), np.float32(110.620155), np.float32(134.50981)) end=(np.float32(108.79462), np.float32(130.87059), np.float32(85.584785))
#   SUCCESS (91/100) - Obstacle Distance: 3.760 Path Length: 53.355
# Attempt 159: hemisphere=left start=(np.float32(70.507545), np.float32(90.59126), np.float32(43.3312)) end=(np.float32(109.25), np.float32(131.59079), np.float32(71.597565))
#   SUCCESS (92/100) - Obstacle Distance: 4.090 Path Length: 63.095
# Attempt 160: hemisphere=left start=(np.float32(53.299614), np.float32(133.98239), np.float32(62.703133)) end=(np.float32(108.36938), np.float32(132.77617), np.float32(74.0))
#   SUCCESS (93/100) - Obstacle Distance: 3.097 Path Length: 56.229
# Attempt 161: hemisphere=left start=(np.float32(131.03175), np.float32(59.00529), np.float32(76.54696)) end=(np.float32(107.49071), np.float32(131.38107), np.float32(74.37822))
#   FAIL - Line intersects obstacles
# Attempt 162: hemisphere=left start=(np.float32(114.5846), np.float32(65.818924), np.float32(59.501614)) end=(np.float32(109.25), np.float32(130.45152), np.float32(71.2049))
#   FAIL - Line intersects obstacles
# Attempt 163: hemisphere=right start=(np.float32(130.17119), np.float32(78.59823), np.float32(130.16667)) end=(np.float32(108.88342), np.float32(130.13927), np.float32(83.994156))
#   FAIL - Line intersects obstacles
# Attempt 164: hemisphere=right start=(np.float32(134.45065), np.float32(94.32921), np.float32(129.48824)) end=(np.float32(108.93792), np.float32(130.77351), np.float32(83.4144))
#   SUCCESS (94/100) - Obstacle Distance: 4.869 Path Length: 64.046
# Attempt 165: hemisphere=right start=(np.float32(109.59514), np.float32(93.40508), np.float32(132.79482)) end=(np.float32(109.25), np.float32(129.89803), np.float32(84.84707))
#   SUCCESS (95/100) - Obstacle Distance: 5.684 Path Length: 60.256
# Attempt 166: hemisphere=left start=(np.float32(126.73687), np.float32(85.06854), np.float32(45.27597)) end=(np.float32(106.75), np.float32(131.65428), np.float32(71.72258))
#   FAIL - Line intersects obstacles
# Attempt 167: hemisphere=right start=(np.float32(88.935776), np.float32(67.68129), np.float32(114.12361)) end=(np.float32(109.23447), np.float32(130.75804), np.float32(83.72642))
#   SUCCESS (96/100) - Obstacle Distance: 5.131 Path Length: 72.902
# Attempt 168: hemisphere=right start=(np.float32(97.128365), np.float32(121.36184), np.float32(125.069)) end=(np.float32(107.080826), np.float32(131.83328), np.float32(82.00246))
#   SUCCESS (97/100) - Obstacle Distance: 4.483 Path Length: 45.425
# Attempt 169: hemisphere=left start=(np.float32(173.7248), np.float32(100.801056), np.float32(80.61208)) end=(np.float32(106.21039), np.float32(130.70753), np.float32(73.91792))
#   FAIL - Line intersects obstacles
# Attempt 170: hemisphere=right start=(np.float32(155.3056), np.float32(63.069183), np.float32(92.43586)) end=(np.float32(107.58143), np.float32(130.40028), np.float32(86.0))
#   FAIL - Line intersects obstacles
# Attempt 171: hemisphere=left start=(np.float32(67.03072), np.float32(94.51659), np.float32(66.03255)) end=(np.float32(109.25), np.float32(129.98003), np.float32(70.9079))
#   FAIL - Line intersects obstacles
# Attempt 172: hemisphere=right start=(np.float32(150.30351), np.float32(93.89604), np.float32(119.40771)) end=(np.float32(107.071846), np.float32(129.25), np.float32(84.27527))
#   SUCCESS (98/100) - Obstacle Distance: 5.127 Path Length: 65.979
# Attempt 173: hemisphere=right start=(np.float32(38.334858), np.float32(101.3136), np.float32(83.95469)) end=(np.float32(107.98815), np.float32(131.76007), np.float32(85.47807))
#   FAIL - Line intersects obstacles
# Attempt 174: hemisphere=right start=(np.float32(154.43929), np.float32(62.837864), np.float32(91.65478)) end=(np.float32(109.25), np.float32(131.01404), np.float32(83.663826))
#   FAIL - Line intersects obstacles
# Attempt 175: hemisphere=right start=(np.float32(168.53018), np.float32(83.00013), np.float32(103.30272)) end=(np.float32(107.5), np.float32(133.28569), np.float32(82.57766))
#   FAIL - Line intersects obstacles
# Attempt 176: hemisphere=right start=(np.float32(86.985435), np.float32(119.754005), np.float32(132.27133)) end=(np.float32(107.766495), np.float32(129.62305), np.float32(86.38954))
#   SUCCESS (99/100) - Obstacle Distance: 7.270 Path Length: 51.326
# Attempt 177: hemisphere=left start=(np.float32(52.375053), np.float32(120.66924), np.float32(42.364655)) end=(np.float32(106.18313), np.float32(131.43314), np.float32(74.20232))
#   SUCCESS (100/100) - Obstacle Distance: 2.476 Path Length: 63.441

# %% [markdown]
# ### Select Optimal Path
#
# Find the best path among successful attempts by maximizing distance from obstacles.

# %%
# Select best path (maximum obstacle distance; tie-breaker shorter path length)
best_path = None
suboptimal_lines = []
selected_hemisphere = None

if successful_attempts:
    # Sort: first by obstacle distance desc, then by path length asc
    successful_attempts.sort(key=lambda x: (-x[3], x[4]))

    best_hemi, best_start, best_end, best_obstacle_dist, best_path_len = successful_attempts[0]
    best_path = Line([best_start, best_end]).c("green").lw(BEST_PATH_WIDTH)
    selected_hemisphere = best_hemi
    print(f"\nBest path: hemisphere={best_hemi} obstacle_dist={best_obstacle_dist:.3f} path_len={best_path_len:.3f}")

    max_suboptimal_paths = 10
    s = 1
    for hemi, start_pt, end_pt, obstacle_dist, path_len in successful_attempts[1:]:
        if s > max_suboptimal_paths:
            break
        
        suboptimal_line = Line([start_pt, end_pt]).c("yellow").alpha(0.3).lw(SUBOPTIMAL_PATH_WIDTH)
        suboptimal_lines.append(suboptimal_line)
        print(f"Suboptimal path {s}: hemi={hemi} obstacle_dist={obstacle_dist:.3f} path_len={path_len:.3f}")
        
        s += 1
else:
    print("No successful paths found!")

print("\nTotal successful paths: ", len(successful_attempts))
# Out:
# Best path: hemisphere=right obstacle_dist=7.586 path_len=63.815
# Suboptimal path 1: hemi=right obstacle_dist=7.522 path_len=51.373
# Suboptimal path 2: hemi=right obstacle_dist=7.433 path_len=46.021
# Suboptimal path 3: hemi=right obstacle_dist=7.270 path_len=51.326
# Suboptimal path 4: hemi=right obstacle_dist=7.221 path_len=54.671
# Suboptimal path 5: hemi=right obstacle_dist=7.111 path_len=73.104
# Suboptimal path 6: hemi=right obstacle_dist=7.082 path_len=64.024
# Suboptimal path 7: hemi=right obstacle_dist=6.972 path_len=73.616
# Suboptimal path 8: hemi=right obstacle_dist=6.902 path_len=81.522
# Suboptimal path 9: hemi=right obstacle_dist=6.648 path_len=63.257
# Suboptimal path 10: hemi=right obstacle_dist=6.637 path_len=63.203
#
# Total successful paths:  100

# %%
## Save Monte Carlo path coordinates to file (success + fail + best flag)
output_file = "monte_carlo_paths.csv"
with open(output_file, 'w') as f:
    f.write("hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,obstacle_distance,path_length,status,is_best\n")
    # Successful attempts are already sorted (best first) after selection step
    for idx, (hemi, start_pt, end_pt, obstacle_dist, path_len) in enumerate(successful_attempts):
        is_best = 1 if idx == 0 else 0
        f.write(
            f"{hemi},{start_pt[0]},{start_pt[1]},{start_pt[2]},{end_pt[0]},{end_pt[1]},{end_pt[2]},{obstacle_dist},{path_len},success,{is_best}\n"
        )
    # Failed attempts
    for hemi, start_pt, end_pt, obstacle_dist, path_len in failed_attempts:
        f.write(
            f"{hemi},{start_pt[0]},{start_pt[1]},{start_pt[2]},{end_pt[0]},{end_pt[1]},{end_pt[2]},{obstacle_dist},{path_len},fail,0\n"
        )
print(f"Saved Monte Carlo paths ({len(successful_attempts)} success, {len(failed_attempts)} fail) to {output_file}")
# Out:
# Saved Monte Carlo paths (100 success, 77 fail) to monte_carlo_paths.csv

# %% [markdown]
# ## 3. Weighted Sum + Nelder-Mead Optimization

# %% [markdown]
# ### Configuration
#
# Set weights and optimization parameters:
# - `w_obstacle`: Weight for obstacle distance (maximize)
# - `w_path_length`: Weight for path length (minimize)
# - Weights are normalized automatically
# - `n_initial`: Number of best Monte Carlo paths to use as initial conditions

# %%
# Weights for multi-objective optimization (easily configurable)
w_obstacle = 0.9     # Weight for obstacle distance (higher = prefer safer paths)
w_path_length = 0.1   # Weight for path length (higher = prefer shorter paths)

# Normalize weights to sum to 1
total_weight = w_obstacle + w_path_length
w_obstacle_norm = w_obstacle / total_weight
w_path_length_norm = w_path_length / total_weight

print(f"Objective function weights:\n  Obstacle distance: {w_obstacle_norm:.3f}\n  Path length: {w_path_length_norm:.3f}")

# Nelder-Mead parameters
initial_point_attempts = 50
nm_max_iterations = 500
nm_tolerance = 1e-6  # default: 1e-6, applied as xatol and fatol

# Hemisphere lock for optimization (set later when picking x0)
nm_hemisphere = None

# Number of best Monte Carlo paths to use as initial conditions
n_initial = 10
# Out:
# Objective function weights:
#   Obstacle distance: 0.900
#   Path length: 0.100

# %% [markdown]
# ### Weighted Sum Objective Function
#
# Combines both objectives (obstacle distance and path length) into a single scalar value for optimization.

# %%
# Global variables for normalization (will be computed from sample paths)
max_obstacle_dist = None
max_path_length = None

def weighted_sum_objective(x):
    """
    Weighted sum objective function for optimization.

    Parameters:
    -----------
    x : array-like, shape (6,)
        [start_x, start_y, start_z, end_x, end_y, end_z]

    Returns:
    --------
    float : Objective value (to be minimized)
    """
    global nm_hemisphere
    start_guess = tuple(x[:3])
    end_guess = tuple(x[3:])

    # If hemisphere not set, infer a reasonable default
    if nm_hemisphere is None:
        nm_hemisphere = 'left' if merged_left_entry_zone and merged_left_stn else 'right'

    # Project guesses to valid surfaces for the locked hemisphere
    start_point, end_point = project_to_surfaces(start_guess, end_guess, nm_hemisphere)

    # Hard constraint: penalize intersection
    if check_intersection(start_point, end_point):
        return 1e10

    # Compute objectives
    obstacle_dist = compute_obstacle_distance(start_point, end_point)
    path_length = compute_path_length(start_point, end_point)

    # Normalize objectives
    if max_obstacle_dist is not None and max_obstacle_dist > 0:
        norm_obstacle_dist = obstacle_dist / max_obstacle_dist
    else:
        norm_obstacle_dist = obstacle_dist / 100.0

    if max_path_length is not None and max_path_length > 0:
        norm_path_length = path_length / max_path_length
    else:
        norm_path_length = path_length / 200.0

    # Weighted sum: minimize (-obstacle_dist) and minimize path_length
    objective = -w_obstacle_norm * norm_obstacle_dist + w_path_length_norm * norm_path_length
    return objective

# %% [markdown]
# ### Estimate Normalization Constants
#
# Sample a few random paths to estimate typical ranges for obstacle distance and path length.

# %%
# ## OPTION 1 - Sample random paths to estimate normalization constants
# ESTIMATION_SAMPLES = 100

# print("Estimating normalization constants from random samples...")
# sample_obstacle_dists = []
# sample_path_lengths = []

# for _ in range(ESTIMATION_SAMPLES):
#     print(f"Sampling path {_+1}/{ESTIMATION_SAMPLES}...")
#     hemi, start, end = sample_start_and_end()
#     if not check_intersection(start, end):
#         obstacle_dist = compute_obstacle_distance(start, end)
#         path_length = compute_path_length(start, end)
#         sample_obstacle_dists.append(obstacle_dist)
#         sample_path_lengths.append(path_length)
#         # print(f"  obstacle_dist={obstacle_dist:.3f} path_len={path_length:.3f}")
#     else:
#         print("  Sampled path intersects obstacles, skipping...")

# if sample_obstacle_dists:
#     max_obstacle_dist = max(sample_obstacle_dists)
#     max_path_length = max(sample_path_lengths)
#     print(f"Estimated max obstacle distance: {max_obstacle_dist:.2f}")
#     print(f"Estimated max path length: {max_path_length:.2f}")
# else:
#     print("Warning: No valid paths found for normalization, using defaults")
#     max_obstacle_dist = 8
#     max_path_length = 100

# %%
## OPTION 2: Use Monte Carlo results for normalization (if available)
if successful_attempts:
    print("\nUsing Monte Carlo results for normalization...")
    mc_obstacle_dists = [x[3] for x in successful_attempts]
    mc_path_lengths = [x[4] for x in successful_attempts]
    max_obstacle_dist = max(mc_obstacle_dists)
    max_path_length = max(mc_path_lengths)
    print(f"Max obstacle distance from Monte Carlo: {max_obstacle_dist:.2f}")
    print(f"Max path length from Monte Carlo: {max_path_length:.2f}")
else:
    print("\nNo Monte Carlo results available for normalization, using defaults")
    max_obstacle_dist = 8
    max_path_length = 100
# Out:
# Using Monte Carlo results for normalization...
# Max obstacle distance from Monte Carlo: 7.59
# Max path length from Monte Carlo: 89.13

# %% [markdown]
# ### Set Initial Path for Optimization
#
# Also select a configurable number of best Monte Carlo paths as initial conditions (`initial_paths`).

# %%
# ## OPTION 1: Find first n_initial feasible initial points from random sampling
# print("\nFinding feasible initial points...")
# initial_paths = []  # list of tuples (hemi, start, end, obstacle_dist, path_len)
# attempts = 0
# while len(initial_paths) < n_initial and attempts < initial_point_attempts:
#     hemi, start, end = sample_start_and_end()
#     attempts += 1
#     if not check_intersection(start, end):
#         path_len = compute_path_length(start, end)
#         obstacle_dist = compute_obstacle_distance(start, end)
#         initial_paths.append((hemi, start, end, obstacle_dist, path_len))
#         print(f"  Feasible {len(initial_paths)}/{n_initial}: hemi={hemi} obstacle={obstacle_dist:.3f} length={path_len:.3f}")
#     else:
#         print("  Sampled path intersects obstacles, skipping...")

# if not initial_paths:
#     print("Warning: Could not find any feasible starting points; will fall back to Monte Carlo best if available.")

# %%
## OPTION 2: Select best Monte Carlo path(s) as starting point(s)
if successful_attempts:
    print("\nSelecting initial conditions from best Monte Carlo paths...")
    # successful_attempts is already sorted earlier (best first)
    take = min(n_initial, len(successful_attempts))
    initial_paths = successful_attempts[:take]
    print(f"  Using {take} initial path(s) from Monte Carlo results")
    
    # Update selected hemisphere preview from the first initial path
    selected_hemisphere = initial_paths[0][0]
else:
    raise RuntimeError("No successful Monte Carlo paths available for optimization initialization.")
# Out:
# Selecting initial conditions from best Monte Carlo paths...
#   Using 10 initial path(s) from Monte Carlo results

# %% [markdown]
# ### Mono-criteria optimization function

# %% [markdown]
# Function to optimize with multiple initial conditions given a specific method.
#
# Methods: Nelder-Mead, Powell, or Cobyla.

# %%
import time

def run_multistart(method_name, options):
    """Run chosen optimization method over all initial_paths and return best record.

    Returns:
      best_record, records_list
    Prints per-start info plus total elapsed time and summed iterations across starts.
    """
    if not initial_paths:
        raise RuntimeError("initial_paths is empty. Ensure Monte Carlo step ran and initial paths were selected.")

    best = None
    records = []
    total_time = 0.0
    total_iterations = 0

    for idx, (hemi, start, end, obst, plen) in enumerate(initial_paths, start=1):
        print(f"\n[{method_name} {idx}/{len(initial_paths)}] hemi={hemi}")
        global nm_hemisphere
        nm_hemisphere = hemi  # hemisphere locking
        x0 = np.concatenate([start, end])
        t0 = time.perf_counter()
        res = minimize(weighted_sum_objective, x0, method=method_name, options=options)
        elapsed = time.perf_counter() - t0
        iters = getattr(res, 'nit', getattr(res, 'nfev', 0)) or 0
        total_time += elapsed
        total_iterations += iters

        raw_start = tuple(res.x[:3])
        raw_end = tuple(res.x[3:])
        opt_start, opt_end = project_to_surfaces(raw_start, raw_end, nm_hemisphere)
        opt_obj = float(res.fun)
        opt_obst = compute_obstacle_distance(opt_start, opt_end)
        opt_len = compute_path_length(opt_start, opt_end)
        opt_line = Line([opt_start, opt_end]).c("cyan").lw(10) if method_name == 'Nelder-Mead' else Line([opt_start, opt_end]).c("magenta" if method_name=='Powell' else "blue").lw(10)

        rec = {
            'method': method_name,
            'hemi': hemi,
            'start': opt_start,
            'end': opt_end,
            'objective': opt_obj,
            'obstacle_distance': opt_obst,
            'path_length': opt_len,
            'line': opt_line,
            'result': res,
            'elapsed': elapsed,
            'iterations': iters
        }
        records.append(rec)
        if best is None or opt_obj < best['objective']:
            best = rec
        print(f"  Objective: {opt_obj:.6f}  ObstDist: {opt_obst:.3f}  PathLen: {opt_len:.3f}")
        print(f"  Elapsed: {elapsed:.3f}s  Iterations: {iters}")

    print(f"\n[{method_name} Summary] Total time: {total_time:.3f}s  Total iterations: {total_iterations}")
    return best, records

# %% [markdown]
# ### Run Mono-Criteria Optimization
#
# Use Nelder-Mead simplex algorithm to optimize the weighted sum objective. Starts from a random feasible point.

# %%
## Run Nelder-Mead optimization over all initial paths
if not initial_paths:
    raise RuntimeError("No initial paths available for Nelder-Mead optimization.")

print(f"\nRunning Nelder-Mead optimization over {len(initial_paths)} initial path(s)...")
nm_best, nm_records = run_multistart('Nelder-Mead', {
    'maxiter': nm_max_iterations,
    'xatol': nm_tolerance,
    'fatol': nm_tolerance,
    'disp': True
})

# Assign best NM run
nm_hemisphere = nm_best['hemi']
nm_optimal_start = nm_best['start']
nm_optimal_end = nm_best['end']
nm_optimal_objective = nm_best['objective']
nm_obstacle_dist = nm_best['obstacle_distance']
nm_path_length = nm_best['path_length']
nm_optimal_line = nm_best['line']
selected_hemisphere = nm_hemisphere

print(f"\n{'='*60}")
print("Best Nelder-Mead run across initial paths:")
print(f"  Hemisphere: {nm_hemisphere}")
print(f"  Objective: {nm_optimal_objective:.6f}")
print(f"  Obstacle distance: {nm_obstacle_dist:.3f}")
print(f"  Path length: {nm_path_length:.3f}")
print(f"  Start: {nm_optimal_start}")
print(f"  End:   {nm_optimal_end}")
# Out:
# Running Nelder-Mead optimization over 10 initial path(s)...
#
# [Nelder-Mead 1/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.851103
#          Iterations: 54
#          Function evaluations: 221
#   Objective: -0.851103  ObstDist: 7.649  PathLen: 50.223
#   Elapsed: 5.392s  Iterations: 54
#
# [Nelder-Mead 2/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.885428
#          Iterations: 53
#          Function evaluations: 229
#   Objective: -0.885428  ObstDist: 7.649  PathLen: 19.629
#   Elapsed: 5.324s  Iterations: 53
#
# [Nelder-Mead 3/10] hemi=right
# C:\Users\doubl\AppData\Local\Temp\ipykernel_12400\769863366.py:24: RuntimeWarning: Maximum number of iterations has been exceeded.
#   res = minimize(weighted_sum_objective, x0, method=method_name, options=options)
#   Objective: -0.884310  ObstDist: 7.649  PathLen: 20.625
#   Elapsed: 85.080s  Iterations: 500
#
# [Nelder-Mead 4/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.885428
#          Iterations: 61
#          Function evaluations: 235
#   Objective: -0.885428  ObstDist: 7.649  PathLen: 19.629
#   Elapsed: 5.428s  Iterations: 61
#
# [Nelder-Mead 5/10] hemi=right
#   Objective: -0.848499  ObstDist: 7.649  PathLen: 52.543
#   Elapsed: 78.405s  Iterations: 500
#
# [Nelder-Mead 6/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.843944
#          Iterations: 490
#          Function evaluations: 900
#   Objective: -0.843944  ObstDist: 7.649  PathLen: 56.603
#   Elapsed: 21.696s  Iterations: 490
#
# [Nelder-Mead 7/10] hemi=right
#   Objective: -0.844742  ObstDist: 7.649  PathLen: 55.892
#   Elapsed: 67.020s  Iterations: 500
#
# [Nelder-Mead 8/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.844086
#          Iterations: 140
#          Function evaluations: 356
#   Objective: -0.844086  ObstDist: 7.649  PathLen: 56.477
#   Elapsed: 8.933s  Iterations: 140
#
# [Nelder-Mead 9/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.839133
#          Iterations: 78
#          Function evaluations: 271
#   Objective: -0.839133  ObstDist: 7.649  PathLen: 60.891
#   Elapsed: 6.713s  Iterations: 78
#
# [Nelder-Mead 10/10] hemi=right
#   Objective: -0.847557  ObstDist: 7.649  PathLen: 53.383
#   Elapsed: 92.573s  Iterations: 500
#
# [Nelder-Mead Summary] Total time: 376.565s  Total iterations: 2876
#
# ============================================================
# Best Nelder-Mead run across initial paths:
#   Hemisphere: right
#   Objective: -0.885428
#   Obstacle distance: 7.649
#   Path length: 19.629
#   Start: (np.float64(88.44739532470703), np.float64(131.32716369628906), np.float64(87.4511947631836))
#   End:   (np.float64(108.0), np.float64(129.75), np.float64(86.75))

# %% [markdown]
# ### Evaluate Optimal Path
#
# Compute detailed metrics for the optimized path.

# %%
# Evaluate the optimal path (best Nelder-Mead across initial paths)
nm_obstacle_dist = compute_obstacle_distance(nm_optimal_start, nm_optimal_end)
nm_path_length = compute_path_length(nm_optimal_start, nm_optimal_end)
nm_has_intersection = check_intersection(nm_optimal_start, nm_optimal_end)

print(f"\nNelder-Mead Optimal Path Metrics:")
print(f"  Obstacle distance: {nm_obstacle_dist:.3f}")
print(f"  Path length: {nm_path_length:.3f}")
print(f"  Intersects obstacles: {nm_has_intersection}")
# Out:
# Nelder-Mead Optimal Path Metrics:
#   Obstacle distance: 7.649
#   Path length: 19.629
#   Intersects obstacles: False

# %%
## Save Nelder-Mead optimal path to file
nm_output_file = "nelder_mead_optimal_path.csv"
if max_obstacle_dist and max_obstacle_dist > 0:
    nm_norm_obstacle = nm_obstacle_dist / max_obstacle_dist
else:
    nm_norm_obstacle = nm_obstacle_dist / 100.0
if max_path_length and max_path_length > 0:
    nm_norm_length = nm_path_length / max_path_length
else:
    nm_norm_length = nm_path_length / 200.0
nm_weighted_obj = nm_optimal_objective
with open(nm_output_file, 'w') as f:
    f.write("method,hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,obstacle_distance,path_length,weighted_objective\n")
    f.write(
        f"Nelder-Mead,{nm_hemisphere},{nm_optimal_start[0]},{nm_optimal_start[1]},{nm_optimal_start[2]},{nm_optimal_end[0]},{nm_optimal_end[1]},{nm_optimal_end[2]},{nm_obstacle_dist},{nm_path_length},{nm_weighted_obj}\n"
    )
print(f"Saved Nelder-Mead optimal path to {nm_output_file}")
# Out:
# Saved Nelder-Mead optimal path to nelder_mead_optimal_path.csv

# %% [markdown]
# ### Compare with Monte Carlo Results
#
# Compare the Nelder-Mead optimized path with the best Monte Carlo path.

# %%
if successful_attempts and nm_optimal_line is not None:
    mc_best_hemi, mc_best_start, mc_best_end, mc_best_obstacle_dist, mc_best_path_len = successful_attempts[0]
    mc_best_path_length = compute_path_length(mc_best_start, mc_best_end)
    
    # Compute weighted sum for Monte Carlo best
    norm_mc_obstacle = mc_best_obstacle_dist / max_obstacle_dist if max_obstacle_dist > 0 else 0
    norm_mc_length = mc_best_path_length / max_path_length if max_path_length > 0 else 0
    mc_weighted_sum = -w_obstacle_norm * norm_mc_obstacle + w_path_length_norm * norm_mc_length
    
    # Compute weighted sum for Nelder-Mead
    norm_nm_obstacle = nm_obstacle_dist / max_obstacle_dist if max_obstacle_dist > 0 else 0
    norm_nm_length = nm_path_length / max_path_length if max_path_length > 0 else 0
    nm_weighted_sum = -w_obstacle_norm * norm_nm_obstacle + w_path_length_norm * norm_nm_length
    
    print(f"\n{'='*60}")
    print(f"Comparison: Monte Carlo vs Weighted Sum Optimization")
    print(f"{'='*60}")
    print(f"\nMonte Carlo (best of {len(successful_attempts)} successful):")
    print(f"  Obstacle distance: {mc_best_obstacle_dist:.3f}")
    print(f"  Path length: {mc_best_path_length:.3f}")
    print(f"  Weighted sum: {mc_weighted_sum:.6f}")
    
    print(f"\nWeighted Sum Optimization:")
    print(f"  Obstacle distance: {nm_obstacle_dist:.3f}")
    print(f"  Path length: {nm_path_length:.3f}")
    print(f"  Weighted sum: {nm_weighted_sum:.6f}")

else:
    print("No Monte Carlo results available for comparison")
# Out:
# ============================================================
# Comparison: Monte Carlo vs Weighted Sum Optimization
# ============================================================
#
# Monte Carlo (best of 100 successful):
#   Obstacle distance: 7.586
#   Path length: 63.815
#   Weighted sum: -0.828403
#
# Weighted Sum Optimization:
#   Obstacle distance: 7.649
#   Path length: 19.629
#   Weighted sum: -0.885428

# %% [markdown]
# ## Load Path Data

# %%
## Load Monte Carlo path coordinates from file
input_file = "monte_carlo_paths.csv"
monte_carlo_records = []

import csv
if os.path.exists(input_file):
    with open(input_file, 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            try:
                record = {
                    'hemisphere': row['hemisphere'],
                    'start': (
                        float(row['start_x']),
                        float(row['start_y']),
                        float(row['start_z'])
                    ),
                    'end': (
                        float(row['end_x']),
                        float(row['end_y']),
                        float(row['end_z'])
                    ),
                    'obstacle_distance': float(row['obstacle_distance']),
                    'path_length': float(row['path_length']),
                    'status': row['status'],
                    'is_best': (row.get('is_best', '0') == '1')
                }
                monte_carlo_records.append(record)
            except Exception as e:
                print(f"[WARN] Skipping row due to parse error: {e}")

    # Rebuild successful_attempts if empty (avoid overwriting if already present)
    if 'successful_attempts' not in globals():
        successful_attempts = []
    if not successful_attempts:
        for r in monte_carlo_records:
            if r['status'] == 'success':
                successful_attempts.append((r['hemisphere'], r['start'], r['end'], r['obstacle_distance'], r['path_length']))

    # Rebuild failed_attempts if empty
    if 'failed_attempts' not in globals():
        failed_attempts = []
    if not failed_attempts:
        for r in monte_carlo_records:
            if r['status'] == 'fail':
                failed_attempts.append((r['hemisphere'], r['start'], r['end'], r['obstacle_distance'], r['path_length']))

    # Identify best path
    loaded_best = next((r for r in monte_carlo_records if r['status'] == 'success' and r['is_best']), None)
    if loaded_best:
        print(f"Loaded best Monte Carlo path: hemi={loaded_best['hemisphere']} obstacle_dist={loaded_best['obstacle_distance']:.3f} path_len={loaded_best['path_length']:.3f}")
    else:
        print("Best Monte Carlo path flag not found; will infer later if needed.")
    print(f"Loaded {len(monte_carlo_records)} Monte Carlo path records from {input_file}")
else:
    print(f"[INFO] Monte Carlo path file not found: {input_file}")
# Out:
# Loaded best Monte Carlo path: hemi=right obstacle_dist=7.427 path_len=62.757
# Loaded 100 Monte Carlo path records from monte_carlo_paths.csv

# %%
## Load optimized Nelder-Mead path from file
nm_input_file = "nelder_mead_optimal_path.csv"
# Read Nelder-Mead optimal path from CSV and rebuild variables
if os.path.exists(nm_input_file):
    with open(nm_input_file, 'r') as f:
        reader = csv.DictReader(f)
        row = next(reader, None)
        if row:
            nm_hemisphere = row['hemisphere']
            nm_optimal_start = (float(row['start_x']), float(row['start_y']), float(row['start_z']))
            nm_optimal_end = (float(row['end_x']), float(row['end_y']), float(row['end_z']))
            nm_obstacle_dist = float(row['obstacle_distance'])
            nm_path_length = float(row['path_length'])
            nm_weighted_obj = float(row.get('weighted_objective', -w_obstacle_norm * (nm_obstacle_dist / max_obstacle_dist if max_obstacle_dist else nm_obstacle_dist / 100.0)
                                            + w_path_length_norm * (nm_path_length / max_path_length if max_path_length else nm_path_length / 200.0)))
            selected_hemisphere = nm_hemisphere
            nm_optimal_line = Line([nm_optimal_start, nm_optimal_end]).c("cyan").lw(10)
            print(f"Loaded NM path: hemi={nm_hemisphere} obstacle={nm_obstacle_dist:.3f} length={nm_path_length:.3f} weighted={nm_weighted_obj:.6f}")
        else:
            print("[INFO] NM file is empty.")
else:
    print(f"[INFO] NM path file not found: {nm_input_file}")

# %% [markdown]
# ## Powell Optimization

# %%
# Run Powell optimization over all initial paths
print(f"\nRunning Powell optimization over {len(initial_paths)} initial path(s)...")
powell_best, powell_records = run_multistart('Powell', {
    'maxiter': nm_max_iterations,
    'xtol': nm_tolerance,
    'ftol': nm_tolerance,
    'disp': True
})

powell_hemisphere = powell_best['hemi']
powell_optimal_start = powell_best['start']
powell_optimal_end = powell_best['end']
powell_optimal_objective = powell_best['objective']
powell_obstacle_dist = powell_best['obstacle_distance']
powell_path_length = powell_best['path_length']
powell_optimal_line = powell_best['line']

print(f"\n{'='*60}")
print("Best Powell run across initial paths:")
print(f"  Hemisphere: {powell_hemisphere}")
print(f"  Objective: {powell_optimal_objective:.6f}")
print(f"  Obstacle distance: {powell_obstacle_dist:.3f}")
print(f"  Path length: {powell_path_length:.3f}")
print(f"  Start: {powell_optimal_start}")
print(f"  End:   {powell_optimal_end}")
# Out:
# Running Powell optimization over 10 initial path(s)...
#
# [Powell 1/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.885428
#          Iterations: 3
#          Function evaluations: 452
#   Objective: -0.885428  ObstDist: 7.649  PathLen: 19.629
#   Elapsed: 11.543s  Iterations: 3
#
# [Powell 2/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.884666
#          Iterations: 2
#          Function evaluations: 197
#   Objective: -0.884666  ObstDist: 7.649  PathLen: 20.308
#   Elapsed: 4.742s  Iterations: 2
#
# [Powell 3/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.873458
#          Iterations: 4
#          Function evaluations: 439
#   Objective: -0.873458  ObstDist: 7.649  PathLen: 30.298
#   Elapsed: 10.449s  Iterations: 4
#
# [Powell 4/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.859073
#          Iterations: 3
#          Function evaluations: 376
#   Objective: -0.859073  ObstDist: 7.649  PathLen: 43.119
#   Elapsed: 9.108s  Iterations: 3
#
# [Powell 5/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.834611
#          Iterations: 3
#          Function evaluations: 539
#   Objective: -0.834611  ObstDist: 7.531  PathLen: 52.475
#   Elapsed: 12.917s  Iterations: 3
#
# [Powell 6/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.829160
#          Iterations: 3
#          Function evaluations: 527
#   Objective: -0.829160  ObstDist: 7.515  PathLen: 55.666
#   Elapsed: 12.369s  Iterations: 3
#
# [Powell 7/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.844737
#          Iterations: 6
#          Function evaluations: 928
#   Objective: -0.844737  ObstDist: 7.649  PathLen: 55.897
#   Elapsed: 20.242s  Iterations: 6
#
# [Powell 8/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.848077
#          Iterations: 3
#          Function evaluations: 288
#   Objective: -0.848077  ObstDist: 7.649  PathLen: 52.920
#   Elapsed: 6.900s  Iterations: 3
#
# [Powell 9/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.847639
#          Iterations: 2
#          Function evaluations: 265
#   Objective: -0.847639  ObstDist: 7.649  PathLen: 53.310
#   Elapsed: 6.253s  Iterations: 2
#
# [Powell 10/10] hemi=right
# Optimization terminated successfully.
#          Current function value: -0.885428
#          Iterations: 3
#          Function evaluations: 379
#   Objective: -0.885428  ObstDist: 7.649  PathLen: 19.629
#   Elapsed: 8.746s  Iterations: 3
#
# [Powell Summary] Total time: 103.270s  Total iterations: 32
#
# ============================================================
# Best Powell run across initial paths:
#   Hemisphere: right
#   Objective: -0.885428
#   Obstacle distance: 7.649
#   Path length: 19.629
#   Start: (np.float64(88.44739532470703), np.float64(131.32716369628906), np.float64(87.4511947631836))
#   End:   (np.float64(108.0), np.float64(129.75), np.float64(86.75))

# %%
# Save to CSV
powell_output_file = 'powell_optimal_path.csv'
with open(powell_output_file, 'w') as f:
    f.write('method,hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,obstacle_distance,path_length,weighted_objective\n')
    f.write(f'Powell,{powell_hemisphere},{powell_optimal_start[0]},{powell_optimal_start[1]},{powell_optimal_start[2]},{powell_optimal_end[0]},{powell_optimal_end[1]},{powell_optimal_end[2]},{powell_obstacle_dist},{powell_path_length},{powell_optimal_objective}\n')
print(f'Saved Powell optimal path to {powell_output_file}')
# Out:
# Saved Powell optimal path to powell_optimal_path.csv

# %% [markdown]
# ## COBYLA Optimization

# %%
# Run COBYLA optimization over all initial paths
print(f"\nRunning COBYLA optimization over {len(initial_paths)} initial path(s)...")
cobyla_best, cobyla_records = run_multistart('COBYLA', {
    'maxiter': nm_max_iterations,
    'tol': nm_tolerance,
    'disp': True
})

cobyla_hemisphere = cobyla_best['hemi']
cobyla_optimal_start = cobyla_best['start']
cobyla_optimal_end = cobyla_best['end']
cobyla_optimal_objective = cobyla_best['objective']
cobyla_obstacle_dist = cobyla_best['obstacle_distance']
cobyla_path_length = cobyla_best['path_length']
cobyla_optimal_line = cobyla_best['line']

print(f"\n{'='*60}")
print("Best COBYLA run across initial paths:")
print(f"  Hemisphere: {cobyla_hemisphere}")
print(f"  Objective: {cobyla_optimal_objective:.6f}")
print(f"  Obstacle distance: {cobyla_obstacle_dist:.3f}")
print(f"  Path length: {cobyla_path_length:.3f}")
print(f"  Start: {cobyla_optimal_start}")
print(f"  End:   {cobyla_optimal_end}")
# Out:
# Running COBYLA optimization over 10 initial path(s)...
#
# [COBYLA 1/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 55   Least value of F = -0.8517323497577344
# The corresponding X is:
# [ 55.52486801 137.89818022  99.97525699 105.25702183 128.42621031
#   92.58794751]
#
#   Objective: -0.851732  ObstDist: 7.649  PathLen: 49.662
#   Elapsed: 1.349s  Iterations: 55
#
# [COBYLA 2/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 71   Least value of F = -0.8664297133602028
# The corresponding X is:
# [ 97.1648449  127.57444577 122.64632051 106.03357538 128.25781711
#   89.91415994]
#
#   Objective: -0.866430  ObstDist: 7.649  PathLen: 36.562
#   Elapsed: 1.760s  Iterations: 71
#
# [COBYLA 3/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 69   Least value of F = -0.8685666997788106
# The corresponding X is:
# [ 76.08247884 130.07435317 100.09583149 106.12815515 129.88475225
#   89.24809959]
#
#   Objective: -0.868567  ObstDist: 7.649  PathLen: 34.657
#   Elapsed: 1.751s  Iterations: 69
#
# [COBYLA 4/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 91   Least value of F = -0.8590726351347721
# The corresponding X is:
# [ 89.86534363 125.13803928 125.95965835 107.9384047  128.77607234
#   88.22128388]
#
#   Objective: -0.859073  ObstDist: 7.649  PathLen: 43.119
#   Elapsed: 2.327s  Iterations: 91
#
# [COBYLA 5/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 105   Least value of F = -0.8155778123987146
# The corresponding X is:
# [108.90844541  91.02235326 122.29838314 107.89837028 131.39812086
#   86.24087943]
#
#   Objective: -0.815578  ObstDist: 7.387  PathLen: 54.192
#   Elapsed: 2.626s  Iterations: 105
#
# [COBYLA 6/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 140   Least value of F = -0.8439844688423636
# The corresponding X is:
# [136.36429941  90.67862644 116.27781899 106.76232729 130.14592095
#   91.95841316]
#
#   Objective: -0.843984  ObstDist: 7.649  PathLen: 56.567
#   Elapsed: 3.452s  Iterations: 140
#
# [COBYLA 7/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 120   Least value of F = -0.8224188982773302
# The corresponding X is:
# [102.3838712   78.17811112 108.22182945 109.94310065 128.99667647
#   89.10405661]
#
#   Objective: -0.822419  ObstDist: 7.462  PathLen: 56.107
#   Elapsed: 3.040s  Iterations: 120
#
# [COBYLA 8/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 106   Least value of F = -0.8264869923465541
# The corresponding X is:
# [145.47885673  80.16234374 123.97087429 108.16324956 129.98946834
#   87.09952241]
#
#   Objective: -0.826487  ObstDist: 7.649  PathLen: 72.163
#   Elapsed: 2.598s  Iterations: 106
#
# [COBYLA 9/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 89   Least value of F = -0.8278044000645741
# The corresponding X is:
# [ 43.09233566 110.58565988 110.80329683 107.45712988 130.03166988
#   88.93101727]
#
#   Objective: -0.827804  ObstDist: 7.649  PathLen: 70.989
#   Elapsed: 2.289s  Iterations: 89
#
# [COBYLA 10/10] hemi=right
# Return from COBYLA because the trust region radius reaches its lower bound.
# Number of function values = 56   Least value of F = -0.8088050216145553
# The corresponding X is:
# [146.31009874 126.07933458 132.74626367 109.02124241 132.51652015
#   87.50753841]
#
#   Objective: -0.808805  ObstDist: 7.387  PathLen: 60.229
#   Elapsed: 1.443s  Iterations: 56
#
# [COBYLA Summary] Total time: 22.635s  Total iterations: 902
#
# ============================================================
# Best COBYLA run across initial paths:
#   Hemisphere: right
#   Objective: -0.868567
#   Obstacle distance: 7.649
#   Path length: 34.657
#   Start: (np.float64(75.6675796508789), np.float64(129.8236541748047), np.float64(99.22866821289062))
#   End:   (np.float64(108.0), np.float64(129.75), np.float64(86.75))

# %%
# Save to CSV
cobyla_output_file = 'cobyla_optimal_path.csv'
with open(cobyla_output_file, 'w') as f:
    f.write('method,hemisphere,start_x,start_y,start_z,end_x,end_y,end_z,obstacle_distance,path_length,weighted_objective\n')
    f.write(f'COBYLA,{cobyla_hemisphere},{cobyla_optimal_start[0]},{cobyla_optimal_start[1]},{cobyla_optimal_start[2]},{cobyla_optimal_end[0]},{cobyla_optimal_end[1]},{cobyla_optimal_end[2]},{cobyla_obstacle_dist},{cobyla_path_length},{cobyla_optimal_objective}\n')
print(f'Saved COBYLA optimal path to {cobyla_output_file}')
# Out:
# Saved COBYLA optimal path to cobyla_optimal_path.csv

# %% [markdown]
# ## Method Comparison

# %%
# Compare best results from Nelder-Mead, Powell, and COBYLA
print(f"\n{'='*70}")
print("Multi-Method Optimization Comparison")
print(f"{'='*70}")
print(f"Nelder-Mead: Obj={nm_optimal_objective:.6f} ObstDist={nm_obstacle_dist:.3f} PathLen={nm_path_length:.3f}")
print(f"Powell:      Obj={powell_optimal_objective:.6f} ObstDist={powell_obstacle_dist:.3f} PathLen={powell_path_length:.3f}")
print(f"COBYLA:      Obj={cobyla_optimal_objective:.6f} ObstDist={cobyla_obstacle_dist:.3f} PathLen={cobyla_path_length:.3f}")

methods_summary = [
    ('Nelder-Mead', nm_optimal_objective, nm_obstacle_dist, nm_path_length),
    ('Powell', powell_optimal_objective, powell_obstacle_dist, powell_path_length),
    ('COBYLA', cobyla_optimal_objective, cobyla_obstacle_dist, cobyla_path_length)
 ]
# Out:
# ======================================================================
# Multi-Method Optimization Comparison
# ======================================================================
# Nelder-Mead: Obj=-0.885428 ObstDist=7.649 PathLen=19.629
# Powell:      Obj=-0.885428 ObstDist=7.649 PathLen=19.629
# COBYLA:      Obj=-0.868567 ObstDist=7.649 PathLen=34.657

# %% [markdown]
# ## Visualization

# %%
# Set vedo backend to pop out plots in separate windows
vedo.settings.default_backend = 'vtk' # or 'vt' or '2d' or 'k3d' or 'ipyvtklink'

# %%
## Plot final results
NUM_FAILED_TO_SHOW = min(10, len(failed_lines))
NUM_SUBOPTIMAL_TO_SHOW = min(10, len(suboptimal_lines))

actors = []
if merged_full_brain: actors.append(merged_full_brain)

if selected_hemisphere == 'left':
    if merged_left_entry_zone:
        actors.append(merged_left_entry_zone.clone().alpha(0.08))
    if merged_right_entry_zone:
        actors.append(merged_right_entry_zone.clone().alpha(0.02))
    if merged_left_stn:
        actors.append(merged_left_stn.clone().alpha(0.9))
    if merged_right_stn:
        actors.append(merged_right_stn.clone().alpha(0.3))
elif selected_hemisphere == 'right':
    if merged_left_entry_zone:
        actors.append(merged_left_entry_zone.clone().alpha(0.02))
    if merged_right_entry_zone:
        actors.append(merged_right_entry_zone.clone().alpha(0.08))
    if merged_left_stn:
        actors.append(merged_left_stn.clone().alpha(0.3))
    if merged_right_stn:
        actors.append(merged_right_stn.clone().alpha(0.9))
else:
    if merged_left_entry_zone: actors.append(merged_left_entry_zone)
    if merged_right_entry_zone: actors.append(merged_right_entry_zone)
    if merged_left_stn: actors.append(merged_left_stn)
    if merged_right_stn: actors.append(merged_right_stn)

if merged_obstacles: actors.append(merged_obstacles.clone().alpha(0.7))

actors.extend(failed_lines[:NUM_FAILED_TO_SHOW])
actors.extend(suboptimal_lines[:NUM_SUBOPTIMAL_TO_SHOW])
if best_path:
    mc_best_faded = best_path.clone().alpha(0.6)
    actors.append(mc_best_faded)

try:
    actors.append(nm_optimal_line)
except:
    print("Nelder-Mead optimized path not found.")

try:
    actors.append(powell_optimal_line)
except:
    print("Powell optimized path not found.")
    
try:
    actors.append(cobyla_optimal_line)
except:
    print("Cobyla optimized path not found.")

print(f"Rendering scene with optimized path (cyan)...")
show(actors, axes=1, viewup="z", 
     title=f"Optimized Path", new=True, interactive=True)
# Out:
# Rendering scene with optimized path (cyan)...

# %% [markdown]
# #### K3D

# %%
import k3d

# Helper function to convert vedo mesh to k3d mesh
def vedo_to_k3d_mesh(vedo_mesh, color=None, opacity_factor=1.0):
    vertices = np.array(vedo_mesh.vertices, dtype=np.float32)
    faces = np.array(vedo_mesh.cells, dtype=np.uint32)
    
    if color is None:
        vedo_color = vedo_mesh.color()
        if isinstance(vedo_color, str):
            import matplotlib.colors as mcolors
            if vedo_color in mcolors.CSS4_COLORS:
                color_hex = mcolors.CSS4_COLORS[vedo_color]
                color = int(color_hex.lstrip('#'), 16)
            else:
                color = 0x808080
        elif isinstance(vedo_color, (list, tuple, np.ndarray)):
            # Handle RGB tuples/arrays (values 0-1 or 0-255)
            rgb = np.asarray(vedo_color[:3])
            # Normalize to 0-255 range if needed
            if rgb.max() <= 1.0:
                rgb = (rgb * 255).astype(int)
            else:
                rgb = rgb.astype(int)
            r, g, b = int(rgb[0]), int(rgb[1]), int(rgb[2])
            color = (r << 16) | (g << 8) | b
        else:
            color = 0x808080
    
    vedo_alpha = vedo_mesh.alpha()
    if vedo_alpha is not None:
        opacity = float(vedo_alpha)
    else:
        opacity = 1.0
        
    opacity = np.clip(opacity * opacity_factor, 0.0, 1.0)
    
    return k3d.mesh(vertices, faces, color=color, opacity=opacity)

def vedo_line_to_k3d(vedo_line, color=None, width=0.1):
    line_scale_factor = 0.2
    points = np.array(vedo_line.vertices, dtype=np.float32)
    
    if color is None:
        vedo_color = vedo_line.color()
        if isinstance(vedo_color, str):
            import matplotlib.colors as mcolors
            if vedo_color in mcolors.CSS4_COLORS:
                color_hex = mcolors.CSS4_COLORS[vedo_color]
                color = int(color_hex.lstrip('#'), 16)
            else:
                color = 0x00FF00
        elif isinstance(vedo_color, (list, tuple, np.ndarray)):
            # Handle RGB tuples/arrays (values 0-1 or 0-255)
            rgb = np.asarray(vedo_color[:3])
            # Normalize to 0-255 range if needed
            if rgb.max() <= 1.0:
                rgb = (rgb * 255).astype(int)
            else:
                rgb = rgb.astype(int)
            r, g, b = int(rgb[0]), int(rgb[1]), int(rgb[2])
            color = (r << 16) | (g << 8) | b
        else:
            color = 0x00FF00
    
    return k3d.line(points, color=color, width=width * line_scale_factor)

# %%
## Plot optimization results with k3d
plot = k3d.plot(name=f'Optimized Path (w_obs={w_obstacle_norm:.2f}, w_len={w_path_length_norm:.2f})')

if merged_full_brain:
    plot += vedo_to_k3d_mesh(merged_full_brain)

if selected_hemisphere == 'left':
    print("Left hemisphere focused.")
    if merged_left_entry_zone:
        plot += vedo_to_k3d_mesh(merged_left_entry_zone, opacity_factor=2)
    if merged_right_entry_zone:
        plot += vedo_to_k3d_mesh(merged_right_entry_zone, opacity_factor=0.5)
    if merged_left_stn:
        plot += vedo_to_k3d_mesh(merged_left_stn, opacity_factor=1)
    if merged_right_stn:
        plot += vedo_to_k3d_mesh(merged_right_stn, opacity_factor=0.5)
elif selected_hemisphere == 'right':
    print("Right hemisphere focused.")
    if merged_left_entry_zone:
        plot += vedo_to_k3d_mesh(merged_left_entry_zone, opacity_factor=0.5)
    if merged_right_entry_zone:
        plot += vedo_to_k3d_mesh(merged_right_entry_zone, opacity_factor=2)
    if merged_left_stn:
        plot += vedo_to_k3d_mesh(merged_left_stn, opacity_factor=0.5)
    if merged_right_stn:
        plot += vedo_to_k3d_mesh(merged_right_stn, opacity_factor=1)
else:
    if merged_left_entry_zone:
        plot += vedo_to_k3d_mesh(merged_left_entry_zone)
    if merged_right_entry_zone:
        plot += vedo_to_k3d_mesh(merged_right_entry_zone)
    if merged_left_stn:
        plot += vedo_to_k3d_mesh(merged_left_stn)
    if merged_right_stn:
        plot += vedo_to_k3d_mesh(merged_right_stn)

if merged_obstacles:
    plot += vedo_to_k3d_mesh(merged_obstacles)

for line in failed_lines:
    plot += vedo_line_to_k3d(line, color=0xFF5F1F, width=FAILED_PATH_WIDTH * 0.5)
for line in suboptimal_lines:
    plot += vedo_line_to_k3d(line, color=0xFFFF00, width=SUBOPTIMAL_PATH_WIDTH * 0.5)
if best_path:
    plot += vedo_line_to_k3d(best_path, color=0x00FF00, width=BEST_PATH_WIDTH * 0.7)

try:
    plot += vedo_line_to_k3d(nm_optimal_line, color=0x00FFFF, width=BEST_PATH_WIDTH * 1.0)
except: 
    print("Nelder-Mead optimized path not found.")

print("Displaying optimization result with k3d...")
plot.display()
# Out:
# Right hemisphere focused.
# Displaying optimization result with k3d...
# Output()
